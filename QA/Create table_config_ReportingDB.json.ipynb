# %%
import os
import pymysql
import datetime
import pandas as pd
from lib.configuration import get_config, get_connection_string,get_current_config
from sqlalchemy import create_engine
from functools import reduce

# %%
os.getcwd()
# Out:
# 'C:\\Users\\estefanovich\\projects\\PatentsView-DB'

# %%
os.environ['PACKAGE_HOME']="C:/Users/estefanovich/projects/PatentsView-DB"

# %%
c=get_config()

# %%
config = get_current_config('granted_patent', **{
        "execution_date": datetime.date(2021, 11, 4)
    })
# Out:
#     generating config with parameters:
#     type: granted_patent
#     schedule: weekly
#     execution date: 2021-11-04

# %%
connection_string=get_connection_string(config, database='PROD_DB')

# %%
engine=create_engine(connection_string)

# %%
columns=pd.read_sql_query(sql="""
select *
from information_schema.COLUMNS
where TABLE_SCHEMA = 'PatentsView_20230330';
""", con=engine)

# %%
columns.groupby('TABLE_NAME').get_group('application')
# Out:
#     TABLE_CATALOG          TABLE_SCHEMA   TABLE_NAME     COLUMN_NAME  \
# 288           def  PatentsView_20230330  application  application_id
# 289           def  PatentsView_20230330  application       patent_id
# 290           def  PatentsView_20230330  application            type
# 291           def  PatentsView_20230330  application          number
# 292           def  PatentsView_20230330  application         country
# 293           def  PatentsView_20230330  application            date
#
#      ORDINAL_POSITION COLUMN_DEFAULT IS_NULLABLE DATA_TYPE  \
# 288                 1           None          NO   varchar
# 289                 2           None          NO   varchar
# 290                 3           NULL         YES   varchar
# 291                 4           NULL         YES   varchar
# 292                 5           NULL         YES   varchar
# 293                 6           NULL         YES      date
#
#      CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 288                      36.0                   144.0  ...
# 289                      20.0                    80.0  ...
# 290                      20.0                    80.0  ...
# 291                      64.0                   256.0  ...
# 292                      20.0                    80.0  ...
# 293                       NaN                     NaN  ...
#
#      DATETIME_PRECISION  CHARACTER_SET_NAME      COLLATION_NAME  COLUMN_TYPE  \
# 288                None             utf8mb4  utf8mb4_unicode_ci  varchar(36)
# 289                None             utf8mb4  utf8mb4_unicode_ci  varchar(20)
# 290                None             utf8mb4  utf8mb4_unicode_ci  varchar(20)
# 291                None             utf8mb4  utf8mb4_unicode_ci  varchar(64)
# 292                None             utf8mb4  utf8mb4_unicode_ci  varchar(20)
# 293                None                None                None         date
#
#     COLUMN_KEY EXTRA                       PRIVILEGES COLUMN_COMMENT  \
# 288        PRI        select,insert,update,references
# 289        PRI        select,insert,update,references
# 290                   select,insert,update,references
# 291        MUL        select,insert,update,references
# 292                   select,insert,update,references
# 293                   select,insert,update,references
#
#     IS_GENERATED GENERATION_EXPRESSION
# 288        NEVER                  None
# 289        NEVER                  None
# 290        NEVER                  None
# 291        NEVER                  None
# 292        NEVER                  None
# 293        NEVER                  None
#
# [6 rows x 22 columns]

# %%
#try to make table of just table names

#columns.groupby('TABLE_NAME') #doesn't work

columns['TABLE_NAME'].unique() #as a list
#pd.DataFrame(data = columns['TABLE_NAME'].unique()) #as a table
# Out:
# array(['temp_id_mapping_location', 'temp_id_mapping_examiner',
#        'temp_location_num_assignees', 'uspc_current_mainclass',
#        'temp_id_mapping_assignee', 'inventor_year',
#        'location_nber_subcategory', 'examiner', 'temp_id_mapping_lawyer',
#        'cpc_subsection', 'assignee', 'lawyer', 'patent_govintorg',
#        'temp_location_num_patents', 'assignee_uspc_mainclass',
#        'temp_num_us_patents_cited', 'temp_lawyer_num_patents',
#        'usapplicationcitation', 'inventor',
#        'temp_patent_firstnamed_assignee', 'temp_id_mapping_inventor',
#        'temp_nber_subcategory_aggregate_counts', 'temp_ipcr_aggregations',
#        'temp_lawyer_num_inventors', 'temp_inventor_lastknown_location',
#        'webtool_comparison_wipoI', 'temp_cpc_subsection_title',
#        'location_year', 'temp_lawyer_num_assignees',
#        'temp_inventor_num_patents', 'temp_subclass_current_title',
#        'location', 'webtool_comparison_stateIA',
#        'webtool_comparison_countryIAsector', 'cpc_current',
#        'cpc_current_group_patent_year', 'nber',
#        'temp_assignee_lastknown_location', 'cpc_current_subsection_copy',
#        'temp_patent_earliest_application_date',
#        'temp_patent_aggregations', 'location_cpc_subsection',
#        'cpc_current_subsection', 'patent_lawyer_unique',
#        'cpc_current_copy', 'assignee_year', 'patent_inventor',
#        'temp_inventor_num_assignees', 'assignee_cpc_group',
#        'assignee_cpc_subsection', 'inventor_uspc_mainclass',
#        'location_cpc_group', 'webtool_comparison_countryIsector', 'wipo',
#        'location_assignee', 'nber_category', 'temp_lawyer_years_active',
#        'application', 'nber_copy', 'patent',
#        'temp_cpc_current_subsection_aggregate_counts',
#        'temp_patent_firstnamed_inventor', 'webtool_comparison_wipoA',
#        'inventor_coinventor', 'cpc_group',
#        'uspc_current_mainclass_application_year',
#        'temp_mainclass_current_aggregate_counts', 'ipcr',
#        'temp_num_times_cited_by_us_patents',
#        'temp_cpc_current_group_aggregate_counts', 'uspc_subclass',
#        'inventor_nber_subcategory', 'temp_inventor_years_active',
#        'inventor_cpc_group', 'uspc_current_copy', 'temp_patent_date',
#        'temp_assignee_years_active', 'cpc_subgroup',
#        'cpc_current_group_copy', 'patent_inventor_old',
#        'cpc_current_group', 'uspc_current_mainclass_copy',
#        'uspc_current_mainclass_patent_year', 'temp_ipcr_years_active',
#        'patent_lawyer', 'assignee_inventor', 'government_interest',
#        'temp_num_foreign_documents_cited', 'patent_assignee',
#        'uspatentcitation', 'temp_assignee_num_inventors',
#        'location_inventor', 'inventor_rawinventor',
#        'nber_subcategory_patent_year', 'webtool_comparison_stateIsector',
#        'patent_contractawardnumber', 'patent_examiner',
#        'inventor_cpc_subsection', 'temp_num_us_applications_cited',
#        'government_organization', 'webtool_comparison_stateA',
#        'location_uspc_mainclass', 'uspc_mainclass',
#        'temp_mainclass_current_title', 'temp_assignee_num_patents',
#        'webtool_comparison_countryI', 'temp_cpc_group_title',
#        'webtool_comparison_stateI', 'temp_cpc_subgroup_title',
#        'cpc_current_subsection_patent_year',
#        'webtool_comparison_stateAsector', 'wipo_field', 'pctdata',
#        'assignee_nber_subcategory', 'uspc_current',
#        'temp_location_patent', 'nber_subcategory',
#        'webtool_comparison_countryIA',
#        'cpc_current_group_application_year',
#        'temp_location_num_inventors', 'foreignpriority'], dtype=object)

# %%
columns["DATA_TYPE"].unique()
# Out:
# array(['varchar', 'int', 'date', 'smallint', 'float', 'bigint', 'text'],
#       dtype=object)

# %%
columns
# Out:
#     TABLE_CATALOG          TABLE_SCHEMA                TABLE_NAME  \
# 0             def  PatentsView_20230330  temp_id_mapping_location
# 1             def  PatentsView_20230330  temp_id_mapping_location
# 2             def  PatentsView_20230330  temp_id_mapping_location
# 3             def  PatentsView_20230330  temp_id_mapping_examiner
# 4             def  PatentsView_20230330  temp_id_mapping_examiner
# ..            ...                   ...                       ...
# 587           def  PatentsView_20230330           foreignpriority
# 588           def  PatentsView_20230330           foreignpriority
# 589           def  PatentsView_20230330           foreignpriority
# 590           def  PatentsView_20230330           foreignpriority
# 591           def  PatentsView_20230330           foreignpriority
#
#                      COLUMN_NAME  ORDINAL_POSITION COLUMN_DEFAULT IS_NULLABLE  \
# 0                old_location_id                 1           None          NO
# 1    old_location_id_transformed                 2           NULL         YES
# 2                new_location_id                 3           None          NO
# 3                old_examiner_id                 1           None          NO
# 4                new_examiner_id                 2           None          NO
# ..                           ...               ...            ...         ...
# 587                     sequence                 2           None          NO
# 588           foreign_doc_number                 3           NULL         YES
# 589                         date                 4           NULL         YES
# 590                      country                 5           NULL         YES
# 591                         kind                 6           NULL         YES
#
#     DATA_TYPE  CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 0     varchar                     128.0                   512.0  ...
# 1     varchar                     128.0                   512.0  ...
# 2         int                       NaN                     NaN  ...
# 3     varchar                      36.0                   144.0  ...
# 4         int                       NaN                     NaN  ...
# ..        ...                       ...                     ...  ...
# 587       int                       NaN                     NaN  ...
# 588   varchar                      64.0                   256.0  ...
# 589      date                       NaN                     NaN  ...
# 590   varchar                      64.0                   256.0  ...
# 591   varchar                      24.0                    96.0  ...
#
#      DATETIME_PRECISION  CHARACTER_SET_NAME      COLLATION_NAME  \
# 0                  None             utf8mb4  utf8mb4_unicode_ci
# 1                  None             utf8mb4  utf8mb4_unicode_ci
# 2                  None                None                None
# 3                  None             utf8mb4  utf8mb4_unicode_ci
# 4                  None                None                None
# ..                  ...                 ...                 ...
# 587                None                None                None
# 588                None             utf8mb4  utf8mb4_unicode_ci
# 589                None                None                None
# 590                None             utf8mb4  utf8mb4_unicode_ci
# 591                None             utf8mb4  utf8mb4_unicode_ci
#
#           COLUMN_TYPE COLUMN_KEY           EXTRA  \
# 0        varchar(128)        PRI
# 1        varchar(128)
# 2    int(10) unsigned        MUL  auto_increment
# 3         varchar(36)        PRI
# 4    int(10) unsigned        UNI  auto_increment
# ..                ...        ...             ...
# 587           int(11)        PRI
# 588       varchar(64)        MUL
# 589              date        MUL
# 590       varchar(64)        MUL
# 591       varchar(24)        MUL
#
#                           PRIVILEGES COLUMN_COMMENT IS_GENERATED  \
# 0    select,insert,update,references                       NEVER
# 1    select,insert,update,references                       NEVER
# 2    select,insert,update,references                       NEVER
# 3    select,insert,update,references                       NEVER
# 4    select,insert,update,references                       NEVER
# ..                               ...            ...          ...
# 587  select,insert,update,references                       NEVER
# 588  select,insert,update,references                       NEVER
# 589  select,insert,update,references                       NEVER
# 590  select,insert,update,references                       NEVER
# 591  select,insert,update,references                       NEVER
#
#     GENERATION_EXPRESSION
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ..                    ...
# 587                  None
# 588                  None
# 589                  None
# 590                  None
# 591                  None
#
# [592 rows x 22 columns]

# %%
"""
# A list of categories pulled from the DataMonitor_categorycount output
# Can program this into the creation of the json file
category_list = ['applicant_type',
'category',
'classification_data_source',
'classification_level',
'classification_status',
# 'country',
# 'country_transformed',
'deceased',
'designation',
'doc_type',
'doctype',
'field_id',
'group',
'group_id',
'ipc_class',
'kind',
'relkind',
'role',
'section',
'section_id',
'state',
'status',
'subclass',
'subgroup',
'subgroup_id',
'symbol_position',
'type']
"""
# Out:
# "\n# A list of categories pulled from the DataMonitor_categorycount output\n# Can program this into the creation of the json file\ncategory_list = ['applicant_type',\n'category',\n'classification_data_source',\n'classification_level',\n'classification_status',\n# 'country',\n# 'country_transformed',\n'deceased',\n'designation',\n'doc_type',\n'doctype',\n'field_id',\n'group',\n'group_id',\n'ipc_class',\n'kind',\n'relkind',\n'role',\n'section',\n'section_id',\n'state',\n'status',\n'subclass',\n'subgroup',\n'subgroup_id',\n'symbol_position',\n'type']\n"

# %%
#category_list #not relevant for now

# %%
"""
for i in category_list:
    if i[:1] >= 'p':
        print(i)
    else:
        continue
"""
# Out:
# "\nfor i in category_list:\n    if i[:1] >= 'p':\n        print(i)\n    else:\n        continue\n"

# %%
def generate_column_setting(column):
    
    data_type = 'varchar'
    if column.DATA_TYPE in ['date', 'timestamp']:
        data_type = 'date'
    if column.DATA_TYPE in ['int', 'bigint', 'smallint', 'float', 'decimal']:
        data_type = 'int'
        
    null_allowed = True
    if column.IS_NULLABLE == 'NO':
        null_allowed = False
        
    location_field = False
    if column.COLUMN_NAME in ['country','country_transformed']:
        location_field = True

    category = False
    if column.COLUMN_NAME in category_list:
        if column.TABLE_NAME == 'foreign_priority':
            if column.COLUMN_NAME =='kind':
                category = False
        elif column.TABLE_NAME in ['further_cpc','main_cpc']:
            category = False
        elif column.COLUMN_NAME == 'section_id' and column.TABLE_NAME != 'cpc':
            category = False
        else:
            category=True
            
    setting = {
        column.COLUMN_NAME: {
            'data_type': data_type,
            'null_allowed': null_allowed,
            'category': category,
            'location_field': location_field
        },
    }
    return setting

# %%
def generate_table_setting(table_group):
    y=table_group.apply(generate_column_setting,axis=1)
    t_set={table_group.name:{"fields":reduce(lambda a, b: dict(a, **b), y.tolist())}}
    return t_set

# %%
x=columns.groupby('TABLE_NAME').apply(func=generate_table_setting)

# %%
x
# Out:
# TABLE_NAME
# application                        {'application': {'fields': {'application_id': ...
# assignee                           {'assignee': {'fields': {'assignee_id': {'data...
# assignee_cpc_group                 {'assignee_cpc_group': {'fields': {'assignee_i...
# assignee_cpc_subsection            {'assignee_cpc_subsection': {'fields': {'assig...
# assignee_inventor                  {'assignee_inventor': {'fields': {'assignee_id...
#                                                          ...
# webtool_comparison_stateIsector    {'webtool_comparison_stateIsector': {'fields':...
# webtool_comparison_wipoA           {'webtool_comparison_wipoA': {'fields': {'sect...
# webtool_comparison_wipoI           {'webtool_comparison_wipoI': {'fields': {'sect...
# wipo                               {'wipo': {'fields': {'patent_id': {'data_type'...
# wipo_field                         {'wipo_field': {'fields': {'id': {'data_type':...
# Length: 121, dtype: object

# %%
x["application"]
# Out:
# {'application': {'fields': {'application_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}}}}

# %%
my_list = []
for keys in x.keys():
    my_list.append(x[keys])

# %%
len(list(x.keys()))
# Out:
# 121

# %%
super_dict = {}
for k in set(k for d in my_list for k in d):
    super_dict[k] = [d[k] for d in my_list if k in d]

# %%
len(list(super_dict.keys()))
# Out:
# 121

# %%
for i in super_dict.keys():
    for j in super_dict[i]:
            j["TestScripts"] = ["ReportingDBTester"]

# %%
super_dict
# Out:
# {'uspc_current': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'mainclass_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subclass_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subclass_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_ipcr_aggregations': [{'fields': {'section': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'ipc_class': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'subclass': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'nber_subcategory_patent_year': [{'fields': {'subcategory_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'patent_year': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'assignee_uspc_mainclass': [{'fields': {'assignee_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'location_uspc_mainclass': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_cpc_subgroup_title': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'nber_category': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current_copy': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'section_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subsection_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'group_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'subgroup_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'category': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspc_current_mainclass': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'location': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'county': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'state_fips': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'county_fips': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'latitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'longitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'persistent_location_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_id_mapping_examiner': [{'fields': {'old_examiner_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'new_examiner_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor_rawinventor': [{'fields': {'uuid': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'patent_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'inventor_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_cpc_group_title': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'location_assignee': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'assignee_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current_group_copy': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'section_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'group_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': True,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_cpc_subsection_title': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_group': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_patent_date': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current_group_application_year': [{'fields': {'group_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': True,
#      'location_field': False},
#     'application_year': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sample_size': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'average_patent_processing_days': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor_cpc_group': [{'fields': {'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'group_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': True,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_id_mapping_lawyer': [{'fields': {'old_lawyer_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'new_lawyer_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'assignee_cpc_group': [{'fields': {'assignee_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'group_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': True,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_id_mapping_assignee': [{'fields': {'old_assignee_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'new_assignee_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_lawyer_num_assignees': [{'fields': {'lawyer_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'foreignpriority': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'foreign_doc_number': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'kind': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_patent_firstnamed_inventor': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'inventor_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'persistent_inventor_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'persistent_location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'latitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'longitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_subsection': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspc_mainclass': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_num_us_patents_cited': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_us_patents_cited': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_location_num_patents': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_subgroup': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current_group_patent_year': [{'fields': {'group_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': True,
#      'location_field': False},
#     'patent_year': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'ipcr': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'section': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'ipc_class': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'subclass': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'main_group': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subgroup': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'symbol_position': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'classification_value': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'classification_data_source': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'action_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'ipc_version_indicator': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_wipoI': [{'fields': {'sector_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'field_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'invSubCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor': [{'fields': {'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'lastknown_location_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_persistent_location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_latitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_longitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'persistent_inventor_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspc_current_copy': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subclass_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_mainclass_current_aggregate_counts': [{'fields': {'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'actual_years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspc_current_mainclass_patent_year': [{'fields': {'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'patent_year': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_num_times_cited_by_us_patents': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_times_cited_by_us_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'location_cpc_group': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'group_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': True,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'patent_contractawardnumber': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'contract_award_number': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_inventor_lastknown_location': [{'fields': {'inventor_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'persistent_location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'latitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'longitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_stateI': [{'fields': {'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'invCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_stateA': [{'fields': {'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assiCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'location_year': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'year': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_subclass_current_title': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'location_inventor': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor_nber_subcategory': [{'fields': {'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'subcategory_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'lawyer': [{'fields': {'lawyer_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'organization': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'persistent_lawyer_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'examiner': [{'fields': {'examiner_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'role': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'group': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'persistent_examiner_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_id_mapping_location': [{'fields': {'old_location_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'old_location_id_transformed': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'new_location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_cpc_current_subsection_aggregate_counts': [{'fields': {'subsection_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'actual_years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_lawyer_num_inventors': [{'fields': {'lawyer_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_countryIAsector': [{'fields': {'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'sector_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assiSubCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_countryI': [{'fields': {'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'invCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'patent_lawyer_unique': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lawyer_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspc_subclass': [{'fields': {'id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_location_num_assignees': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'assignee': [{'fields': {'assignee_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'organization': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'lastknown_location_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_persistent_location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_latitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'lastknown_longitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'persistent_assignee_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current_subsection_copy': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'section_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subsection_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'patent_govintorg': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'organization_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_location_num_inventors': [{'fields': {'location_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'wipo': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'field_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'government_interest': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'gi_statement': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current_subsection_patent_year': [{'fields': {'subsection_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'patent_year': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspatentcitation': [{'fields': {'citing_patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'cited_patent_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'category': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current_subsection': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'section_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subsection_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'subsection_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspc_current_mainclass_copy': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'application': [{'fields': {'application_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'number': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor_coinventor': [{'fields': {'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'coinventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_inventor_num_assignees': [{'fields': {'inventor_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'patent_inventor_old': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_id_mapping_inventor': [{'fields': {'old_inventor_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'new_inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'patent_lawyer': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'lawyer_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
# ...
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_stateIsector': [{'fields': {'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'sector_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'invSubCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'section_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subsection_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subsection_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'group_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'group_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subgroup_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'subgroup_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'category': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees_group': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors_group': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents_group': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date_group': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date_group': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active_group': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'usapplicationcitation': [{'fields': {'citing_patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'cited_application_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'name': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'kind': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'category': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_num_foreign_documents_cited': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_foreign_documents_cited': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_ipcr_years_active': [{'fields': {'section': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'ipc_class': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'subclass': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'actual_years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor_year': [{'fields': {'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'patent_year': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_assignee_lastknown_location': [{'fields': {'assignee_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'persistent_location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'latitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'longitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_countryIA': [{'fields': {'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assiCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_num_us_applications_cited': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_us_applications_cited': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'nber': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'category_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'category_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subcategory_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subcategory_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'years_active': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'nber_copy': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'category_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subcategory_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor_uspc_mainclass': [{'fields': {'inventor_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'mainclass_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_assignee_num_inventors': [{'fields': {'assignee_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_patent_earliest_application_date': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'earliest_application_date': {'data_type': 'date',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_patent_firstnamed_assignee': [{'fields': {'patent_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'assignee_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'persistent_assignee_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'persistent_location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True},
#     'latitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'longitude': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_cpc_current_group_aggregate_counts': [{'fields': {'group_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': True,
#      'location_field': False},
#     'num_assignees': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_inventors': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'actual_years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'government_organization': [{'fields': {'organization_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'name': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'level_one': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'level_two': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'level_three': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'webtool_comparison_wipoA': [{'fields': {'sector_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'year': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'field_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assiSubCount': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_assignee_num_patents': [{'fields': {'assignee_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'assignee_nber_subcategory': [{'fields': {'assignee_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'subcategory_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'num_patents': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'temp_inventor_years_active': [{'fields': {'inventor_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'first_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'last_seen_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'actual_years_active': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}]}

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
#x = x.to_json()

x = x.to_json(orient='records')
# Out:
# '[{"application":{"fields":{"application_id":{"data_type":"varchar","null_allowed":false,"category":false,"location_field":false},"patent_id":{"data_type":"varchar","null_allowed":false,"category":false,"location_field":false},"type":{"data_type":"varchar","null_allowed":true,"category":true,"location_field":false},"number":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"country":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":true},"date":{"data_type":"date","null_allowed":true,"category":false,"location_field":false}},"TestScripts":["ReportingDBTester"]}},{"assignee":{"fields":{"assignee_id":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"type":{"data_type":"varchar","null_allowed":true,"category":true,"location_field":false},"name_first":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"name_last":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"organization":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"num_patents":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"num_inventors":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"lastknown_location_id":{"data_type":"int","null_allowed":true,"category":false,"location_field":false},"lastknown_persistent_location_id":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"lastknown_city":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"lastknown_state":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"lastknown_country":{"data_type":"varchar","null_allowed":true,"category":false,"location_field":false},"lastknown_latitude":{"data_type":"int","null_allowed":true,"category":false,"location_field":false},"lastknown_longitude":{"data_type":"int","null_allowed":true,"category":false,"location_field":false},"first_seen_date":{"data_type":"date","null_allowed":true,"category":false,"location_field":false},"last_seen_date":{"data_type":"date","null_allowed":true,"category":false,"location_field":false},"years_active":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"persistent_assignee_id":{"data_type":"varchar","null_allowed":false,"category":false,"location_field":false}},"TestScripts":["ReportingDBTester"]}},{"assignee_cpc_group":{"fields":{"assignee_id":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"group_id":{"data_type":"varchar","null_allowed":false,"category":true,"location_field":false},"num_patents":{"data_type":"int","null_allowed":false,"category":false,"location_field":false}},"TestScripts":["ReportingDBTester"]}},{"assignee_cpc_subsection":{"fields":{"assignee_id":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"subsection_id":{"data_type":"varchar","null_allowed":false,"category":false,"location_field":false},"num_patents":{"data_type":"int","null_allowed":false,"category":false,"location_field":false}},"TestScripts":["ReportingDBTester"]}},{"assignee_inventor":{"fields":{"assignee_id":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"inventor_id":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"num_patents":{"data_type":"int","null_allowed":false,"category":false,"location_field":false}},"TestScripts":["ReportingDBTester"]}},{"assignee_nber_subcategory":{"fields":{"assignee_id":{"data_type":"int","null_allowed":false,"category":false,"location_field":false},"subcategory_id":{"data_type":"varchar","null_allowed":false,"category":false,"location_field":false},"num_patents":{"data_type":"int","null_allowed":false,"category":false,"location_field":false}},"TestScripts":["ReportingDBTester"]}},{"assignee_uspc_mainclass":{"fields":{"assignee_id" ...

# %%
x
# Out:
# TABLE_NAME
# application                        {'application': {'fields': {'application_id': ...
# assignee                           {'assignee': {'fields': {'assignee_id': {'data...
# assignee_cpc_group                 {'assignee_cpc_group': {'fields': {'assignee_i...
# assignee_cpc_subsection            {'assignee_cpc_subsection': {'fields': {'assig...
# assignee_inventor                  {'assignee_inventor': {'fields': {'assignee_id...
#                                                          ...
# webtool_comparison_stateIsector    {'webtool_comparison_stateIsector': {'fields':...
# webtool_comparison_wipoA           {'webtool_comparison_wipoA': {'fields': {'sect...
# webtool_comparison_wipoI           {'webtool_comparison_wipoI': {'fields': {'sect...
# wipo                               {'wipo': {'fields': {'patent_id': {'data_type'...
# wipo_field                         {'wipo_field': {'fields': {'id': {'data_type':...
# Length: 121, dtype: object

# %%
for i in x:
    print(i)
# Out:
# {
# "
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# "
# :
# {
# "
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# y
# p
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# b
# e
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# o
# u
# n
# t
# r
# y
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# t
# r
# u
# e
# }
# ,
# "
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# a
# s
# s
# i
# g
# n
# e
# e
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# y
# p
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# f
# i
# r
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# l
# a
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# o
# r
# g
# a
# n
# i
# z
# a
# t
# i
# o
# n
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# k
# n
# o
# w
# n
# _
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# k
# n
# o
# w
# n
# _
# p
# e
# r
# s
# i
# s
# t
# e
# n
# t
# _
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# q
# u
# e
# n
# c
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# g
# r
# o
# u
# p
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
#
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# c
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# c
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# c
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# g
# r
# o
# u
# p
# _
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# c
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# g
# r
# o
# u
# p
# _
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# c
# pd
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# e
# x
# a
# m
# i
# n
# e
# r
# "
# :
# {
# "
# e
# x
# a
# m
# i
# n
# e
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# e
# x
# a
# m
# i
# n
# e
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# f
# i
# r
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# l
# a
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# r
# o
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# e
# r
# s
# i
# s
# t
# e
# n
# t
# _
# e
# x
# a
# m
# i
# n
# e
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# f
# o
# r
# e
# i
# g
# n
# p
# r
# i
# o
# r
# i
# t
# y
# "
# :
# {
# "
# f
# o
# r
# e
# i
# g
# n
# p
# r
# i
# o
# r
# i
# t
# y
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# q
# u
# e
# n
# c
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# "
# ]
# }
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# f
# i
# r
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# l
# a
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# e
# r
# s
# i
# s
# t
# e
# n
# t
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# c
# o
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# c
# o
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# o
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# u
# s
# p
# c
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# u
# s
# p
# c
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# y
# e
# a
# r
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# y
# e
# a
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# i
# p
# c
# r
# "
# :
# {
# "
# i
# p
# c
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# q
# u
# e
# n
# c
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# c
# t
# i
# o
# n
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# i
# p
# c
# _
# c
# l
# a
# s
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# c
# l
# a
# s
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# l
# a
# w
# y
# e
# r
# "
# :
# {
# "
# l
# a
# w
# y
# e
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# l
# a
# w
# y
# e
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# f
# i
# r
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# a
# m
# e
# _
# l
# a
# s
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# o
# r
# g
# a
# n
# i
# z
# a
# t
# i
# o
# n
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# e
# r
# s
# i
# s
# t
# e
# n
# t
# _
# l
# a
# w
# y
# e
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# l
# o
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# a
# l
# s
# e
# }
# ,
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# g
# r
# o
# u
# p
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# n
# v
# e
# n
# t
# o
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# _
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# n
# b
# e
# r
# _
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# _
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# s
# u
# b
# c
# a
# t
# e
# g
# o
# r
# y
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# n
# a
# m
# e
# d
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# c
# o
# u
# n
# t
# r
# y
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# n
# a
# m
# e
# d
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# l
# a
# t
# i
# t
# u
# d
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# n
# a
# m
# e
# d
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# l
# o
# n
# g
# i
# t
# u
# d
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# f
# o
# r
# e
# i
# g
# n
# _
# d
# o
# c
# u
# m
# e
# n
# t
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# u
# s
# _
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# u
# s
# _
# p
# a
# t
# e
# n
# t
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# t
# o
# t
# a
# l
# _
# d
# o
# c
# u
# m
# e
# n
# t
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# t
# i
# m
# e
# s
# _
# c
# i
# t
# e
# d
# _
# b
# y
# _
# u
# s
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# e
# a
# r
# l
# i
# e
# s
# t
# _
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# p
# r
# o
# c
# e
# s
# s
# i
# n
# g
# _
# d
# a
# y
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# u
# s
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# a
# v
# e
# r
# a
# g
# e
# _
# p
# a
# t
# e
# n
# t
# _
# p
# r
# o
# c
# e
# s
# s
# i
# n
# g
# _
# d
# a
# y
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# g
# r
# o
# u
# p
# _
# a
# v
# e
# r
# a
# g
# e
# _
# p
# a
# t
# e
# n
# t
# _
# p
# r
# o
# c
# e
# s
# s
# i
# n
# g
# _
# d
# a
# y
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# e
# r
# m
# _
# e
# x
# t
# e
# n
# s
# i
# o
# n
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# q
# u
# e
# n
# c
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# l
# a
# w
# y
# e
# r
# _
# u
# n
# i
# q
# u
# e
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# l
# a
# w
# y
# e
# r
# _
# u
# n
# i
# q
# u
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# w
# y
# e
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# q
# u
# e
# n
# c
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# p
# c
# t
# d
# a
# t
# a
# "
# :
# {
# "
# p
# c
# t
# d
# a
# t
# a
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# d
# o
# c
# _
# t
# y
# p
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# k
# i
# n
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# d
# o
# c
# _
# n
# u
# m
# b
# e
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# 1
# 0
# 2
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# 3
# 7
# 1
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# a
# s
# s
# i
# g
# n
# e
# e
# _
# l
# a
# s
# t
# k
# n
# o
# w
# n
# _
# l
# o
# c
# a
# t
# i
# o
# n
# "
# :
# {
# "
# t
# e
# m
# p
# _
# a
# s
# s
# i
# g
# n
# e
# e
# _
# l
# a
# s
# t
# k
# n
# o
# w
# n
# _
# l
# o
# c
# a
# t
# i
# o
# n
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# a
# g
# g
# r
# e
# g
# a
# t
# e
# _
# c
# o
# u
# n
# t
# s
# "
# :
# {
# "
# t
# e
# m
# p
# _
# c
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# a
# g
# g
# r
# e
# g
# a
# t
# e
# _
# c
# o
# u
# n
# t
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# a
# c
# t
# u
# a
# l
# _
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# t
# e
# m
# p
# _
# c
# p
# c
# _
# g
# r
# o
# u
# p
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# c
# p
# c
# _
# s
# u
# b
# g
# r
# o
# u
# p
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# t
# e
# m
# p
# _
# c
# p
# c
# _
# s
# u
# b
# g
# r
# o
# u
# p
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# t
# e
# m
# p
# _
# c
# p
# c
# _
# s
# u
# b
# s
# e
# c
# t
# i
# o
# n
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# t
# e
# m
# p
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# t
# e
# m
# p
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# n
# v
# e
# n
# t
# o
# r
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# i
# n
# v
# e
# n
# t
# o
# r
# _
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# t
# ...
# t
# e
# n
# t
# s
# "
# :
# {
# "
# t
# e
# m
# p
# _
# l
# o
# c
# a
# t
# i
# o
# n
# _
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# l
# o
# c
# a
# t
# i
# o
# n
# _
# p
# a
# t
# e
# n
# t
# "
# :
# {
# "
# t
# e
# m
# p
# _
# l
# o
# c
# a
# t
# i
# o
# n
# _
# p
# a
# t
# e
# n
# t
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# c
# u
# r
# r
# e
# n
# t
# _
# a
# g
# g
# r
# e
# g
# a
# t
# e
# _
# c
# o
# u
# n
# t
# s
# "
# :
# {
# "
# t
# e
# m
# p
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# c
# u
# r
# r
# e
# n
# t
# _
# a
# g
# g
# r
# e
# g
# a
# t
# e
# _
# c
# o
# u
# n
# t
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# f
# o
# r
# e
# i
# g
# n
# _
# d
# o
# c
# u
# m
# e
# n
# t
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# u
# s
# _
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# u
# s
# _
# p
# a
# t
# e
# n
# t
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# t
# o
# t
# a
# l
# _
# d
# o
# c
# u
# m
# e
# n
# t
# s
# _
# c
# i
# t
# e
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# t
# i
# m
# e
# s
# _
# c
# i
# t
# e
# d
# _
# b
# y
# _
# u
# s
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# p
# a
# t
# e
# n
# t
# _
# d
# a
# t
# e
# "
# :
# {
# "
# t
# e
# m
# p
# _
# p
# a
# t
# e
# n
# t
# _
# d
# a
# t
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# p
# a
# t
# e
# n
# t
# _
# e
# a
# r
# l
# i
# e
# s
# t
# _
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# t
# e
# m
# p
# _
# p
# a
# t
# e
# n
# t
# _
# e
# a
# r
# l
# i
# e
# s
# t
# _
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# e
# a
# r
# l
# i
# e
# s
# t
# _
# a
# p
# p
# l
# i
# c
# a
# t
# i
# o
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# t
# e
# m
# p
# _
# p
# a
# t
# e
# n
# t
# _
# f
# i
# r
# s
# t
# n
# a
# m
# e
# d
# _
# a
# s
# s
# i
# g
# n
# e
# e
# "
# :
# {
# "
# t
# e
# m
# p
# _
# p
# a
# t
# e
# n
# t
# _
# f
# i
# r
# s
# t
# n
# a
# m
# e
# d
# _
# a
# s
# s
# i
# g
# n
# e
# e
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# a
# s
# s
# i
# g
# n
# e
# e
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# k
# i
# n
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# u
# s
# p
# a
# t
# e
# n
# t
# c
# i
# t
# a
# t
# i
# o
# n
# "
# :
# {
# "
# u
# s
# p
# a
# t
# e
# n
# t
# c
# i
# t
# a
# t
# i
# o
# n
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# c
# i
# t
# i
# n
# g
# _
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# q
# u
# e
# n
# c
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# i
# t
# e
# d
# _
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# u
# s
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# "
# :
# {
# "
# u
# s
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# p
# a
# t
# e
# n
# t
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# q
# u
# e
# n
# c
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# c
# l
# a
# s
# s
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# u
# b
# c
# l
# a
# s
# s
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# u
# s
# p
# c
# _
# c
# u
# r
# r
# e
# n
# t
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# m
# a
# i
# n
# c
# l
# a
# s
# s
# _
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# p
# a
# t
# e
# n
# t
# _
# y
# e
# a
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# u
# s
# p
# c
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# "
# :
# {
# "
# u
# s
# p
# c
# _
# m
# a
# i
# n
# c
# l
# a
# s
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# p
# a
# t
# e
# n
# t
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# i
# n
# v
# e
# n
# t
# o
# r
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# n
# u
# m
# _
# a
# s
# s
# i
# g
# n
# e
# e
# s
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# r
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# l
# a
# s
# t
# _
# s
# e
# e
# n
# _
# d
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# d
# a
# t
# e
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# s
# _
# a
# c
# t
# i
# v
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# u
# s
# p
# c
# _
# s
# u
# b
# c
# l
# a
# s
# s
# "
# :
# {
# "
# u
# s
# p
# c
# _
# s
# u
# b
# c
# l
# a
# s
# s
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# i
# d
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# p
# a
# r
# i
# s
# o
# n
# _
# s
# t
# a
# t
# e
# I
# A
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# s
# t
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# c
# t
# o
# r
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# a
# s
# s
# i
# S
# u
# b
# C
# o
# u
# n
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# w
# e
# b
# t
# o
# o
# l
# _
# c
# o
# m
# p
# a
# r
# i
# s
# o
# n
# _
# s
# t
# a
# t
# e
# I
# s
# e
# c
# t
# o
# r
# "
# :
# {
# "
# w
# e
# b
# t
# o
# o
# l
# _
# c
# o
# m
# p
# a
# r
# i
# s
# o
# n
# _
# s
# t
# a
# t
# e
# I
# s
# e
# c
# t
# o
# r
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# s
# t
# a
# t
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# t
# r
# u
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# s
# e
# c
# t
# o
# r
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# i
# n
# v
# S
# u
# b
# C
# o
# u
# n
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# w
# e
# b
# t
# o
# o
# l
# _
# c
# o
# m
# p
# a
# r
# i
# s
# o
# n
# _
# w
# i
# p
# o
# A
# "
# :
# {
# "
# w
# e
# b
# t
# o
# o
# l
# _
# c
# o
# m
# p
# a
# r
# i
# s
# o
# n
# _
# w
# i
# p
# o
# A
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# s
# e
# c
# t
# o
# r
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# y
# e
# a
# r
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# f
# i
# e
# l
# d
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# v
# a
# r
# c
# h
# a
# r
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# t
# r
# u
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# ,
# "
# a
# s
# s
# i
# S
# u
# b
# C
# o
# u
# n
# t
# "
# :
# {
# "
# d
# a
# t
# a
# _
# t
# y
# p
# e
# "
# :
# "
# i
# n
# t
# "
# ,
# "
# n
# u
# l
# l
# _
# a
# l
# l
# o
# w
# e
# d
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# c
# a
# t
# e
# g
# o
# r
# y
# "
# :
# f
# a
# l
# s
# e
# ,
# "
# l
# o
# c
# a
# t
# i
# o
# n
# _
# f
# i
# e
# l
# d
# "
# :
# f
# a
# l
# s
# e
# }
# }
# ,
# "
# T
# e
# s
# t
# S
# c
# r
# i
# p
# t
# s
# "
# :
# [
# "
# R
# e
# p
# o
# r
# t
# i
# n
# g
# D
# B
# T
# e
# s
# t
# e
# r
# "
# ]
# }
# }
# ,
# "
# w
# e
# b
# t
# o
# o
# l
# _
# c
# o
# m
# p
# a
# r
# i
# s
# o
# n
# _
# w
# i
# p
# o
# I
# "
# :
# {
# "
# w
# e
# b
# t
# o
# o
# l
# _
# c
# o
# m
# p
# a
# r
# i
# s
# o
# n
# _
# w
# i
# p
# o
# I
# "
# :
# {
# "
# f
# i
# e
# l
# d
# s
# "
# :
# {
# "
# s
# e
# c
# t
# o
# r
# _
# t
# i
# t
# l
# e
# "
# :
# {
# "
# d
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import json
with open("table_config_reporting_db.json", "w") as write_file:
    json.dump(c_set, write_file, indent=4)

# %%
cd Resources
# Out:
# C:\Users\estefanovich\projects\PatentsView-DB\Resources

# %%
os.getcwd()
# Out:
# 'C:\\Users\\estefanovich\\projects\\PatentsView-DB\\Resources'

# %%
list(x.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 list(x.keys())
#
# AttributeError: 'str' object has no attribute 'keys'

# %% [markdown]
# #### START HERE WHEN RE-BUILDING BASE DICTIONARY

# %%
c_set=reduce(lambda a, b: dict(a, **b), x.tolist())

# %%
c_set
# Out:
# {'application': {'fields': {'application_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'assignee': {'fields': {'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lastknown_location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_persistent_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'persistent_assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'assignee_cpc_group': {'fields': {'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'assignee_cpc_subsection': {'fields': {'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'assignee_inventor': {'fields': {'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'assignee_nber_subcategory': {'fields': {'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'assignee_uspc_mainclass': {'fields': {'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'assignee_year': {'fields': {'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'group_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subgroup_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees_group': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors_group': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents_group': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date_group': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date_group': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active_group': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_copy': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_group': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'group_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_group_application_year': {'fields': {'group_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'application_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sample_size': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'average_patent_processing_days': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_group_copy': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_group_patent_year': {'fields': {'group_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'patent_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_subsection': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'subsection_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_subsection_copy': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_current_subsection_patent_year': {'fields': {'subsection_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_group': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_subgroup': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'cpc_subsection': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'examiner': {'fields': {'examiner_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'role': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'persistent_examiner_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'foreignpriority': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'foreign_doc_number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'government_interest': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'gi_statement': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'government_organization': {'fields': {'organization_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_one': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_two': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_three': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor': {'fields': {'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lastknown_location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_persistent_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lastknown_longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'persistent_inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor_coinventor': {'fields': {'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'coinventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor_cpc_group': {'fields': {'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor_cpc_subsection': {'fields': {'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor_nber_subcategory': {'fields': {'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor_rawinventor': {'fields': {'uuid': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor_uspc_mainclass': {'fields': {'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'inventor_year': {'fields': {'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'ipcr': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'section': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'ipc_class': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subclass': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'main_group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'classification_value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'classification_data_source': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'ipc_version_indicator': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'lawyer': {'fields': {'lawyer_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'persistent_lawyer_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'county': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'county_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'persistent_location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location_assignee': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location_cpc_group': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location_cpc_subsection': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location_inventor': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location_nber_subcategory': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location_uspc_mainclass': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'location_year': {'fields': {'location_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'nber': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'category_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subcategory_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'nber_category': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'nber_copy': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'category_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'nber_subcategory': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'nber_subcategory_patent_year': {'fields': {'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'abstract': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'num_claims': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_persistent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_persistent_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_assignee_longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_persistent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_persistent_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'firstnamed_inventor_longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_foreign_documents_cited': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_us_applications_cited': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_us_patents_cited': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_total_documents_cited': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_times_cited_by_us_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'earliest_application_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_processing_days': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'uspc_current_mainclass_average_patent_processing_days': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'cpc_current_group_average_patent_processing_days': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'term_extension': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'detail_desc_length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_assignee': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_contractawardnumber': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'contract_award_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_examiner': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'examiner_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'role': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_govintorg': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'organization_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_inventor': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_inventor_old': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_lawyer': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lawyer_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'patent_lawyer_unique': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lawyer_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'pctdata': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'doc_type': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': True,
#     'location_field': False},
#    'doc_number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    '102_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    '371_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'temp_assignee_lastknown_location': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'persistent_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'temp_assignee_num_inventors': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'temp_assignee_num_patents': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'temp_assignee_years_active': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
# ...
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'temp_patent_firstnamed_inventor': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'persistent_inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'persistent_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'temp_subclass_current_title': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'usapplicationcitation': {'fields': {'citing_patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'cited_application_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspatentcitation': {'fields': {'citing_patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'cited_patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_current': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'mainclass_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_current_copy': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_current_mainclass': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_current_mainclass_application_year': {'fields': {'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'application_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sample_size': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'average_patent_processing_days': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_current_mainclass_copy': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_current_mainclass_patent_year': {'fields': {'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_year': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_mainclass': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_patents': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_inventors': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_assignees': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'first_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'last_seen_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'years_active': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'uspc_subclass': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_countryI': {'fields': {'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_countryIA': {'fields': {'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assiCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_countryIAsector': {'fields': {'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assiSubCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_countryIsector': {'fields': {'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invSubCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_stateA': {'fields': {'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assiCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_stateAsector': {'fields': {'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assiSubCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_stateI': {'fields': {'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_stateIA': {'fields': {'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assiSubCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_stateIsector': {'fields': {'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invSubCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_wipoA': {'fields': {'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'field_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assiSubCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'webtool_comparison_wipoI': {'fields': {'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'year': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'field_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invSubCount': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'wipo': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'field_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']},
#  'wipo_field': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'field_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['ReportingDBTester']}}

# %%
exclusion_list = []
for i in c_set.keys():
    if i == "patent":
        print("skipping patent")
    else:
        print(i,"TABLE =====================")
        temp = 0
        for j in c_set[i]['fields']:
            print(j, "FIELD")
            if j == 'patent_id':
                temp += 1
            else:
                pass
        print(temp)
        if temp == 1:
            pass
        else:
            exclusion_list.append(i)
# Out:
# application TABLE =====================
# id FIELD
# patent_id FIELD
# type FIELD
# number FIELD
# country FIELD
# date FIELD
# id_transformed FIELD
# number_transformed FIELD
# series_code_transformed_from_type FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# assignee TABLE =====================
# id FIELD
# type FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# assignee_disambiguation_mapping TABLE =====================
# uuid FIELD
# assignee_id FIELD
# 0
# botanic TABLE =====================
# uuid FIELD
# patent_id FIELD
# latin_name FIELD
# variety FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# claim TABLE =====================
# uuid FIELD
# patent_id FIELD
# text FIELD
# dependent FIELD
# sequence FIELD
# 1
# country_codes TABLE =====================
# name FIELD
# alpha-2 FIELD
# alpha-3 FIELD
# country-code FIELD
# iso_3166-2 FIELD
# region FIELD
# sub-region FIELD
# intermediate-region FIELD
# region-code FIELD
# sub-region-code FIELD
# intermediate-region-code FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# cpc TABLE =====================
# uuid FIELD
# patent_id FIELD
# section_id FIELD
# subsection_id FIELD
# group_id FIELD
# subgroup_id FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# cpc_current TABLE =====================
# uuid FIELD
# patent_id FIELD
# section_id FIELD
# subsection_id FIELD
# group_id FIELD
# subgroup_id FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# cpc_group TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# cpc_subgroup TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# cpc_subsection TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# disambiguated_assignee_ids TABLE =====================
# assignee_id FIELD
# 0
# disambiguated_inventor_ids TABLE =====================
# inventor_id FIELD
# 0
# disambiguated_location_ids TABLE =====================
# location_id FIELD
# 0
# figures TABLE =====================
# uuid FIELD
# patent_id FIELD
# num_figures FIELD
# num_sheets FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# foreign_priority TABLE =====================
# uuid FIELD
# patent_id FIELD
# sequence FIELD
# kind FIELD
# number FIELD
# date FIELD
# country FIELD
# country_transformed FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# foreigncitation TABLE =====================
# uuid FIELD
# patent_id FIELD
# date FIELD
# number FIELD
# country FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# further_cpc TABLE =====================
# uuid FIELD
# patent_id FIELD
# sequence FIELD
# version FIELD
# section FIELD
# class FIELD
# subclass FIELD
# main_group FIELD
# subgroup FIELD
# symbol_position FIELD
# value FIELD
# action_date FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# government_interest TABLE =====================
# patent_id FIELD
# gi_statement FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# government_organization TABLE =====================
# organization_id FIELD
# name FIELD
# level_one FIELD
# level_two FIELD
# level_three FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# inventor TABLE =====================
# id FIELD
# name_first FIELD
# name_last FIELD
# male_flag FIELD
# attribution_status FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# inventor_disambiguation_mapping TABLE =====================
# uuid FIELD
# inventor_id FIELD
# 0
# inventor_gender TABLE =====================
# id FIELD
# name_first FIELD
# name_last FIELD
# dumale FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# ipcr TABLE =====================
# uuid FIELD
# patent_id FIELD
# classification_level FIELD
# section FIELD
# ipc_class FIELD
# subclass FIELD
# main_group FIELD
# subgroup FIELD
# symbol_position FIELD
# classification_value FIELD
# classification_status FIELD
# classification_data_source FIELD
# action_date FIELD
# ipc_version_indicator FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# lat_longs TABLE =====================
# id FIELD
# lat FIELD
# lon FIELD
# 0
# lawyer TABLE =====================
# id FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# country FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# location TABLE =====================
# id FIELD
# city FIELD
# state FIELD
# country FIELD
# latitude FIELD
# longitude FIELD
# county FIELD
# state_fips FIELD
# county_fips FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# lat_new FIELD
# long_new FIELD
# 0
# location_assignee TABLE =====================
# location_id FIELD
# assignee_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# location_by_lat_long TABLE =====================
# location_id_transformed FIELD
# location_id FIELD
# 0
# location_disambiguation_mapping TABLE =====================
# uuid FIELD
# old_location_id FIELD
# location_id FIELD
# 0
# location_fips TABLE =====================
# id FIELD
# county FIELD
# county_fips FIELD
# state_fips FIELD
# 0
# location_id_lat_long TABLE =====================
# id FIELD
# location_id FIELD
# location_id_transformed FIELD
# 0
# location_inventor TABLE =====================
# inventor_id FIELD
# location_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# location_lat_lon TABLE =====================
# id FIELD
# latitude FIELD
# longitude FIELD
# 0
# main_cpc TABLE =====================
# uuid FIELD
# patent_id FIELD
# sequence FIELD
# version FIELD
# section FIELD
# class FIELD
# subclass FIELD
# main_group FIELD
# subgroup FIELD
# symbol_position FIELD
# value FIELD
# action_date FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# mainclass TABLE =====================
# id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# mainclass_current TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# nber TABLE =====================
# uuid FIELD
# patent_id FIELD
# category_id FIELD
# subcategory_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# nber_category TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# nber_subcategory TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# non_inventor_applicant TABLE =====================
# uuid FIELD
# patent_id FIELD
# rawlocation_id FIELD
# lname FIELD
# fname FIELD
# organization FIELD
# sequence FIELD
# designation FIELD
# applicant_type FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# otherreference TABLE =====================
# uuid FIELD
# patent_id FIELD
# text FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# skipping patent
# patent_assignee TABLE =====================
# patent_id FIELD
# assignee_id FIELD
# sequence FIELD
# location_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_contractawardnumber TABLE =====================
# patent_id FIELD
# contract_award_number FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_govintorg TABLE =====================
# patent_id FIELD
# organization_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_inventor TABLE =====================
# patent_id FIELD
# inventor_id FIELD
# sequence FIELD
# location_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_lawyer TABLE =====================
# patent_id FIELD
# lawyer_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# pct_data TABLE =====================
# uuid FIELD
# patent_id FIELD
# rel_id FIELD
# date FIELD
# 371_date FIELD
# country FIELD
# kind FIELD
# doc_type FIELD
# 102_date FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# persistent_assignee_disambig TABLE =====================
# current_rawassignee_id FIELD
# old_rawassignee_id FIELD
# disamb_assignee_id_20181127 FIELD
# disamb_assignee_id_20190312 FIELD
# disamb_assignee_id_20190820 FIELD
# disamb_assignee_id_20191008 FIELD
# disamb_assignee_id_20191231 FIELD
# disamb_assignee_id_20200331 FIELD
# disamb_assignee_id_20200630 FIELD
# disamb_assignee_id_20200929 FIELD
# disamb_assignee_id_20201229 FIELD
# disamb_assignee_id_20210330 FIELD
# disambig_assignee_id_20210629 FIELD
# disamb_assignee_id_20210930 FIELD
# disamb_assignee_id_20210708 FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# persistent_assignee_disambig_long TABLE =====================
# id FIELD
# uuid FIELD
# database_update FIELD
# assignee_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# persistent_inventor_disambig TABLE =====================
# current_rawinventor_id FIELD
# old_rawinventor_id FIELD
# disamb_inventor_id_20170808 FIELD
# disamb_inventor_id_20171003 FIELD
# disamb_inventor_id_20171226 FIELD
# disamb_inventor_id_20180528 FIELD
# disamb_inventor_id_20181127 FIELD
# disamb_inventor_id_20190312 FIELD
# disamb_inventor_id_20190820 FIELD
# disamb_inventor_id_20191008 FIELD
# disamb_inventor_id_20191231 FIELD
# disamb_inventor_id_20200331 FIELD
# disamb_inventor_id_20200630 FIELD
# disamb_inventor_id_20200929 FIELD
# disamb_inventor_id_20201229 FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# persistent_inventor_disambig_long TABLE =====================
# id FIELD
# uuid FIELD
# database_update FIELD
# inventor_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# rawassignee TABLE =====================
# uuid FIELD
# patent_id FIELD
# assignee_id FIELD
# rawlocation_id FIELD
# type FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawexaminer TABLE =====================
# uuid FIELD
# patent_id FIELD
# name_first FIELD
# name_last FIELD
# role FIELD
# group FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawinventor TABLE =====================
# uuid FIELD
# patent_id FIELD
# inventor_id FIELD
# rawlocation_id FIELD
# name_first FIELD
# name_last FIELD
# sequence FIELD
# rule_47 FIELD
# deceased FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawlawyer TABLE =====================
# uuid FIELD
# lawyer_id FIELD
# patent_id FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# country FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawlocation TABLE =====================
# id FIELD
# location_id FIELD
# city FIELD
# state FIELD
# country FIELD
# country_transformed FIELD
# location_id_transformed FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# location_new_id FIELD
# 0
# rel_app_text TABLE =====================
# uuid FIELD
# patent_id FIELD
# text FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# state_codes TABLE =====================
# State/Possession FIELD
# Abbreviation FIELD
# 0
# subclass TABLE =====================
# id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# subclass_current TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# unique_locations TABLE =====================
# id FIELD
# city FIELD
# state FIELD
# country_transformed FIELD
# lattitude FIELD
# longitude FIELD
# 0
# us_term_of_grant TABLE =====================
# uuid FIELD
# patent_id FIELD
# lapse_of_patent FIELD
# disclaimer_date FIELD
# term_disclaimer FIELD
# term_grant FIELD
# term_extension FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# usapplicationcitation TABLE =====================
# uuid FIELD
# patent_id FIELD
# application_id FIELD
# date FIELD
# name FIELD
# kind FIELD
# number FIELD
# country FIELD
# category FIELD
# sequence FIELD
# application_id_transformed FIELD
# number_transformed FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# uspatentcitation TABLE =====================
# uuid FIELD
# patent_id FIELD
# citation_id FIELD
# date FIELD
# name FIELD
# kind FIELD
# country FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# uspc TABLE =====================
# uuid FIELD
# patent_id FIELD
# mainclass_id FIELD
# subclass_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# uspc_current TABLE =====================
# uuid FIELD
# patent_id FIELD
# mainclass_id FIELD
# subclass_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# usreldoc TABLE =====================
# uuid FIELD
# patent_id FIELD
# doctype FIELD
# relkind FIELD
# reldocno FIELD
# country FIELD
# date FIELD
# status FIELD
# sequence FIELD
# kind FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# wipo TABLE =====================
# patent_id FIELD
# field_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# wipo_field TABLE =====================
# id FIELD
# sector_title FIELD
# field_title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0

# %%
exclusion_list
# Out:
# ['assignee',
#  'assignee_disambiguation_mapping',
#  'country_codes',
#  'cpc_group',
#  'cpc_subgroup',
#  'cpc_subsection',
#  'disambiguated_assignee_ids',
#  'disambiguated_inventor_ids',
#  'disambiguated_location_ids',
#  'government_organization',
#  'inventor',
#  'inventor_disambiguation_mapping',
#  'inventor_gender',
#  'lat_longs',
#  'lawyer',
#  'location',
#  'location_assignee',
#  'location_by_lat_long',
#  'location_disambiguation_mapping',
#  'location_fips',
#  'location_id_lat_long',
#  'location_inventor',
#  'location_lat_lon',
#  'mainclass',
#  'mainclass_current',
#  'nber_category',
#  'nber_subcategory',
#  'persistent_assignee_disambig',
#  'persistent_assignee_disambig_long',
#  'persistent_inventor_disambig',
#  'persistent_inventor_disambig_long',
#  'rawlocation',
#  'state_codes',
#  'subclass',
#  'subclass_current',
#  'unique_locations',
#  'wipo_field']

# %% [markdown]
# ## USING THE CURRENT JSON TO DETERMINE WHICH TABLES ARE NEEDED

# %% [markdown]
# ## ADDING MISSING TABLES

# %%
# c_set.keys()

# %%
# missing_tables = dict((k, c_set[k]) for k in ('cpc'))

# %%
# legacy_json.update(missing_tables)

# %%
# Sorting alphabetically 
# import collections
# legacy_json = collections.OrderedDict(sorted(legacy_json.items()))

# %%
# legacy_json.keys()

# %%
# Adding location field
# for i in legacy_json.keys():
#     for j in legacy_json[i]['fields']:
#         location_field = False
#         # Only using country for now because we just on country code later for verification
#         if j in ['country','country_transformed']:
#             location_field = True
#         legacy_json[i]['fields'][j].update({'location_field': location_field})

# %% [markdown]
# ## ADD IN RELATED ENTITIES FOR THE PATENT TABLE

# %%
# Add in all entities related to PATENTS

# %%
foreign_tables = []
for i in c_set.keys():
#     print(i)
    if i != 'patent':
        for j in c_set[i]['fields']:
    #         print("=====", j)
            if j == 'patent_id':
                foreign_tables.append(['patent', 'id', i, 'patent_id'])

# %%
related_entities_lookup1 = pd.DataFrame(list(foreign_tables), columns=['main_table','main_table_id','related_table','related_table_id'])

# %%
related_entities_lookup1
# Out:
#    main_table main_table_id               related_table related_table_id
# 0      patent            id                 application        patent_id
# 1      patent            id                     botanic        patent_id
# 2      patent            id                       claim        patent_id
# 3      patent            id                         cpc        patent_id
# 4      patent            id                 cpc_current        patent_id
# 5      patent            id                     figures        patent_id
# 6      patent            id            foreign_priority        patent_id
# 7      patent            id             foreigncitation        patent_id
# 8      patent            id                 further_cpc        patent_id
# 9      patent            id         government_interest        patent_id
# 10     patent            id                        ipcr        patent_id
# 11     patent            id                    main_cpc        patent_id
# 12     patent            id                        nber        patent_id
# 13     patent            id      non_inventor_applicant        patent_id
# 14     patent            id              otherreference        patent_id
# 15     patent            id             patent_assignee        patent_id
# 16     patent            id  patent_contractawardnumber        patent_id
# 17     patent            id            patent_govintorg        patent_id
# 18     patent            id             patent_inventor        patent_id
# 19     patent            id               patent_lawyer        patent_id
# 20     patent            id                    pct_data        patent_id
# 21     patent            id                 rawassignee        patent_id
# 22     patent            id                 rawexaminer        patent_id
# 23     patent            id                 rawinventor        patent_id
# 24     patent            id                   rawlawyer        patent_id
# 25     patent            id                rel_app_text        patent_id
# 26     patent            id            us_term_of_grant        patent_id
# 27     patent            id       usapplicationcitation        patent_id
# 28     patent            id            uspatentcitation        patent_id
# 29     patent            id                        uspc        patent_id
# 30     patent            id                uspc_current        patent_id
# 31     patent            id                    usreldoc        patent_id
# 32     patent            id                        wipo        patent_id

# %%
# Add in other relationships beyond to the central table (patent)
foreign_tables = []
for i in c_set.keys():
#     print(i)
    for j in c_set[i]['fields']:
#         print("=====", j)
        words = j.split("_")
        if 'patent' in words:
            words.remove('patent')
        if j not in ['location_new_id','location_id_transformed','application_id_transformed','old_location_id','old_rawassignee_id','old_rawinventor_id']:
            for w in words:
#                 print("++++++++++++++++++", w)
                if w in c_set.keys():
                    if i != w:
                        if w[:3] == 'raw':
                            related_id = 'uuid'
                        else:
                            related_id = 'id'
                        # i: main_table; j: main_table_id; w: related_table
                        foreign_tables.append([i, j, w, related_id])

# %%
related_entities_lookup2 = pd.DataFrame(list(foreign_tables), columns=['main_table','main_table_id','related_table','related_table_id'])

# %%
related_entities_lookup2.tail(35)
# Out:
#                            main_table                  main_table_id  \
# 27       persistent_assignee_disambig    disamb_assignee_id_20200331
# 28       persistent_assignee_disambig    disamb_assignee_id_20200630
# 29       persistent_assignee_disambig    disamb_assignee_id_20200929
# 30       persistent_assignee_disambig    disamb_assignee_id_20201229
# 31       persistent_assignee_disambig    disamb_assignee_id_20210330
# 32       persistent_assignee_disambig  disambig_assignee_id_20210629
# 33       persistent_assignee_disambig    disamb_assignee_id_20210930
# 34       persistent_assignee_disambig    disamb_assignee_id_20210708
# 35  persistent_assignee_disambig_long                    assignee_id
# 36       persistent_inventor_disambig         current_rawinventor_id
# 37       persistent_inventor_disambig    disamb_inventor_id_20170808
# 38       persistent_inventor_disambig    disamb_inventor_id_20171003
# 39       persistent_inventor_disambig    disamb_inventor_id_20171226
# 40       persistent_inventor_disambig    disamb_inventor_id_20180528
# 41       persistent_inventor_disambig    disamb_inventor_id_20181127
# 42       persistent_inventor_disambig    disamb_inventor_id_20190312
# 43       persistent_inventor_disambig    disamb_inventor_id_20190820
# 44       persistent_inventor_disambig    disamb_inventor_id_20191008
# 45       persistent_inventor_disambig    disamb_inventor_id_20191231
# 46       persistent_inventor_disambig    disamb_inventor_id_20200331
# 47       persistent_inventor_disambig    disamb_inventor_id_20200630
# 48       persistent_inventor_disambig    disamb_inventor_id_20200929
# 49       persistent_inventor_disambig    disamb_inventor_id_20201229
# 50  persistent_inventor_disambig_long                    inventor_id
# 51                        rawassignee                    assignee_id
# 52                        rawassignee                 rawlocation_id
# 53                        rawinventor                    inventor_id
# 54                        rawinventor                 rawlocation_id
# 55                          rawlawyer                      lawyer_id
# 56                        rawlocation                    location_id
# 57              usapplicationcitation                 application_id
# 58                               uspc                   mainclass_id
# 59                               uspc                    subclass_id
# 60                       uspc_current                   mainclass_id
# 61                       uspc_current                    subclass_id
#
#    related_table related_table_id
# 27      assignee               id
# 28      assignee               id
# 29      assignee               id
# 30      assignee               id
# 31      assignee               id
# 32      assignee               id
# 33      assignee               id
# 34      assignee               id
# 35      assignee               id
# 36   rawinventor             uuid
# 37      inventor               id
# 38      inventor               id
# 39      inventor               id
# 40      inventor               id
# 41      inventor               id
# 42      inventor               id
# 43      inventor               id
# 44      inventor               id
# 45      inventor               id
# 46      inventor               id
# 47      inventor               id
# 48      inventor               id
# 49      inventor               id
# 50      inventor               id
# 51      assignee               id
# 52   rawlocation             uuid
# 53      inventor               id
# 54   rawlocation             uuid
# 55        lawyer               id
# 56      location               id
# 57   application               id
# 58     mainclass               id
# 59      subclass               id
# 60     mainclass               id
# 61      subclass               id

# %%
related_entities_lookup2[ (related_entities_lookup2['main_table'] == 'rawlawyer')]
# Out:
#    main_table main_table_id related_table related_table_id
# 55  rawlawyer     lawyer_id        lawyer               id

# %%
# run for persistent_assignee_disambig (related table: assignee) & persistent_inventor_disambig (related table: inventor)
list_to_edit = [['persistent_assignee_disambig','assignee'], ['persistent_inventor_disambig','inventor']]
for a,b in list_to_edit:
    year_columns = []
    cols_in_disamb = list( related_entities_lookup2['main_table_id'][ (related_entities_lookup2['main_table'] == a) & (related_entities_lookup2['related_table'] == b)])
    for i in cols_in_disamb:
        words = i.split("_")
        for w in words:
            if w[0]=='2':
                year_columns.append(w)
    # print(year_columns)
    last_year = max(year_columns)
    for k in cols_in_disamb:
        if last_year in k:
            winner_column = k
            print(winner_column)
    cols_in_disamb.remove(winner_column)
    related_entities_lookup2 = related_entities_lookup2[~related_entities_lookup2['main_table_id'].isin(cols_in_disamb)]
# Out:
# disamb_assignee_id_20210930
# disamb_inventor_id_20201229

# %%
related_entities_lookup2[related_entities_lookup2['main_table']=='persistent_assignee_disambig']
# Out:
#                       main_table                main_table_id related_table  \
# 21  persistent_assignee_disambig       current_rawassignee_id   rawassignee
# 33  persistent_assignee_disambig  disamb_assignee_id_20210930      assignee
#
#    related_table_id
# 21             uuid
# 33               id

# %% [markdown]
# #### DYNAMICALLY FINDING THE RIGHT COLUMN TO USE FOR MAIN_TABLE_ID

# %%
related_entities_lookup = pd.concat([related_entities_lookup1, related_entities_lookup2])

# %%
related_entities_lookup
# Out:
#                main_table   main_table_id related_table related_table_id
# 0                  patent              id   application        patent_id
# 1                  patent              id       botanic        patent_id
# 2                  patent              id         claim        patent_id
# 3                  patent              id           cpc        patent_id
# 4                  patent              id   cpc_current        patent_id
# ..                    ...             ...           ...              ...
# 57  usapplicationcitation  application_id   application               id
# 58                   uspc    mainclass_id     mainclass               id
# 59                   uspc     subclass_id      subclass               id
# 60           uspc_current    mainclass_id     mainclass               id
# 61           uspc_current     subclass_id      subclass               id
#
# [71 rows x 4 columns]

# %%
related_entities_lookup[related_entities_lookup['main_table']=='location_disambiguation_mapping']
# Out:
#                          main_table main_table_id related_table  \
# 10  location_disambiguation_mapping   location_id      location
#
#    related_table_id
# 10               id

# %%
# ADDING IN RELATIONAL ENTITIES 
for i in c_set.keys():
    if i in list(related_entities_lookup["main_table"]):
        related_tables = list(related_entities_lookup["related_table"][related_entities_lookup["main_table"]==i])
        dict_list = []
        for z in related_tables:
            ids = list(related_entities_lookup["main_table_id"][ (related_entities_lookup["main_table"]==i) & (related_entities_lookup["related_table"]==z)])
            for each_id in ids:
                table =z
                rel_id = related_entities_lookup["related_table_id"][ (related_entities_lookup["main_table"]==i) & (related_entities_lookup["related_table"]==z)& (related_entities_lookup["main_table_id"]== each_id) ].item()
                temp = {
                    "related_table": table,
                    "main_table_id": each_id,
                    "related_table_id": rel_id
                    }
                dict_list.append(temp)
        c_set[i]['related_entities']=dict_list

# %% [markdown]
# ## CREATE FLAG FOR EACH TABLE ON WHICH TESTS IT RUNS

# %%
test_script_list = []
for i in c_set.keys():
    if i in MergeTestWeekly.keys():
        test_script_list.append("MergeTestWeekly")
    if i in UploadTest.keys():
        test_script_list.append("UploadTest")
    if i in MergeTestQuarterly.keys():
        test_script_list.append("MergeTestQuarterly")
        
    c_set[i]['TestScripts'] = test_script_list
    if i == 'botanic':
        c_set[i]["custom_float_condition"] = "p.type='plant'"
    if i in ['cpc','cpc_current']:
        c_set[i]["custom_float_condition"] = "p.type='design'"
    test_script_list = []

# %%
c_set
# Out:
# {'application': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'series_code_transformed_from_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'assignee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'botanic': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'latin_name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'variety': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly'],
#   'custom_float_condition': "p.type='plant'"},
#  'claim': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'country_codes': {'fields': {'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'alpha-2': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'alpha-3': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'iso_3166-2': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'region': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sub-region': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'intermediate-region': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'region-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sub-region-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'intermediate-region-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': [],
#   'custom_float_condition': "p.type='design'"},
#  'cpc_current': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': [],
#   'custom_float_condition': "p.type='design'"},
#  'cpc_group': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc_subgroup': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc_subsection': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'disambiguated_assignee_ids': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'disambiguated_inventor_ids': {'fields': {'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'disambiguated_location_ids': {'fields': {'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'figures': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_figures': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_sheets': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'foreign_priority': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'foreigncitation': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'further_cpc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'class': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'main_group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'subclass',
#     'main_table_id': 'subclass',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'government_interest': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'gi_statement': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'government_organization': {'fields': {'organization_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_one': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_two': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_three': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'inventor': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'male_flag': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'attribution_status': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'inventor_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'inventor_gender': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dumale': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'ipcr': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'classification_level': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'section': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'ipc_class': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subclass': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'main_group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'classification_value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'classification_status': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'classification_data_source': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'ipc_version_indicator': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'subclass',
#     'main_table_id': 'subclass',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'lat_longs': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lat': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'lawyer': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True}},
#   'TestScripts': []},
#  'location': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'county': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'county_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lat_new': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'long_new': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'location_assignee': {'fields': {'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'},
#    {'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_by_lat_long': {'fields': {'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'old_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_fips': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'county': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'county_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'location_id_lat_long': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_inventor': {'fields': {'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'},
#    {'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_lat_lon': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'main_cpc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'class': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'main_group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'subclass',
#     'main_table_id': 'subclass',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'mainclass': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'mainclass_current': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'nber': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['UploadTest']},
#  'nber_category': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['UploadTest']},
#  'nber_subcategory': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['UploadTest']},
#  'non_inventor_applicant': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lname': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'fname': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'applicant_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'rawlocation',
#     'main_table_id': 'rawlocation_id',
#     'related_table_id': 'uuid'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'otherreference': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'patent': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'abstract': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'num_claims': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'withdrawn': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'application',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'botanic',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'claim',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'cpc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'cpc_current',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'figures',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'foreign_priority',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'foreigncitation',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'further_cpc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'government_interest',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'ipcr',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'main_cpc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'nber',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'non_inventor_applicant',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'otherreference',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_assignee',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_contractawardnumber',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_govintorg',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_inventor',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_lawyer',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'pct_data',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawassignee',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawexaminer',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawinventor',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawlawyer',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rel_app_text',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'us_term_of_grant',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'usapplicationcitation',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'uspatentcitation',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'uspc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'uspc_current',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'usreldoc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'wipo',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'patent_assignee': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'},
#    {'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'patent_contractawardnumber': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'contract_award_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'patent_govintorg': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'organization_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'patent_inventor': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'},
#    {'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'patent_lawyer': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lawyer_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'lawyer',
#     'main_table_id': 'lawyer_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'pct_data': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'rel_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    '371_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'doc_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    '102_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'persistent_assignee_disambig': {'fields': {'current_rawassignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'old_rawassignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20181127': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20190312': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20190820': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20191008': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20191231': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20200331': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20200630': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20200929': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20201229': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20210330': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disambig_assignee_id_20210629': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20210930': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20210708': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'rawassignee',
#     'main_table_id': 'current_rawassignee_id',
#     'related_table_id': 'uuid'},
#    {'related_table': 'assignee',
#     'main_table_id': 'disamb_assignee_id_20210930',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'persistent_assignee_disambig_long': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'database_update': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'persistent_inventor_disambig': {'fields': {'current_rawinventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'old_rawinventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20170808': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20171003': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20171226': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20180528': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20181127': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20190312': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20190820': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20191008': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20191231': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20200331': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20200630': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20200929': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20201229': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'rawinventor',
#     'main_table_id': 'current_rawinventor_id',
#     'related_table_id': 'uuid'},
#    {'related_table': 'inventor',
#     'main_table_id': 'disamb_inventor_id_20201229',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'persistent_inventor_disambig_long': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'database_update': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'rawassignee': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'},
#    {'related_table': 'rawlocation',
#     'main_table_id': 'rawlocation_id',
#     'related_table_id': 'uuid'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rawexaminer': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'role': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'MergeTestQuarterly']},
#  'rawinventor': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rule_47': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'deceased': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'},
#    {'related_table': 'rawlocation',
#     'main_table_id': 'rawlocation_id',
#     'related_table_id': 'uuid'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rawlawyer': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lawyer_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'lawyer',
#     'main_table_id': 'lawyer_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rawlocation': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_new_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rel_app_text': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'state_codes': {'fields': {'State/Possession': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'Abbreviation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'subclass': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'subclass_current': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'unique_locations': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'lattitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'us_term_of_grant': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lapse_of_patent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disclaimer_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'term_disclaimer': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'term_grant': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'term_extension': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'usapplicationcitation': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'application',
#     'main_table_id': 'application_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'uspatentcitation': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'citation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'uspc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'mainclass',
#     'main_table_id': 'mainclass_id',
#     'related_table_id': 'id'},
#    {'related_table': 'subclass',
#     'main_table_id': 'subclass_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'uspc_current': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'mainclass',
#     'main_table_id': 'mainclass_id',
#     'related_table_id': 'id'},
#    {'related_table': 'subclass',
#     'main_table_id': 'subclass_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['UploadTest']},
#  'usreldoc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'doctype': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'relkind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'reldocno': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'status': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'wipo': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'field_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'wipo_field': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'field_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []}}

# %% [markdown]
# #### REMOVE UNIMPORTANT FIELDS

# %%
for i in c_set.keys():
    for j in list(c_set[i]['fields'].keys()):
        if j in ['created_date','updated_date','version_indicator']:
            del c_set[i]['fields'][j]

# %%
a = 'pgpubs_20211012'

# %%
a[:6]
# Out:
# 'pgpubs'

# %%
# 24 items
MergeTest.keys()

# %%
# 27 items
UploadTest.keys()

# %%
UploadTest = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'custom_float_condition': "p.type='plant'",
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     True
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'nber':                   {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subcategory_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        }
                                }
                        },
                'nber_category':          {
                        'fields': {
                                'id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'title': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'nber_subcategory':       {
                        'fields': {
                                'id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'title': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'uspc_current': {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                }

# %%
MergeTestWeekly = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                },
                        'custom_float_condition': "p.type='plant'"
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawexaminer':            {
                        'fields': {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_last':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'role':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'group':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        }
                }

# %%
MergeTestQuarterly = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                },
                        'custom_float_condition': "p.type='plant'"
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawexaminer':            {
                        'fields': {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_last':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'role':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'group':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        }
                }
