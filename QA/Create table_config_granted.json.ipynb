# %%
import os
import pymysql
import datetime

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /Users/bcard/opt/anaconda3/lib/python3.9/site-packages (1.0.2)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/bcard/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
os.environ['PACKAGE_HOME']="/Users/bcard/OneDrive - American Institutes for Research in the Behavioral Sciences/projects/patentsview/PatentsView-DB"

# %%
cd ..
# Out:
# /Users/bcard/Library/CloudStorage/OneDrive-AmericanInstitutesforResearchintheBehavioralSciences/projects/patentsview/PatentsView-DB

# %%
cd OneDrive - American Institutes for Research in the Behavioral Sciences
# Out:
# [Errno 2] No such file or directory: 'OneDrive - American Institutes for Research in the Behavioral Sciences'
# /Users/bcard/Library/CloudStorage/OneDrive-AmericanInstitutesforResearchintheBehavioralSciences/projects/patentsview/PatentsView-DB

# %%
cd projects/patentsview/PatentsView-DB
# Out:
# [Errno 2] No such file or directory: 'projects/patentsview/PatentsView-DB'
# /Users/bcard/Library/CloudStorage/OneDrive-AmericanInstitutesforResearchintheBehavioralSciences/projects/patentsview/PatentsView-DB

# %%
from lib.configuration import get_config, get_connection_string,get_current_config


c=get_config()

# %%
config = get_current_config('granted_patent', **{
        "execution_date": datetime.date(2021, 11, 4)
    })

# %%
connection_string=get_connection_string(config, database='PROD_DB')

# %%
connection_string
# Out:
# 'mysql+pymysql://bcard:oVKUc4A7ofP5S@pv3-ingestmysql.cckzcdkkfzqo.us-east-1.rds.amazonaws.com:3306/patent?charset=utf8mb4'

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine(connection_string)

# %%
import pandas as pd

# %%
columns=pd.read_sql_query(sql="""
select *
from information_schema.COLUMNS
where TABLE_SCHEMA = 'patentsview_exports_pregrant';
""", con=engine)

# %%
columns.groupby('TABLE_NAME').get_group('application')
# Out:
#    TABLE_CATALOG                  TABLE_SCHEMA   TABLE_NAME  \
# 67           def  patentsview_exports_pregrant  application
# 68           def  patentsview_exports_pregrant  application
# 69           def  patentsview_exports_pregrant  application
# 70           def  patentsview_exports_pregrant  application
# 71           def  patentsview_exports_pregrant  application
# 72           def  patentsview_exports_pregrant  application
# 73           def  patentsview_exports_pregrant  application
# 74           def  patentsview_exports_pregrant  application
# 75           def  patentsview_exports_pregrant  application
# 76           def  patentsview_exports_pregrant  application
# 77           def  patentsview_exports_pregrant  application
# 78           def  patentsview_exports_pregrant  application
#
#              COLUMN_NAME  ORDINAL_POSITION COLUMN_DEFAULT IS_NULLABLE  \
# 67       document_number                 1           None          NO
# 68        application_id                 2           NULL         YES
# 69           filing_date                 3           NULL         YES
# 70           patent_type                 4           NULL         YES
# 71           filing_type                 5           NULL         YES
# 72        published_date                 6           NULL         YES
# 73             wipo_kind                 7           NULL         YES
# 74           series_code                 8           NULL         YES
# 75     application_title                 9           NULL         YES
# 76  application_abstract                10           NULL         YES
# 77          rule_47_flag                11           NULL         YES
# 78              filename                12           NULL         YES
#
#      DATA_TYPE  CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 67      bigint                       NaN                     NaN  ...
# 68     varchar                      16.0                    64.0  ...
# 69        date                       NaN                     NaN  ...
# 70     varchar                      30.0                   120.0  ...
# 71     varchar                     128.0                   512.0  ...
# 72        date                       NaN                     NaN  ...
# 73     varchar                       8.0                    32.0  ...
# 74     varchar                      16.0                    64.0  ...
# 75  mediumtext                16777215.0              16777215.0  ...
# 76  mediumtext                16777215.0              16777215.0  ...
# 77     varchar                       8.0                    32.0  ...
# 78     varchar                      16.0                    64.0  ...
#
#     DATETIME_PRECISION  CHARACTER_SET_NAME      COLLATION_NAME   COLUMN_TYPE  \
# 67                None                None                None    bigint(16)
# 68                None             utf8mb4  utf8mb4_unicode_ci   varchar(16)
# 69                None                None                None          date
# 70                None             utf8mb4  utf8mb4_unicode_ci   varchar(30)
# 71                None             utf8mb4  utf8mb4_unicode_ci  varchar(128)
# 72                None                None                None          date
# 73                None             utf8mb4  utf8mb4_unicode_ci    varchar(8)
# 74                None             utf8mb4  utf8mb4_unicode_ci   varchar(16)
# 75                None             utf8mb4  utf8mb4_unicode_ci    mediumtext
# 76                None             utf8mb4  utf8mb4_unicode_ci    mediumtext
# 77                None             utf8mb4  utf8mb4_unicode_ci    varchar(8)
# 78                None             utf8mb4  utf8mb4_unicode_ci   varchar(16)
#
#    COLUMN_KEY EXTRA            PRIVILEGES COLUMN_COMMENT IS_GENERATED  \
# 67                   select,insert,update                       NEVER
# 68                   select,insert,update                       NEVER
# 69                   select,insert,update                       NEVER
# 70                   select,insert,update                       NEVER
# 71                   select,insert,update                       NEVER
# 72                   select,insert,update                       NEVER
# 73                   select,insert,update                       NEVER
# 74                   select,insert,update                       NEVER
# 75                   select,insert,update                       NEVER
# 76                   select,insert,update                       NEVER
# 77                   select,insert,update                       NEVER
# 78                   select,insert,update                       NEVER
#
#    GENERATION_EXPRESSION
# 67                  None
# 68                  None
# 69                  None
# 70                  None
# 71                  None
# 72                  None
# 73                  None
# 74                  None
# 75                  None
# 76                  None
# 77                  None
# 78                  None
#
# [12 rows x 22 columns]

# %%
columns["DATA_TYPE"].unique()
# Out:
# array(['bigint', 'int', 'varchar', 'date', 'mediumtext', 'binary',
#        'double'], dtype=object)

# %%
columns
# Out:
#     TABLE_CATALOG                  TABLE_SCHEMA        TABLE_NAME  \
# 0             def  patentsview_exports_pregrant              ipcr
# 1             def  patentsview_exports_pregrant              ipcr
# 2             def  patentsview_exports_pregrant              ipcr
# 3             def  patentsview_exports_pregrant              ipcr
# 4             def  patentsview_exports_pregrant              ipcr
# ..            ...                           ...               ...
# 130           def  patentsview_exports_pregrant  foreign_priority
# 131           def  patentsview_exports_pregrant  foreign_priority
# 132           def  patentsview_exports_pregrant  foreign_priority
# 133           def  patentsview_exports_pregrant  foreign_priority
# 134           def  patentsview_exports_pregrant  foreign_priority
#
#                  COLUMN_NAME  ORDINAL_POSITION COLUMN_DEFAULT IS_NULLABLE  \
# 0            document_number                 1           None          NO
# 1               ipc_sequence                 2           NULL         YES
# 2       classification_level                 3           NULL         YES
# 3                    section                 4           NULL         YES
# 4                  ipc_class                 5           NULL         YES
# ..                       ...               ...            ...         ...
# 130  priority_claim_sequence                 2              0          NO
# 131      priority_claim_kind                 3           NULL         YES
# 132   foreign_application_id                 4           NULL         YES
# 133              filing_date                 5           NULL         YES
# 134    foreign_country_filed                 6           NULL         YES
#
#     DATA_TYPE  CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 0      bigint                       NaN                     NaN  ...
# 1         int                       NaN                     NaN  ...
# 2     varchar                     256.0                  1024.0  ...
# 3     varchar                     256.0                  1024.0  ...
# 4     varchar                     256.0                  1024.0  ...
# ..        ...                       ...                     ...  ...
# 130    bigint                       NaN                     NaN  ...
# 131   varchar                      20.0                    80.0  ...
# 132   varchar                     256.0                  1024.0  ...
# 133      date                       NaN                     NaN  ...
# 134   varchar                     256.0                  1024.0  ...
#
#      DATETIME_PRECISION  CHARACTER_SET_NAME      COLLATION_NAME   COLUMN_TYPE  \
# 0                  None                None                None    bigint(16)
# 1                  None                None                None       int(11)
# 2                  None             utf8mb4  utf8mb4_unicode_ci  varchar(256)
# 3                  None             utf8mb4  utf8mb4_unicode_ci  varchar(256)
# 4                  None             utf8mb4  utf8mb4_unicode_ci  varchar(256)
# ..                  ...                 ...                 ...           ...
# 130                None                None                None    bigint(21)
# 131                None             utf8mb4  utf8mb4_unicode_ci   varchar(20)
# 132                None             utf8mb4  utf8mb4_unicode_ci  varchar(256)
# 133                None                None                None          date
# 134                None             utf8mb4  utf8mb4_unicode_ci  varchar(256)
#
#     COLUMN_KEY EXTRA            PRIVILEGES COLUMN_COMMENT IS_GENERATED  \
# 0                     select,insert,update                       NEVER
# 1                     select,insert,update                       NEVER
# 2                     select,insert,update                       NEVER
# 3                     select,insert,update                       NEVER
# 4                     select,insert,update                       NEVER
# ..         ...   ...                   ...            ...          ...
# 130                   select,insert,update                       NEVER
# 131                   select,insert,update                       NEVER
# 132                   select,insert,update                       NEVER
# 133                   select,insert,update                       NEVER
# 134                   select,insert,update                       NEVER
#
#     GENERATION_EXPRESSION
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ..                    ...
# 130                  None
# 131                  None
# 132                  None
# 133                  None
# 134                  None
#
# [135 rows x 22 columns]

# %%
# A list of categories pulled from the DataMonitor_categorycount output
# Can program this into the creation of the json file
category_list = ['applicant_type',
'category',
'classification_data_source',
'classification_level',
'classification_status',
# 'country',
# 'country_transformed',
'deceased',
'designation',
'doc_type',
'doctype',
'field_id',
'group',
'group_id',
'ipc_class',
'kind',
'relkind',
'role',
'section',
'section_id',
'state',
'status',
'subclass',
'subgroup',
'subgroup_id',
'symbol_position',
'type']

# %%
category_list
# Out:
# ['applicant_type',
#  'category',
#  'classification_data_source',
#  'classification_level',
#  'classification_status',
#  'deceased',
#  'designation',
#  'doc_type',
#  'doctype',
#  'field_id',
#  'group',
#  'group_id',
#  'ipc_class',
#  'kind',
#  'relkind',
#  'role',
#  'section',
#  'section_id',
#  'state',
#  'status',
#  'subclass',
#  'subgroup',
#  'subgroup_id',
#  'symbol_position',
#  'type']

# %%
for i in category_list:
    if i[:1] >= 'p':
        print(i)
    else:
        continue
# Out:
# relkind
# role
# section
# section_id
# state
# status
# subclass
# subgroup
# subgroup_id
# symbol_position
# type

# %%
def generate_column_setting(column):
    
    data_type = 'varchar'
    if column.DATA_TYPE in ['date', 'timestamp']:
        data_type = 'date'
    if column.DATA_TYPE in ['int', 'bigint', 'smallint', 'float', 'decimal']:
        data_type = 'int'
        
    null_allowed = True
    if column.IS_NULLABLE == 'NO':
        null_allowed = False
        
    location_field = False
    if column.COLUMN_NAME in ['country','country_transformed']:
        location_field = True

    category = False
    if column.COLUMN_NAME in category_list:
        if column.TABLE_NAME == 'foreign_priority':
            if column.COLUMN_NAME =='kind':
                category = False
        elif column.TABLE_NAME in ['further_cpc','main_cpc']:
            category = False
        elif column.COLUMN_NAME == 'section_id' and column.TABLE_NAME != 'cpc':
            category = False
        else:
            category=True
            
    setting = {
        column.COLUMN_NAME: {
            'data_type': data_type,
            'null_allowed': null_allowed,
            'category': category,
            'location_field': location_field
        },
    }
    return setting

# %%
from functools import reduce

# %%
def generate_table_setting(table_group):
    y=table_group.apply(generate_column_setting,axis=1)
    t_set={table_group.name:{"fields":reduce(lambda a, b: dict(a, **b), y.tolist())}}
    return t_set

# %%
x=columns.groupby('TABLE_NAME').apply(func=generate_table_setting)

# %%
x
# Out:
# TABLE_NAME
# applicant_not_disambiguated    {'applicant_not_disambiguated': {'fields': {'d...
# application                    {'application': {'fields': {'document_number':...
# assignee_disambiguated         {'assignee_disambiguated': {'fields': {'docume...
# assignee_not_disambiguated     {'assignee_not_disambiguated': {'fields': {'do...
# cpc_at_issue                   {'cpc_at_issue': {'fields': {'document_number'...
# cpc_current                    {'cpc_current': {'fields': {'document_number':...
# foreign_priority               {'foreign_priority': {'fields': {'document_num...
# govinterest                    {'govinterest': {'fields': {'document_number':...
# govinterest_contracts          {'govinterest_contracts': {'fields': {'documen...
# govinterest_org                {'govinterest_org': {'fields': {'document_numb...
# granted_patent_crosswalk       {'granted_patent_crosswalk': {'fields': {'docu...
# inventor_disambiguated         {'inventor_disambiguated': {'fields': {'docume...
# inventor_not_disambiguated     {'inventor_not_disambiguated': {'fields': {'do...
# ipcr                           {'ipcr': {'fields': {'document_number': {'data...
# location_not_disambiguated     {'location_not_disambiguated': {'fields': {'ra...
# pct_data                       {'pct_data': {'fields': {'document_number': {'...
# rel_app_text                   {'rel_app_text': {'fields': {'document_number'...
# us_rel_doc                     {'us_rel_doc': {'fields': {'document_number': ...
# uspc_at_issue                  {'uspc_at_issue': {'fields': {'document_number...
# wipo                           {'wipo': {'fields': {'document_number': {'data...
# dtype: object

# %%
x["application"]
# Out:
# {'application': {'fields': {'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'application_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filing_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filing_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'published_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'wipo_kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'series_code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_abstract': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rule_47_flag': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}}}}

# %%
my_list = []
for keys in x.keys():
    my_list.append(x[keys])

# %%
len(list(x.keys()))
# Out:
# 20

# %%
super_dict = {}
for k in set(k for d in my_list for k in d):
    super_dict[k] = [d[k] for d in my_list if k in d]

# %%
len(list(super_dict.keys()))
# Out:
# 20

# %%
for i in super_dict.keys():
    for j in super_dict[i]:
            j["TestScripts"] = ["ReportingDBTester"]

# %%
super_dict
# Out:
# {'inventor_not_disambiguated': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'inventor_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'inventor_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'inventor_name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'inventor_name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'deceased_flag': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'rawlocation_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'wipo': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'wipo_field_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'wipo_field_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'wipo_sector_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'wipo_field_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'foreign_priority': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'priority_claim_sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'priority_claim_kind': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'foreign_application_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'filing_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'foreign_country_filed': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'govinterest_org': [{'fields': {'document_number': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'organization_id': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_current': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'cpc_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_section': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_class': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_subclass': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_group': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_version_indicator': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_symbol_position': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_action_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'applicant_not_disambiguated': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'applicant_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'applicant_name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'applicant_name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'applicant_organization': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'applicant_type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'applicant_designation': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'rawlocation_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'uspc_at_issue': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'uspc_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'uspc_mainclass_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'uspc_mainclass_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'uspc_subclass_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'uspc_subclass_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'granted_patent_crosswalk': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'patent_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'application_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'assignee_disambiguated': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'assignee_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_individual_name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_individual_name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_organization': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_type': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'ipcr': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'ipc_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'classification_level': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'section': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'ipc_class': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'subclass': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'main_group': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'subgroup': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'symbol_position': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'classification_value': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'classification_status': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'classification_data_source': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'action_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'ipc_version_indicator': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'assignee_not_disambiguated': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'assignee_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_individual_name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_individual_name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_organization': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'assignee_type': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'rawlocation_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'cpc_at_issue': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'cpc_sequence': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_version_indicator': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_section': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_class': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_subclass': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_group': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_symbol_position': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'cpc_action_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'inventor_disambiguated': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'inventor_sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'inventor_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'inventor_name_first': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'inventor_name_last': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'male_flag': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'attribution_status': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'us_rel_doc': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'related_doc_number': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'published_country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'related_doc_type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'related_doc_kind': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'related_doc_published_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'related_doc_status': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'related_doc_sequence': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'wipo_kind': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'location_not_disambiguated': [{'fields': {'rawlocation_id': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'location_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'city': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'state': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': True,
#      'location_field': False},
#     'country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': True}},
#    'TestScripts': ['ReportingDBTester']}],
#  'rel_app_text': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'rel_app_text': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'govinterest_contracts': [{'fields': {'document_number': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'contract_award_number': {'data_type': 'varchar',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'govinterest': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'gi_statement': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'pct_data': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'published_filed_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'pct_371_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'pct_102_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'filed_country': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'application_kind': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'pct_doc_number': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'pct_doc_type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}],
#  'application': [{'fields': {'document_number': {'data_type': 'int',
#      'null_allowed': False,
#      'category': False,
#      'location_field': False},
#     'application_id': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'filing_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'patent_type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'filing_type': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'published_date': {'data_type': 'date',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'wipo_kind': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'series_code': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'application_title': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'application_abstract': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'rule_47_flag': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False},
#     'filename': {'data_type': 'varchar',
#      'null_allowed': True,
#      'category': False,
#      'location_field': False}},
#    'TestScripts': ['ReportingDBTester']}]}

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x = x.to_json()

# %%
for i in x:
    print(i)
# Out:
# {'application': {'fields': {'application_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'type': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'number': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'assignee': {'fields': {'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'type': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'name_first': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'name_last': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'organization': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'lastknown_location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_state': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'persistent_assignee_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'assignee_cpc_group': {'fields': {'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'assignee_cpc_subsection': {'fields': {'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'subsection_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'assignee_inventor': {'fields': {'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'assignee_nber_subcategory': {'fields': {'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'subcategory_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'assignee_uspc_mainclass': {'fields': {'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'assignee_year': {'fields': {'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'patent_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'section_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subsection_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subsection_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'group_id': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'group_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subgroup_id': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'subgroup_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'category': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees_group': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors_group': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents_group': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date_group': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date_group': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active_group': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_copy': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'section_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subsection_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'group_id': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'subgroup_id': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'category': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_group': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'section_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'group_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_group_application_year': {'fields': {'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'application_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'sample_size': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'average_patent_processing_days': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_group_copy': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'section_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_group_patent_year': {'fields': {'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'patent_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_subsection': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'section_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subsection_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'subsection_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_subsection_copy': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'section_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subsection_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_current_subsection_patent_year': {'fields': {'subsection_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'patent_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_group': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_subgroup': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'cpc_subsection': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'examiner': {'fields': {'examiner_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'name_first': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'name_last': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'role': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'group': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'persistent_examiner_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'foreignpriority': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'foreign_doc_number': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'kind': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'government_interest': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'gi_statement': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'government_organization': {'fields': {'organization_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'name': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'level_one': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'level_two': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'level_three': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor': {'fields': {'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'name_first': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'name_last': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'lastknown_location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_state': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'lastknown_longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'persistent_inventor_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor_coinventor': {'fields': {'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'coinventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor_cpc_group': {'fields': {'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor_cpc_subsection': {'fields': {'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'subsection_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor_nber_subcategory': {'fields': {'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'subcategory_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor_rawinventor': {'fields': {'uuid': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'name_first': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'name_last': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'patent_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'inventor_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor_uspc_mainclass': {'fields': {'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'inventor_year': {'fields': {'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'patent_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'ipcr': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'section': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'ipc_class': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'subclass': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'main_group': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subgroup': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'symbol_position': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'classification_value': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'classification_data_source': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'action_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'ipc_version_indicator': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'lawyer': {'fields': {'lawyer_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'name_first': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'name_last': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'organization': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'persistent_lawyer_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'state': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'county': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'state_fips': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'county_fips': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'persistent_location_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location_assignee': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location_cpc_group': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location_cpc_subsection': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'subsection_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location_inventor': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location_nber_subcategory': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'subcategory_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location_uspc_mainclass': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'location_year': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'nber': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'category_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'category_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subcategory_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subcategory_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'nber_category': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'nber_copy': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'category_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subcategory_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'nber_subcategory': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'nber_subcategory_patent_year': {'fields': {'subcategory_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'patent_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'type': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'number': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'year': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'abstract': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'kind': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'num_claims': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_persistent_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_state': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_assignee_longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_persistent_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_state': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'firstnamed_inventor_longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_foreign_documents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_us_applications_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_us_patents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_total_documents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_times_cited_by_us_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'earliest_application_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'patent_processing_days': {'data_type': ' ...
# {'patent_assignee': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent_contractawardnumber': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'contract_award_number': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent_examiner': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'examiner_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'role': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent_govintorg': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'organization_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent_inventor': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent_lawyer': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'lawyer_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent_lawyer_unique': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lawyer_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'patent_lawyer_unique3': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'lawyer_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'pctdata': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'doc_type': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'kind': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'doc_number': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, '102_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, '371_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_assignee_lastknown_location': {'fields': {'assignee_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'state': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_assignee_num_inventors': {'fields': {'assignee_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_assignee_num_patents': {'fields': {'assignee_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_assignee_years_active': {'fields': {'assignee_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'actual_years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_cpc_current_group_aggregate_counts': {'fields': {'group_id': {'data_type': 'varchar', 'null_allowed': False, 'category': True, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'actual_years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_cpc_current_subsection_aggregate_counts': {'fields': {'subsection_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'actual_years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_cpc_group_title': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_cpc_subgroup_title': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_cpc_subsection_title': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_id_mapping_assignee': {'fields': {'old_assignee_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'new_assignee_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_id_mapping_examiner': {'fields': {'old_examiner_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'new_examiner_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_id_mapping_inventor': {'fields': {'old_inventor_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'new_inventor_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_id_mapping_lawyer': {'fields': {'old_lawyer_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'new_lawyer_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_id_mapping_location': {'fields': {'old_location_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'old_location_id_transformed': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'new_location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_inventor_lastknown_location': {'fields': {'inventor_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'state': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_inventor_num_assignees': {'fields': {'inventor_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_inventor_num_patents': {'fields': {'inventor_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# ...
# {'temp_location_num_assignees': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_location_num_inventors': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_location_num_patents': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_location_patent': {'fields': {'location_id': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_mainclass_current_aggregate_counts': {'fields': {'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'actual_years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_mainclass_current_title': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_nber_subcategory_aggregate_counts': {'fields': {'subcategory_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'actual_years_active': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_num_foreign_documents_cited': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_foreign_documents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_num_times_cited_by_us_patents': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_times_cited_by_us_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_num_us_applications_cited': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_us_applications_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_num_us_patents_cited': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_us_patents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_patent_aggregations': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_foreign_documents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_us_applications_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_us_patents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_total_documents_cited': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_times_cited_by_us_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_patent_date': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_patent_earliest_application_date': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'earliest_application_date': {'data_type': 'date', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_patent_firstnamed_assignee': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'assignee_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'persistent_assignee_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'state': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_patent_firstnamed_inventor': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'inventor_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'persistent_inventor_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'location_id': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'persistent_location_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'city': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'state': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'country': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': True}, 'latitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'longitude': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'temp_subclass_current_title': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'usapplicationcitation': {'fields': {'citing_patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'cited_application_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'name': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'kind': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'category': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspatentcitation': {'fields': {'citing_patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'cited_patent_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'category': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_current': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'mainclass_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subclass_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subclass_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_current_copy': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'subclass_id': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_current_mainclass': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_current_mainclass_application_year': {'fields': {'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'application_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'sample_size': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'average_patent_processing_days': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_current_mainclass_copy': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_current_mainclass_patent_year': {'fields': {'mainclass_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'patent_year': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_mainclass': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_patents': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_inventors': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'num_assignees': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}, 'first_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'last_seen_date': {'data_type': 'date', 'null_allowed': True, 'category': False, 'location_field': False}, 'years_active': {'data_type': 'int', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'uspc_subclass': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'wipo': {'fields': {'patent_id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'field_id': {'data_type': 'varchar', 'null_allowed': True, 'category': True, 'location_field': False}, 'sequence': {'data_type': 'int', 'null_allowed': False, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}
# {'wipo_field': {'fields': {'id': {'data_type': 'varchar', 'null_allowed': False, 'category': False, 'location_field': False}, 'sector_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}, 'field_title': {'data_type': 'varchar', 'null_allowed': True, 'category': False, 'location_field': False}}}, 'TestScripts': 'ReportingDBTester'}

# %%
import json
with open("table_config_reporting_db.json", "w") as write_file:
    json.dump(x, write_file, indent=4)

# %%
pwd
# Out:
# '/Users/bcard/Library/CloudStorage/OneDrive-AmericanInstitutesforResearchintheBehavioralSciences/projects/patentsview/PatentsView-DB'

# %%
list(x.keys())
# Out:
# ['application',
#  'assignee',
#  'assignee_disambiguation_mapping',
#  'botanic',
#  'claim',
#  'country_codes',
#  'cpc',
#  'cpc_current',
#  'cpc_group',
#  'cpc_subgroup',
#  'cpc_subsection',
#  'disambiguated_assignee_ids',
#  'disambiguated_inventor_ids',
#  'disambiguated_location_ids',
#  'figures',
#  'foreign_priority',
#  'foreigncitation',
#  'further_cpc',
#  'government_interest',
#  'government_organization',
#  'inventor',
#  'inventor_disambiguation_mapping',
#  'inventor_gender',
#  'ipcr',
#  'lat_longs',
#  'lawyer',
#  'location',
#  'location_assignee',
#  'location_by_lat_long',
#  'location_disambiguation_mapping',
#  'location_fips',
#  'location_id_lat_long',
#  'location_inventor',
#  'location_lat_lon',
#  'main_cpc',
#  'mainclass',
#  'mainclass_current',
#  'nber',
#  'nber_category',
#  'nber_subcategory',
#  'non_inventor_applicant',
#  'otherreference',
#  'patent',
#  'patent_assignee',
#  'patent_contractawardnumber',
#  'patent_govintorg',
#  'patent_inventor',
#  'patent_lawyer',
#  'pct_data',
#  'persistent_assignee_disambig',
#  'persistent_assignee_disambig_long',
#  'persistent_inventor_disambig',
#  'persistent_inventor_disambig_long',
#  'rawassignee',
#  'rawexaminer',
#  'rawinventor',
#  'rawlawyer',
#  'rawlocation',
#  'rel_app_text',
#  'state_codes',
#  'subclass',
#  'subclass_current',
#  'unique_locations',
#  'us_term_of_grant',
#  'usapplicationcitation',
#  'uspatentcitation',
#  'uspc',
#  'uspc_current',
#  'usreldoc',
#  'wipo',
#  'wipo_field']

# %% [markdown]
# #### START HERE WHEN RE-BUILDING BASE DICTIONARY

# %%
c_set=reduce(lambda a, b: dict(a, **b), x.tolist())

# %%
exclusion_list = []
for i in c_set.keys():
    if i == "patent":
        print("skipping patent")
    else:
        print(i,"TABLE =====================")
        temp = 0
        for j in c_set[i]['fields']:
            print(j, "FIELD")
            if j == 'patent_id':
                temp += 1
            else:
                pass
        print(temp)
        if temp == 1:
            pass
        else:
            exclusion_list.append(i)
# Out:
# application TABLE =====================
# id FIELD
# patent_id FIELD
# type FIELD
# number FIELD
# country FIELD
# date FIELD
# id_transformed FIELD
# number_transformed FIELD
# series_code_transformed_from_type FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# assignee TABLE =====================
# id FIELD
# type FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# assignee_disambiguation_mapping TABLE =====================
# uuid FIELD
# assignee_id FIELD
# 0
# botanic TABLE =====================
# uuid FIELD
# patent_id FIELD
# latin_name FIELD
# variety FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# claim TABLE =====================
# uuid FIELD
# patent_id FIELD
# text FIELD
# dependent FIELD
# sequence FIELD
# 1
# country_codes TABLE =====================
# name FIELD
# alpha-2 FIELD
# alpha-3 FIELD
# country-code FIELD
# iso_3166-2 FIELD
# region FIELD
# sub-region FIELD
# intermediate-region FIELD
# region-code FIELD
# sub-region-code FIELD
# intermediate-region-code FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# cpc TABLE =====================
# uuid FIELD
# patent_id FIELD
# section_id FIELD
# subsection_id FIELD
# group_id FIELD
# subgroup_id FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# cpc_current TABLE =====================
# uuid FIELD
# patent_id FIELD
# section_id FIELD
# subsection_id FIELD
# group_id FIELD
# subgroup_id FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# cpc_group TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# cpc_subgroup TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# cpc_subsection TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# disambiguated_assignee_ids TABLE =====================
# assignee_id FIELD
# 0
# disambiguated_inventor_ids TABLE =====================
# inventor_id FIELD
# 0
# disambiguated_location_ids TABLE =====================
# location_id FIELD
# 0
# figures TABLE =====================
# uuid FIELD
# patent_id FIELD
# num_figures FIELD
# num_sheets FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# foreign_priority TABLE =====================
# uuid FIELD
# patent_id FIELD
# sequence FIELD
# kind FIELD
# number FIELD
# date FIELD
# country FIELD
# country_transformed FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# foreigncitation TABLE =====================
# uuid FIELD
# patent_id FIELD
# date FIELD
# number FIELD
# country FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# further_cpc TABLE =====================
# uuid FIELD
# patent_id FIELD
# sequence FIELD
# version FIELD
# section FIELD
# class FIELD
# subclass FIELD
# main_group FIELD
# subgroup FIELD
# symbol_position FIELD
# value FIELD
# action_date FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# government_interest TABLE =====================
# patent_id FIELD
# gi_statement FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# government_organization TABLE =====================
# organization_id FIELD
# name FIELD
# level_one FIELD
# level_two FIELD
# level_three FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# inventor TABLE =====================
# id FIELD
# name_first FIELD
# name_last FIELD
# male_flag FIELD
# attribution_status FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# inventor_disambiguation_mapping TABLE =====================
# uuid FIELD
# inventor_id FIELD
# 0
# inventor_gender TABLE =====================
# id FIELD
# name_first FIELD
# name_last FIELD
# dumale FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# ipcr TABLE =====================
# uuid FIELD
# patent_id FIELD
# classification_level FIELD
# section FIELD
# ipc_class FIELD
# subclass FIELD
# main_group FIELD
# subgroup FIELD
# symbol_position FIELD
# classification_value FIELD
# classification_status FIELD
# classification_data_source FIELD
# action_date FIELD
# ipc_version_indicator FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# lat_longs TABLE =====================
# id FIELD
# lat FIELD
# lon FIELD
# 0
# lawyer TABLE =====================
# id FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# country FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# location TABLE =====================
# id FIELD
# city FIELD
# state FIELD
# country FIELD
# latitude FIELD
# longitude FIELD
# county FIELD
# state_fips FIELD
# county_fips FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# lat_new FIELD
# long_new FIELD
# 0
# location_assignee TABLE =====================
# location_id FIELD
# assignee_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# location_by_lat_long TABLE =====================
# location_id_transformed FIELD
# location_id FIELD
# 0
# location_disambiguation_mapping TABLE =====================
# uuid FIELD
# old_location_id FIELD
# location_id FIELD
# 0
# location_fips TABLE =====================
# id FIELD
# county FIELD
# county_fips FIELD
# state_fips FIELD
# 0
# location_id_lat_long TABLE =====================
# id FIELD
# location_id FIELD
# location_id_transformed FIELD
# 0
# location_inventor TABLE =====================
# inventor_id FIELD
# location_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# location_lat_lon TABLE =====================
# id FIELD
# latitude FIELD
# longitude FIELD
# 0
# main_cpc TABLE =====================
# uuid FIELD
# patent_id FIELD
# sequence FIELD
# version FIELD
# section FIELD
# class FIELD
# subclass FIELD
# main_group FIELD
# subgroup FIELD
# symbol_position FIELD
# value FIELD
# action_date FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# mainclass TABLE =====================
# id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# mainclass_current TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# nber TABLE =====================
# uuid FIELD
# patent_id FIELD
# category_id FIELD
# subcategory_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# nber_category TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# nber_subcategory TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# non_inventor_applicant TABLE =====================
# uuid FIELD
# patent_id FIELD
# rawlocation_id FIELD
# lname FIELD
# fname FIELD
# organization FIELD
# sequence FIELD
# designation FIELD
# applicant_type FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# otherreference TABLE =====================
# uuid FIELD
# patent_id FIELD
# text FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# skipping patent
# patent_assignee TABLE =====================
# patent_id FIELD
# assignee_id FIELD
# sequence FIELD
# location_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_contractawardnumber TABLE =====================
# patent_id FIELD
# contract_award_number FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_govintorg TABLE =====================
# patent_id FIELD
# organization_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_inventor TABLE =====================
# patent_id FIELD
# inventor_id FIELD
# sequence FIELD
# location_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# patent_lawyer TABLE =====================
# patent_id FIELD
# lawyer_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# pct_data TABLE =====================
# uuid FIELD
# patent_id FIELD
# rel_id FIELD
# date FIELD
# 371_date FIELD
# country FIELD
# kind FIELD
# doc_type FIELD
# 102_date FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# persistent_assignee_disambig TABLE =====================
# current_rawassignee_id FIELD
# old_rawassignee_id FIELD
# disamb_assignee_id_20181127 FIELD
# disamb_assignee_id_20190312 FIELD
# disamb_assignee_id_20190820 FIELD
# disamb_assignee_id_20191008 FIELD
# disamb_assignee_id_20191231 FIELD
# disamb_assignee_id_20200331 FIELD
# disamb_assignee_id_20200630 FIELD
# disamb_assignee_id_20200929 FIELD
# disamb_assignee_id_20201229 FIELD
# disamb_assignee_id_20210330 FIELD
# disambig_assignee_id_20210629 FIELD
# disamb_assignee_id_20210930 FIELD
# disamb_assignee_id_20210708 FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# persistent_assignee_disambig_long TABLE =====================
# id FIELD
# uuid FIELD
# database_update FIELD
# assignee_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# persistent_inventor_disambig TABLE =====================
# current_rawinventor_id FIELD
# old_rawinventor_id FIELD
# disamb_inventor_id_20170808 FIELD
# disamb_inventor_id_20171003 FIELD
# disamb_inventor_id_20171226 FIELD
# disamb_inventor_id_20180528 FIELD
# disamb_inventor_id_20181127 FIELD
# disamb_inventor_id_20190312 FIELD
# disamb_inventor_id_20190820 FIELD
# disamb_inventor_id_20191008 FIELD
# disamb_inventor_id_20191231 FIELD
# disamb_inventor_id_20200331 FIELD
# disamb_inventor_id_20200630 FIELD
# disamb_inventor_id_20200929 FIELD
# disamb_inventor_id_20201229 FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# persistent_inventor_disambig_long TABLE =====================
# id FIELD
# uuid FIELD
# database_update FIELD
# inventor_id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# rawassignee TABLE =====================
# uuid FIELD
# patent_id FIELD
# assignee_id FIELD
# rawlocation_id FIELD
# type FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawexaminer TABLE =====================
# uuid FIELD
# patent_id FIELD
# name_first FIELD
# name_last FIELD
# role FIELD
# group FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawinventor TABLE =====================
# uuid FIELD
# patent_id FIELD
# inventor_id FIELD
# rawlocation_id FIELD
# name_first FIELD
# name_last FIELD
# sequence FIELD
# rule_47 FIELD
# deceased FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawlawyer TABLE =====================
# uuid FIELD
# lawyer_id FIELD
# patent_id FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# country FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# rawlocation TABLE =====================
# id FIELD
# location_id FIELD
# city FIELD
# state FIELD
# country FIELD
# country_transformed FIELD
# location_id_transformed FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# location_new_id FIELD
# 0
# rel_app_text TABLE =====================
# uuid FIELD
# patent_id FIELD
# text FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# state_codes TABLE =====================
# State/Possession FIELD
# Abbreviation FIELD
# 0
# subclass TABLE =====================
# id FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# subclass_current TABLE =====================
# id FIELD
# title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# unique_locations TABLE =====================
# id FIELD
# city FIELD
# state FIELD
# country_transformed FIELD
# lattitude FIELD
# longitude FIELD
# 0
# us_term_of_grant TABLE =====================
# uuid FIELD
# patent_id FIELD
# lapse_of_patent FIELD
# disclaimer_date FIELD
# term_disclaimer FIELD
# term_grant FIELD
# term_extension FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# usapplicationcitation TABLE =====================
# uuid FIELD
# patent_id FIELD
# application_id FIELD
# date FIELD
# name FIELD
# kind FIELD
# number FIELD
# country FIELD
# category FIELD
# sequence FIELD
# application_id_transformed FIELD
# number_transformed FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# uspatentcitation TABLE =====================
# uuid FIELD
# patent_id FIELD
# citation_id FIELD
# date FIELD
# name FIELD
# kind FIELD
# country FIELD
# category FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# uspc TABLE =====================
# uuid FIELD
# patent_id FIELD
# mainclass_id FIELD
# subclass_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# uspc_current TABLE =====================
# uuid FIELD
# patent_id FIELD
# mainclass_id FIELD
# subclass_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# usreldoc TABLE =====================
# uuid FIELD
# patent_id FIELD
# doctype FIELD
# relkind FIELD
# reldocno FIELD
# country FIELD
# date FIELD
# status FIELD
# sequence FIELD
# kind FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# wipo TABLE =====================
# patent_id FIELD
# field_id FIELD
# sequence FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# wipo_field TABLE =====================
# id FIELD
# sector_title FIELD
# field_title FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0

# %%
exclusion_list
# Out:
# ['assignee',
#  'assignee_disambiguation_mapping',
#  'country_codes',
#  'cpc_group',
#  'cpc_subgroup',
#  'cpc_subsection',
#  'disambiguated_assignee_ids',
#  'disambiguated_inventor_ids',
#  'disambiguated_location_ids',
#  'government_organization',
#  'inventor',
#  'inventor_disambiguation_mapping',
#  'inventor_gender',
#  'lat_longs',
#  'lawyer',
#  'location',
#  'location_assignee',
#  'location_by_lat_long',
#  'location_disambiguation_mapping',
#  'location_fips',
#  'location_id_lat_long',
#  'location_inventor',
#  'location_lat_lon',
#  'mainclass',
#  'mainclass_current',
#  'nber_category',
#  'nber_subcategory',
#  'persistent_assignee_disambig',
#  'persistent_assignee_disambig_long',
#  'persistent_inventor_disambig',
#  'persistent_inventor_disambig_long',
#  'rawlocation',
#  'state_codes',
#  'subclass',
#  'subclass_current',
#  'unique_locations',
#  'wipo_field']

# %% [markdown]
# ## USING THE CURRENT JSON TO DETERMINE WHICH TABLES ARE NEEDED

# %% [markdown]
# ## ADDING MISSING TABLES

# %%
# c_set.keys()

# %%
# missing_tables = dict((k, c_set[k]) for k in ('cpc'))

# %%
# legacy_json.update(missing_tables)

# %%
# Sorting alphabetically 
# import collections
# legacy_json = collections.OrderedDict(sorted(legacy_json.items()))

# %%
# legacy_json.keys()

# %%
# Adding location field
# for i in legacy_json.keys():
#     for j in legacy_json[i]['fields']:
#         location_field = False
#         # Only using country for now because we just on country code later for verification
#         if j in ['country','country_transformed']:
#             location_field = True
#         legacy_json[i]['fields'][j].update({'location_field': location_field})

# %% [markdown]
# ## ADD IN RELATED ENTITIES FOR THE PATENT TABLE

# %%
# Add in all entities related to PATENTS

# %%
foreign_tables = []
for i in c_set.keys():
#     print(i)
    if i != 'patent':
        for j in c_set[i]['fields']:
    #         print("=====", j)
            if j == 'patent_id':
                foreign_tables.append(['patent', 'id', i, 'patent_id'])

# %%
related_entities_lookup1 = pd.DataFrame(list(foreign_tables), columns=['main_table','main_table_id','related_table','related_table_id'])

# %%
related_entities_lookup1
# Out:
#    main_table main_table_id               related_table related_table_id
# 0      patent            id                 application        patent_id
# 1      patent            id                     botanic        patent_id
# 2      patent            id                       claim        patent_id
# 3      patent            id                         cpc        patent_id
# 4      patent            id                 cpc_current        patent_id
# 5      patent            id                     figures        patent_id
# 6      patent            id            foreign_priority        patent_id
# 7      patent            id             foreigncitation        patent_id
# 8      patent            id                 further_cpc        patent_id
# 9      patent            id         government_interest        patent_id
# 10     patent            id                        ipcr        patent_id
# 11     patent            id                    main_cpc        patent_id
# 12     patent            id                        nber        patent_id
# 13     patent            id      non_inventor_applicant        patent_id
# 14     patent            id              otherreference        patent_id
# 15     patent            id             patent_assignee        patent_id
# 16     patent            id  patent_contractawardnumber        patent_id
# 17     patent            id            patent_govintorg        patent_id
# 18     patent            id             patent_inventor        patent_id
# 19     patent            id               patent_lawyer        patent_id
# 20     patent            id                    pct_data        patent_id
# 21     patent            id                 rawassignee        patent_id
# 22     patent            id                 rawexaminer        patent_id
# 23     patent            id                 rawinventor        patent_id
# 24     patent            id                   rawlawyer        patent_id
# 25     patent            id                rel_app_text        patent_id
# 26     patent            id            us_term_of_grant        patent_id
# 27     patent            id       usapplicationcitation        patent_id
# 28     patent            id            uspatentcitation        patent_id
# 29     patent            id                        uspc        patent_id
# 30     patent            id                uspc_current        patent_id
# 31     patent            id                    usreldoc        patent_id
# 32     patent            id                        wipo        patent_id

# %%
# Add in other relationships beyond to the central table (patent)
foreign_tables = []
for i in c_set.keys():
#     print(i)
    for j in c_set[i]['fields']:
#         print("=====", j)
        words = j.split("_")
        if 'patent' in words:
            words.remove('patent')
        if j not in ['location_new_id','location_id_transformed','application_id_transformed','old_location_id','old_rawassignee_id','old_rawinventor_id']:
            for w in words:
#                 print("++++++++++++++++++", w)
                if w in c_set.keys():
                    if i != w:
                        if w[:3] == 'raw':
                            related_id = 'uuid'
                        else:
                            related_id = 'id'
                        # i: main_table; j: main_table_id; w: related_table
                        foreign_tables.append([i, j, w, related_id])

# %%
related_entities_lookup2 = pd.DataFrame(list(foreign_tables), columns=['main_table','main_table_id','related_table','related_table_id'])

# %%
related_entities_lookup2.tail(35)
# Out:
#                            main_table                  main_table_id  \
# 27       persistent_assignee_disambig    disamb_assignee_id_20200331
# 28       persistent_assignee_disambig    disamb_assignee_id_20200630
# 29       persistent_assignee_disambig    disamb_assignee_id_20200929
# 30       persistent_assignee_disambig    disamb_assignee_id_20201229
# 31       persistent_assignee_disambig    disamb_assignee_id_20210330
# 32       persistent_assignee_disambig  disambig_assignee_id_20210629
# 33       persistent_assignee_disambig    disamb_assignee_id_20210930
# 34       persistent_assignee_disambig    disamb_assignee_id_20210708
# 35  persistent_assignee_disambig_long                    assignee_id
# 36       persistent_inventor_disambig         current_rawinventor_id
# 37       persistent_inventor_disambig    disamb_inventor_id_20170808
# 38       persistent_inventor_disambig    disamb_inventor_id_20171003
# 39       persistent_inventor_disambig    disamb_inventor_id_20171226
# 40       persistent_inventor_disambig    disamb_inventor_id_20180528
# 41       persistent_inventor_disambig    disamb_inventor_id_20181127
# 42       persistent_inventor_disambig    disamb_inventor_id_20190312
# 43       persistent_inventor_disambig    disamb_inventor_id_20190820
# 44       persistent_inventor_disambig    disamb_inventor_id_20191008
# 45       persistent_inventor_disambig    disamb_inventor_id_20191231
# 46       persistent_inventor_disambig    disamb_inventor_id_20200331
# 47       persistent_inventor_disambig    disamb_inventor_id_20200630
# 48       persistent_inventor_disambig    disamb_inventor_id_20200929
# 49       persistent_inventor_disambig    disamb_inventor_id_20201229
# 50  persistent_inventor_disambig_long                    inventor_id
# 51                        rawassignee                    assignee_id
# 52                        rawassignee                 rawlocation_id
# 53                        rawinventor                    inventor_id
# 54                        rawinventor                 rawlocation_id
# 55                          rawlawyer                      lawyer_id
# 56                        rawlocation                    location_id
# 57              usapplicationcitation                 application_id
# 58                               uspc                   mainclass_id
# 59                               uspc                    subclass_id
# 60                       uspc_current                   mainclass_id
# 61                       uspc_current                    subclass_id
#
#    related_table related_table_id
# 27      assignee               id
# 28      assignee               id
# 29      assignee               id
# 30      assignee               id
# 31      assignee               id
# 32      assignee               id
# 33      assignee               id
# 34      assignee               id
# 35      assignee               id
# 36   rawinventor             uuid
# 37      inventor               id
# 38      inventor               id
# 39      inventor               id
# 40      inventor               id
# 41      inventor               id
# 42      inventor               id
# 43      inventor               id
# 44      inventor               id
# 45      inventor               id
# 46      inventor               id
# 47      inventor               id
# 48      inventor               id
# 49      inventor               id
# 50      inventor               id
# 51      assignee               id
# 52   rawlocation             uuid
# 53      inventor               id
# 54   rawlocation             uuid
# 55        lawyer               id
# 56      location               id
# 57   application               id
# 58     mainclass               id
# 59      subclass               id
# 60     mainclass               id
# 61      subclass               id

# %%
related_entities_lookup2[ (related_entities_lookup2['main_table'] == 'rawlawyer')]
# Out:
#    main_table main_table_id related_table related_table_id
# 55  rawlawyer     lawyer_id        lawyer               id

# %%
# run for persistent_assignee_disambig (related table: assignee) & persistent_inventor_disambig (related table: inventor)
list_to_edit = [['persistent_assignee_disambig','assignee'], ['persistent_inventor_disambig','inventor']]
for a,b in list_to_edit:
    year_columns = []
    cols_in_disamb = list( related_entities_lookup2['main_table_id'][ (related_entities_lookup2['main_table'] == a) & (related_entities_lookup2['related_table'] == b)])
    for i in cols_in_disamb:
        words = i.split("_")
        for w in words:
            if w[0]=='2':
                year_columns.append(w)
    # print(year_columns)
    last_year = max(year_columns)
    for k in cols_in_disamb:
        if last_year in k:
            winner_column = k
            print(winner_column)
    cols_in_disamb.remove(winner_column)
    related_entities_lookup2 = related_entities_lookup2[~related_entities_lookup2['main_table_id'].isin(cols_in_disamb)]
# Out:
# disamb_assignee_id_20210930
# disamb_inventor_id_20201229

# %%
related_entities_lookup2[related_entities_lookup2['main_table']=='persistent_assignee_disambig']
# Out:
#                       main_table                main_table_id related_table  \
# 21  persistent_assignee_disambig       current_rawassignee_id   rawassignee
# 33  persistent_assignee_disambig  disamb_assignee_id_20210930      assignee
#
#    related_table_id
# 21             uuid
# 33               id

# %% [markdown]
# #### DYNAMICALLY FINDING THE RIGHT COLUMN TO USE FOR MAIN_TABLE_ID

# %%
related_entities_lookup = pd.concat([related_entities_lookup1, related_entities_lookup2])

# %%
related_entities_lookup
# Out:
#                main_table   main_table_id related_table related_table_id
# 0                  patent              id   application        patent_id
# 1                  patent              id       botanic        patent_id
# 2                  patent              id         claim        patent_id
# 3                  patent              id           cpc        patent_id
# 4                  patent              id   cpc_current        patent_id
# ..                    ...             ...           ...              ...
# 57  usapplicationcitation  application_id   application               id
# 58                   uspc    mainclass_id     mainclass               id
# 59                   uspc     subclass_id      subclass               id
# 60           uspc_current    mainclass_id     mainclass               id
# 61           uspc_current     subclass_id      subclass               id
#
# [71 rows x 4 columns]

# %%
related_entities_lookup[related_entities_lookup['main_table']=='location_disambiguation_mapping']
# Out:
#                          main_table main_table_id related_table  \
# 10  location_disambiguation_mapping   location_id      location
#
#    related_table_id
# 10               id

# %%
# ADDING IN RELATIONAL ENTITIES 
for i in c_set.keys():
    if i in list(related_entities_lookup["main_table"]):
        related_tables = list(related_entities_lookup["related_table"][related_entities_lookup["main_table"]==i])
        dict_list = []
        for z in related_tables:
            ids = list(related_entities_lookup["main_table_id"][ (related_entities_lookup["main_table"]==i) & (related_entities_lookup["related_table"]==z)])
            for each_id in ids:
                table =z
                rel_id = related_entities_lookup["related_table_id"][ (related_entities_lookup["main_table"]==i) & (related_entities_lookup["related_table"]==z)& (related_entities_lookup["main_table_id"]== each_id) ].item()
                temp = {
                    "related_table": table,
                    "main_table_id": each_id,
                    "related_table_id": rel_id
                    }
                dict_list.append(temp)
        c_set[i]['related_entities']=dict_list

# %% [markdown]
# ## CREATE FLAG FOR EACH TABLE ON WHICH TESTS IT RUNS

# %%
test_script_list = []
for i in c_set.keys():
    if i in MergeTestWeekly.keys():
        test_script_list.append("MergeTestWeekly")
    if i in UploadTest.keys():
        test_script_list.append("UploadTest")
    if i in MergeTestQuarterly.keys():
        test_script_list.append("MergeTestQuarterly")
        
    c_set[i]['TestScripts'] = test_script_list
    if i == 'botanic':
        c_set[i]["custom_float_condition"] = "p.type='plant'"
    if i in ['cpc','cpc_current']:
        c_set[i]["custom_float_condition"] = "p.type='design'"
    test_script_list = []

# %%
c_set
# Out:
# {'application': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'series_code_transformed_from_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'assignee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'botanic': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'latin_name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'variety': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly'],
#   'custom_float_condition': "p.type='plant'"},
#  'claim': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'country_codes': {'fields': {'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'alpha-2': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'alpha-3': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'iso_3166-2': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'region': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sub-region': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'intermediate-region': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'region-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sub-region-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'intermediate-region-code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': [],
#   'custom_float_condition': "p.type='design'"},
#  'cpc_current': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': [],
#   'custom_float_condition': "p.type='design'"},
#  'cpc_group': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc_subgroup': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc_subsection': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'disambiguated_assignee_ids': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'disambiguated_inventor_ids': {'fields': {'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'disambiguated_location_ids': {'fields': {'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'figures': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'num_figures': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num_sheets': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'foreign_priority': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'foreigncitation': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'further_cpc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'class': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'main_group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'subclass',
#     'main_table_id': 'subclass',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'government_interest': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'gi_statement': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'government_organization': {'fields': {'organization_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_one': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_two': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'level_three': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'inventor': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'male_flag': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'attribution_status': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'inventor_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'inventor_gender': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dumale': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'ipcr': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'classification_level': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'section': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'ipc_class': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'subclass': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'main_group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'classification_value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'classification_status': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'classification_data_source': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'ipc_version_indicator': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'subclass',
#     'main_table_id': 'subclass',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'lat_longs': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lat': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'lawyer': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True}},
#   'TestScripts': []},
#  'location': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'county': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'county_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lat_new': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'long_new': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'location_assignee': {'fields': {'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'},
#    {'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_by_lat_long': {'fields': {'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'old_location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_fips': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'county': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'county_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state_fips': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'location_id_lat_long': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_inventor': {'fields': {'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'},
#    {'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'location_lat_lon': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'main_cpc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'class': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'main_group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'subclass',
#     'main_table_id': 'subclass',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'mainclass': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'mainclass_current': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'nber': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subcategory_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['UploadTest']},
#  'nber_category': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['UploadTest']},
#  'nber_subcategory': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['UploadTest']},
#  'non_inventor_applicant': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lname': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'fname': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'applicant_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'rawlocation',
#     'main_table_id': 'rawlocation_id',
#     'related_table_id': 'uuid'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'otherreference': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'patent': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'abstract': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'num_claims': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'withdrawn': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'application',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'botanic',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'claim',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'cpc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'cpc_current',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'figures',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'foreign_priority',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'foreigncitation',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'further_cpc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'government_interest',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'ipcr',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'main_cpc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'nber',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'non_inventor_applicant',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'otherreference',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_assignee',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_contractawardnumber',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_govintorg',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_inventor',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'patent_lawyer',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'pct_data',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawassignee',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawexaminer',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawinventor',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rawlawyer',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'rel_app_text',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'us_term_of_grant',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'usapplicationcitation',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'uspatentcitation',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'uspc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'uspc_current',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'usreldoc',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'},
#    {'related_table': 'wipo',
#     'main_table_id': 'id',
#     'related_table_id': 'patent_id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'patent_assignee': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'},
#    {'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'patent_contractawardnumber': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'contract_award_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'patent_govintorg': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'organization_id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'patent_inventor': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'},
#    {'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'patent_lawyer': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lawyer_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'lawyer',
#     'main_table_id': 'lawyer_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'pct_data': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'rel_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    '371_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'doc_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    '102_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'persistent_assignee_disambig': {'fields': {'current_rawassignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'old_rawassignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20181127': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20190312': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20190820': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20191008': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20191231': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20200331': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20200630': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20200929': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20201229': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20210330': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disambig_assignee_id_20210629': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20210930': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_assignee_id_20210708': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'rawassignee',
#     'main_table_id': 'current_rawassignee_id',
#     'related_table_id': 'uuid'},
#    {'related_table': 'assignee',
#     'main_table_id': 'disamb_assignee_id_20210930',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'persistent_assignee_disambig_long': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'database_update': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'persistent_inventor_disambig': {'fields': {'current_rawinventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'old_rawinventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20170808': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20171003': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20171226': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20180528': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20181127': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20190312': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20190820': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20191008': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20191231': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20200331': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20200630': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20200929': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disamb_inventor_id_20201229': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'rawinventor',
#     'main_table_id': 'current_rawinventor_id',
#     'related_table_id': 'uuid'},
#    {'related_table': 'inventor',
#     'main_table_id': 'disamb_inventor_id_20201229',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'persistent_inventor_disambig_long': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'database_update': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'}],
#   'TestScripts': []},
#  'rawassignee': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'assignee',
#     'main_table_id': 'assignee_id',
#     'related_table_id': 'id'},
#    {'related_table': 'rawlocation',
#     'main_table_id': 'rawlocation_id',
#     'related_table_id': 'uuid'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rawexaminer': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'role': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'group': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'MergeTestQuarterly']},
#  'rawinventor': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rule_47': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'deceased': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'inventor',
#     'main_table_id': 'inventor_id',
#     'related_table_id': 'id'},
#    {'related_table': 'rawlocation',
#     'main_table_id': 'rawlocation_id',
#     'related_table_id': 'uuid'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rawlawyer': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lawyer_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'lawyer',
#     'main_table_id': 'lawyer_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rawlocation': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_new_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'location',
#     'main_table_id': 'location_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'rel_app_text': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'state_codes': {'fields': {'State/Possession': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'Abbreviation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'subclass': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'subclass_current': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'unique_locations': {'fields': {'id': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'lattitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'us_term_of_grant': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lapse_of_patent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'disclaimer_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'term_disclaimer': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'term_grant': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'term_extension': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'usapplicationcitation': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'application',
#     'main_table_id': 'application_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'uspatentcitation': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'citation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'uspc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'mainclass',
#     'main_table_id': 'mainclass_id',
#     'related_table_id': 'id'},
#    {'related_table': 'subclass',
#     'main_table_id': 'subclass_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'uspc_current': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'related_entities': [{'related_table': 'mainclass',
#     'main_table_id': 'mainclass_id',
#     'related_table_id': 'id'},
#    {'related_table': 'subclass',
#     'main_table_id': 'subclass_id',
#     'related_table_id': 'id'}],
#   'TestScripts': ['UploadTest']},
#  'usreldoc': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'doctype': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'relkind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'reldocno': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'status': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False}},
#   'TestScripts': ['MergeTest', 'UploadTest', 'MergeTestQuarterly']},
#  'wipo': {'fields': {'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'field_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'wipo_field': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sector_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'field_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []}}

# %% [markdown]
# #### REMOVE UNIMPORTANT FIELDS

# %%
for i in c_set.keys():
    for j in list(c_set[i]['fields'].keys()):
        if j in ['created_date','updated_date','version_indicator']:
            del c_set[i]['fields'][j]

# %%
a = 'pgpubs_20211012'

# %%
a[:6]
# Out:
# 'pgpubs'

# %%
# 24 items
MergeTest.keys()

# %%
# 27 items
UploadTest.keys()

# %%
UploadTest = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'custom_float_condition': "p.type='plant'",
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     True
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'nber':                   {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subcategory_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        }
                                }
                        },
                'nber_category':          {
                        'fields': {
                                'id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'title': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'nber_subcategory':       {
                        'fields': {
                                'id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'title': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'uspc_current': {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                }

# %%
MergeTestWeekly = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                },
                        'custom_float_condition': "p.type='plant'"
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawexaminer':            {
                        'fields': {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_last':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'role':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'group':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        }
                }

# %%
MergeTestQuarterly = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                },
                        'custom_float_condition': "p.type='plant'"
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawexaminer':            {
                        'fields': {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_last':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'role':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'group':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        }
                }
