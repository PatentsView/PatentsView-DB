# %%
import os
import pymysql
import datetime

# %%
pip install pymysql
# Out:
# WARNING: Ignoring invalid distribution -ip (/Users/bcard/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/bcard/opt/anaconda3/lib/python3.8/site-packages)
# ...
# WARNING: Ignoring invalid distribution -ip (/Users/bcard/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/bcard/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/bcard/opt/anaconda3/lib/python3.8/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
os.environ['PACKAGE_HOME']="/Users/bcard/OneDrive - American Institutes for Research in the Behavioral Sciences/projects/patentsview/PatentsView-DB"

# %%
cd ..
# Out:
# /Users/bcard

# %%
cd OneDrive - American Institutes for Research in the Behavioral Sciences
# Out:
# /Users/bcard/OneDrive - American Institutes for Research in the Behavioral Sciences

# %%
cd projects/patentsview/PatentsView-DB
# Out:
# /Users/bcard/OneDrive - American Institutes for Research in the Behavioral Sciences/projects/patentsview/PatentsView-DB

# %%
from lib.configuration import get_config, get_connection_string,get_current_config


c=get_config()

# %%
config = get_current_config('granted_patent', **{
        "execution_date": datetime.date(2021, 11, 4)
    })

# %%
connection_string=get_connection_string(config, database='PROD_DB')

# %%
connection_string
# Out:
# 'mysql+pymysql://bcard:oVKUc4A7ofP5S@pv3-ingestmysql.cckzcdkkfzqo.us-east-1.rds.amazonaws.com:3306/patent?charset=utf8mb4'

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine(connection_string)

# %%
import pandas as pd

# %%
columns=pd.read_sql_query(sql="""
select *
from information_schema.COLUMNS
where TABLE_SCHEMA = 'patent'
  and TABLE_NAME not like '%%temp%%'
  and TABLE_NAME not like '%%tmp%%'
  and TABLE_NAME not like '%%2021%%'
  and TABLE_NAME not like '%%old%%'
  and TABLE_NAME not like '%%backup%%'
  and TABLE_NAME not like '%%archive%%'
  and TABLE_NAME not like '%%20201229%%'
  and TABLE_NAME not like '%%20201231%%'
  and TABLE_NAME not like '%%20210330%%'
  and TABLE_NAME not like '%%20210629%%'
  and TABLE_NAME not like '%%20210930%%'
  and TABLE_NAME not like '%%ernest%%'
  and TABLE_NAME not like 'brf_sum_text%%'
  and TABLE_NAME not like 'detail_desc%%'
  and table_name not like 'draw_desc%%'
  and table_name not like 'claim_%%';
""", con=engine)

# %%
columns.groupby('TABLE_NAME').get_group('application')
# Out:
#     TABLE_CATALOG TABLE_SCHEMA   TABLE_NAME  \
# 317           def       patent  application
# 318           def       patent  application
# 319           def       patent  application
# 320           def       patent  application
# 321           def       patent  application
# 322           def       patent  application
# 323           def       patent  application
# 324           def       patent  application
# 325           def       patent  application
# 326           def       patent  application
# 327           def       patent  application
# 328           def       patent  application
#
#                            COLUMN_NAME  ORDINAL_POSITION       COLUMN_DEFAULT  \
# 317                                 id                 1                 None
# 318                          patent_id                 2                 None
# 319                               type                 3                 NULL
# ...

# %%
columns["DATA_TYPE"].unique()
# Out:
# array(['varchar', 'date', 'timestamp', 'text', 'int', 'float',
#        'mediumtext', 'bigint', 'double'], dtype=object)

# %%
columns
# Out:
#     TABLE_CATALOG TABLE_SCHEMA                    TABLE_NAME  \
# 0             def       patent  persistent_inventor_disambig
# 1             def       patent  persistent_inventor_disambig
# 2             def       patent  persistent_inventor_disambig
# 3             def       patent  persistent_inventor_disambig
# 4             def       patent  persistent_inventor_disambig
# ..            ...          ...                           ...
# 549           def       patent              foreign_priority
# 550           def       patent              foreign_priority
# 551           def       patent              foreign_priority
# 552           def       patent              foreign_priority
# 553           def       patent              foreign_priority
#
#                      COLUMN_NAME  ORDINAL_POSITION       COLUMN_DEFAULT  \
# 0         current_rawinventor_id                 1                 None
# 1             old_rawinventor_id                 2                 NULL
# ...

# %%
# A list of categories pulled from the DataMonitor_categorycount output
# Can program this into the creation of the json file
category_list = ['applicant_type',
'category',
'classification_data_source',
'classification_level',
'classification_status',
# 'country',
# 'country_transformed',
'deceased',
'designation',
'doc_type',
'doctype',
'field_id',
'group',
'group_id',
'ipc_class',
'kind',
'relkind',
'role',
'section',
'section_id',
'state',
'status',
'subclass',
'subgroup',
'subgroup_id',
'symbol_position',
'type']

# %%
for i in category_list:
    if i[:1] >= 'p':
        print(i)
    else:
        continue
# Out:
# relkind
# role
# section
# section_id
# state
# status
# subclass
# subgroup
# subgroup_id
# symbol_position
# type

# %%
def generate_column_setting(column):
    
    data_type = 'varchar'
    if column.DATA_TYPE in ['date', 'timestamp']:
        data_type = 'date'
    if column.DATA_TYPE in ['int', 'bigint', 'smallint', 'float', 'decimal']:
        data_type = 'int'
        
    null_allowed = True
    if column.IS_NULLABLE == 'NO':
        null_allowed = False
        
    location_field = False
    if column.COLUMN_NAME in ['country','country_transformed']:
        location_field = True

    category = False
    if column.COLUMN_NAME in category_list:
        if column.TABLE_NAME == 'foreign_priority':
            if column.COLUMN_NAME =='kind':
                category = False
        elif column.TABLE_NAME in ['further_cpc','main_cpc']:
            category = False
        elif column.COLUMN_NAME == 'section_id' and column.TABLE_NAME != 'cpc':
            category = False
        else:
            category=True
            
    setting = {
        column.COLUMN_NAME: {
            'data_type': data_type,
            'null_allowed': null_allowed,
            'category': category,
            'location_field': location_field
        }
    }
    return setting

# %%
from functools import reduce

# %%
def generate_table_setting(table_group):
    y=table_group.apply(generate_column_setting,axis=1)
    t_set={table_group.name:{"fields":reduce(lambda a, b: dict(a, **b), y.tolist())}}
    return t_set

# %%
x=columns.groupby('TABLE_NAME').apply(func=generate_table_setting)

# %%
x
# Out:
# TABLE_NAME
# application                        {'application': {'fields': {'id': {'data_type'...
# assignee                           {'assignee': {'fields': {'id': {'data_type': '...
# assignee_disambiguation_mapping    {'assignee_disambiguation_mapping': {'fields':...
# botanic                            {'botanic': {'fields': {'uuid': {'data_type': ...
# claim                              {'claim': {'fields': {'uuid': {'data_type': 'v...
#                                                          ...
# uspc                               {'uspc': {'fields': {'uuid': {'data_type': 'va...
# uspc_current                       {'uspc_current': {'fields': {'uuid': {'data_ty...
# usreldoc                           {'usreldoc': {'fields': {'uuid': {'data_type':...
# wipo                               {'wipo': {'fields': {'patent_id': {'data_type'...
# wipo_field                         {'wipo_field': {'fields': {'id': {'data_type':...
# Length: 71, dtype: object

# %%
# TABLES FROM QUERY: 104
len(x.keys())
# Out:
# 71

# %%
list(x.keys())
# Out:
# ['application',
#  'assignee',
#  'assignee_disambiguation_mapping',
#  'botanic',
#  'claim',
#  'country_codes',
#  'cpc',
#  'cpc_current',
#  'cpc_group',
#  'cpc_subgroup',
#  'cpc_subsection',
#  'disambiguated_assignee_ids',
#  'disambiguated_inventor_ids',
#  'disambiguated_location_ids',
#  'figures',
#  'foreign_priority',
#  'foreigncitation',
#  'further_cpc',
#  'government_interest',
#  'government_organization',
#  'inventor',
#  'inventor_disambiguation_mapping',
#  'inventor_gender',
#  'ipcr',
#  'lat_longs',
#  'lawyer',
#  'location',
#  'location_assignee',
#  'location_by_lat_long',
#  'location_disambiguation_mapping',
#  'location_fips',
#  'location_id_lat_long',
#  'location_inventor',
#  'location_lat_lon',
#  'main_cpc',
#  'mainclass',
#  'mainclass_current',
#  'nber',
#  'nber_category',
#  'nber_subcategory',
#  'non_inventor_applicant',
#  'otherreference',
#  'patent',
#  'patent_assignee',
#  'patent_contractawardnumber',
#  'patent_govintorg',
# ...

# %% [markdown]
# #### START HERE WHEN RE-BUILDING BASE DICTIONARY

# %%
c_set=reduce(lambda a, b: dict(a, **b), x.tolist())

# %%
exclusion_list = []
for i in c_set.keys():
    if i == "patent":
        print("skipping patent")
    else:
        print(i,"TABLE =====================")
        temp = 0
        for j in c_set[i]['fields']:
            print(j, "FIELD")
            if j == 'patent_id':
                temp += 1
            else:
                pass
        print(temp)
        if temp == 1:
            pass
        else:
            exclusion_list.append(i)
# Out:
# application TABLE =====================
# id FIELD
# patent_id FIELD
# type FIELD
# number FIELD
# country FIELD
# date FIELD
# id_transformed FIELD
# number_transformed FIELD
# series_code_transformed_from_type FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# assignee TABLE =====================
# id FIELD
# type FIELD
# name_first FIELD
# name_last FIELD
# organization FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 0
# assignee_disambiguation_mapping TABLE =====================
# uuid FIELD
# assignee_id FIELD
# 0
# botanic TABLE =====================
# uuid FIELD
# patent_id FIELD
# latin_name FIELD
# variety FIELD
# version_indicator FIELD
# created_date FIELD
# updated_date FIELD
# 1
# claim TABLE =====================
# uuid FIELD
# patent_id FIELD
# text FIELD
# dependent FIELD
# sequence FIELD
# 1
# country_codes TABLE =====================
# name FIELD
# alpha-2 FIELD
# alpha-3 FIELD
# country-code FIELD
# ...

# %%
exclusion_list
# Out:
# ['assignee',
#  'assignee_disambiguation_mapping',
#  'country_codes',
#  'cpc_group',
#  'cpc_subgroup',
#  'cpc_subsection',
#  'disambiguated_assignee_ids',
#  'disambiguated_inventor_ids',
#  'disambiguated_location_ids',
#  'government_organization',
#  'inventor',
#  'inventor_disambiguation_mapping',
#  'inventor_gender',
#  'lat_longs',
#  'lawyer',
#  'location',
#  'location_assignee',
#  'location_by_lat_long',
#  'location_disambiguation_mapping',
#  'location_fips',
#  'location_id_lat_long',
#  'location_inventor',
#  'location_lat_lon',
#  'mainclass',
#  'mainclass_current',
#  'nber_category',
#  'nber_subcategory',
#  'persistent_assignee_disambig',
#  'persistent_assignee_disambig_long',
#  'persistent_inventor_disambig',
#  'persistent_inventor_disambig_long',
#  'rawlocation',
#  'state_codes',
#  'subclass',
#  'subclass_current',
#  'unique_locations',
#  'wipo_field']

# %% [markdown]
# ## USING THE CURRENT JSON TO DETERMINE WHICH TABLES ARE NEEDED

# %% [markdown]
# ## ADDING MISSING TABLES

# %%
# c_set.keys()

# %%
# missing_tables = dict((k, c_set[k]) for k in ('cpc'))

# %%
# legacy_json.update(missing_tables)

# %%
# Sorting alphabetically 
# import collections
# legacy_json = collections.OrderedDict(sorted(legacy_json.items()))

# %%
# legacy_json.keys()

# %%
# Adding location field
# for i in legacy_json.keys():
#     for j in legacy_json[i]['fields']:
#         location_field = False
#         # Only using country for now because we just on country code later for verification
#         if j in ['country','country_transformed']:
#             location_field = True
#         legacy_json[i]['fields'][j].update({'location_field': location_field})

# %% [markdown]
# ## ADD IN RELATED ENTITIES FOR THE PATENT TABLE

# %%
# Add in all entities related to PATENTS

# %%
foreign_tables = []
for i in c_set.keys():
#     print(i)
    if i != 'patent':
        for j in c_set[i]['fields']:
    #         print("=====", j)
            if j == 'patent_id':
                foreign_tables.append(['patent', 'id', i, 'patent_id'])

# %%
related_entities_lookup1 = pd.DataFrame(list(foreign_tables), columns=['main_table','main_table_id','related_table','related_table_id'])

# %%
related_entities_lookup1
# Out:
#    main_table main_table_id               related_table related_table_id
# 0      patent            id                 application        patent_id
# 1      patent            id                     botanic        patent_id
# 2      patent            id                       claim        patent_id
# 3      patent            id                         cpc        patent_id
# 4      patent            id                 cpc_current        patent_id
# 5      patent            id                     figures        patent_id
# 6      patent            id            foreign_priority        patent_id
# 7      patent            id             foreigncitation        patent_id
# 8      patent            id                 further_cpc        patent_id
# 9      patent            id         government_interest        patent_id
# 10     patent            id                        ipcr        patent_id
# 11     patent            id                    main_cpc        patent_id
# ...

# %%
# Add in other relationships beyond to the central table (patent)
foreign_tables = []
for i in c_set.keys():
#     print(i)
    for j in c_set[i]['fields']:
#         print("=====", j)
        words = j.split("_")
        if 'patent' in words:
            words.remove('patent')
        if j not in ['location_new_id','location_id_transformed','application_id_transformed','old_location_id','old_rawassignee_id','old_rawinventor_id']:
            for w in words:
#                 print("++++++++++++++++++", w)
                if w in c_set.keys():
                    if i != w:
                        if w[:3] == 'raw':
                            related_id = 'uuid'
                        else:
                            related_id = 'id'
                        # i: main_table; j: main_table_id; w: related_table
                        foreign_tables.append([i, j, w, related_id])

# %%
related_entities_lookup2 = pd.DataFrame(list(foreign_tables), columns=['main_table','main_table_id','related_table','related_table_id'])

# %%
related_entities_lookup2.tail(35)
# Out:
#                            main_table                  main_table_id  \
# 27       persistent_assignee_disambig    disamb_assignee_id_20200331
# 28       persistent_assignee_disambig    disamb_assignee_id_20200630
# 29       persistent_assignee_disambig    disamb_assignee_id_20200929
# 30       persistent_assignee_disambig    disamb_assignee_id_20201229
# 31       persistent_assignee_disambig    disamb_assignee_id_20210330
# 32       persistent_assignee_disambig  disambig_assignee_id_20210629
# 33       persistent_assignee_disambig    disamb_assignee_id_20210930
# 34       persistent_assignee_disambig    disamb_assignee_id_20210708
# 35  persistent_assignee_disambig_long                    assignee_id
# 36       persistent_inventor_disambig         current_rawinventor_id
# 37       persistent_inventor_disambig    disamb_inventor_id_20170808
# 38       persistent_inventor_disambig    disamb_inventor_id_20171003
# 39       persistent_inventor_disambig    disamb_inventor_id_20171226
# ...

# %%
related_entities_lookup2[ (related_entities_lookup2['main_table'] == 'rawlawyer')]
# Out:
#    main_table main_table_id related_table related_table_id
# 55  rawlawyer     lawyer_id        lawyer               id

# %%
# run for persistent_assignee_disambig (related table: assignee) & persistent_inventor_disambig (related table: inventor)
list_to_edit = [['persistent_assignee_disambig','assignee'], ['persistent_inventor_disambig','inventor']]
for a,b in list_to_edit:
    year_columns = []
    cols_in_disamb = list( related_entities_lookup2['main_table_id'][ (related_entities_lookup2['main_table'] == a) & (related_entities_lookup2['related_table'] == b)])
    for i in cols_in_disamb:
        words = i.split("_")
        for w in words:
            if w[0]=='2':
                year_columns.append(w)
    # print(year_columns)
    last_year = max(year_columns)
    for k in cols_in_disamb:
        if last_year in k:
            winner_column = k
            print(winner_column)
    cols_in_disamb.remove(winner_column)
    related_entities_lookup2 = related_entities_lookup2[~related_entities_lookup2['main_table_id'].isin(cols_in_disamb)]
# Out:
# disamb_assignee_id_20210930
# disamb_inventor_id_20201229

# %%
related_entities_lookup2[related_entities_lookup2['main_table']=='persistent_assignee_disambig']
# Out:
#                       main_table                main_table_id related_table  \
# 21  persistent_assignee_disambig       current_rawassignee_id   rawassignee
# 33  persistent_assignee_disambig  disamb_assignee_id_20210930      assignee
#
#    related_table_id
# 21             uuid
# 33               id

# %% [markdown]
# #### DYNAMICALLY FINDING THE RIGHT COLUMN TO USE FOR MAIN_TABLE_ID

# %%
related_entities_lookup = pd.concat([related_entities_lookup1, related_entities_lookup2])

# %%
related_entities_lookup
# Out:
#                main_table   main_table_id related_table related_table_id
# 0                  patent              id   application        patent_id
# 1                  patent              id       botanic        patent_id
# 2                  patent              id         claim        patent_id
# 3                  patent              id           cpc        patent_id
# 4                  patent              id   cpc_current        patent_id
# ..                    ...             ...           ...              ...
# 57  usapplicationcitation  application_id   application               id
# 58                   uspc    mainclass_id     mainclass               id
# 59                   uspc     subclass_id      subclass               id
# 60           uspc_current    mainclass_id     mainclass               id
# 61           uspc_current     subclass_id      subclass               id
#
# [71 rows x 4 columns]

# %%
related_entities_lookup[related_entities_lookup['main_table']=='location_disambiguation_mapping']
# Out:
#                          main_table main_table_id related_table  \
# 10  location_disambiguation_mapping   location_id      location
#
#    related_table_id
# 10               id

# %%
# ADDING IN RELATIONAL ENTITIES 
for i in c_set.keys():
    if i in list(related_entities_lookup["main_table"]):
        related_tables = list(related_entities_lookup["related_table"][related_entities_lookup["main_table"]==i])
        dict_list = []
        for z in related_tables:
            ids = list(related_entities_lookup["main_table_id"][ (related_entities_lookup["main_table"]==i) & (related_entities_lookup["related_table"]==z)])
            for each_id in ids:
                table =z
                rel_id = related_entities_lookup["related_table_id"][ (related_entities_lookup["main_table"]==i) & (related_entities_lookup["related_table"]==z)& (related_entities_lookup["main_table_id"]== each_id) ].item()
                temp = {
                    "related_table": table,
                    "main_table_id": each_id,
                    "related_table_id": rel_id
                    }
                dict_list.append(temp)
        c_set[i]['related_entities']=dict_list

# %% [markdown]
# ## CREATE FLAG FOR EACH TABLE ON WHICH TESTS IT RUNS

# %%
test_script_list = []
for i in c_set.keys():
    if i in MergeTestWeekly.keys():
        test_script_list.append("MergeTestWeekly")
    if i in UploadTest.keys():
        test_script_list.append("UploadTest")
    if i in MergeTestQuarterly.keys():
        test_script_list.append("MergeTestQuarterly")
        
    c_set[i]['TestScripts'] = test_script_list
    if i == 'botanic':
        c_set[i]["custom_float_condition"] = "p.type='plant'"
    if i in ['cpc','cpc_current']:
        c_set[i]["custom_float_condition"] = "p.type='design'"
    test_script_list = []

# %%
c_set
# Out:
# {'application': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': True,
#     'location_field': False},
#    'number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': True},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'number_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
# ...

# %% [markdown]
# #### REMOVE UNIMPORTANT FIELDS

# %%
for i in c_set.keys():
    for j in list(c_set[i]['fields'].keys()):
        if j in ['created_date','updated_date','version_indicator']:
            del c_set[i]['fields'][j]

# %%
a = 'pgpubs_20211012'

# %%
a[:6]
# Out:
# 'pgpubs'

# %%
# 24 items
MergeTest.keys()

# %%
# 27 items
UploadTest.keys()

# %%
UploadTest = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'custom_float_condition': "p.type='plant'",
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     True
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'nber':                   {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subcategory_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        }
                                }
                        },
                'nber_category':          {
                        'fields': {
                                'id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'title': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'nber_subcategory':       {
                        'fields': {
                                'id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'title': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'uspc_current': {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                }

# %%
MergeTestWeekly = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                },
                        'custom_float_condition': "p.type='plant'"
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawexaminer':            {
                        'fields': {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_last':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'role':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'group':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        }
                }

# %%
MergeTestQuarterly = {
                'application':            {
                        'fields': {
                                'patent_id':                         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id_transformed':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'type':                              {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number_transformed':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number':                            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'series_code_transformed_from_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':                           {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'id':                                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':                              {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        }
                                }
                        },
                'botanic':                {
                        'fields':                 {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'latin_name': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'variety':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                },
                        'custom_float_condition': "p.type='plant'"
                        },
                'figures':                {
                        'fields': {
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'num_figures': {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'num_sheets':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'foreigncitation':        {
                        'fields': {
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'number':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'foreign_priority':       {
                        'fields': {
                                'date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'patent_id':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':            {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'kind':                {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'number':              {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'government_interest':    {
                        'fields': {
                                'gi_statement': {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'ipcr':                   {
                        'fields': {
                                'ipc_version_indicator':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'ipc_class':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_value':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'subclass':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_status':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'main_group':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_data_source': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'classification_level':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'subgroup':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'action_date':                {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'section':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'symbol_position':            {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'mainclass':              {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'non_inventor_applicant': {
                        'fields': {
                                'fname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'designation':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'lname':          {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'applicant_type': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'otherreference':         {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'text',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'patent':                 {
                        'fields': {
                                'type':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'title':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':     {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'country':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'num_claims': {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':       {
                                        'data_type':    'date',
                                        'null_allowed': False,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'filename':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'id':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'abstract':   {
                                        'data_type':    'mediumtext',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'withdrawn':  {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'pct_data':               {
                        'fields': {
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'rel_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'doc_type':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '102_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                '371_date':  {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawassignee':            {
                        'fields': {
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'assignee_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'organization':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'type':           {
                                        'data_type':    'int',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawinventor':            {
                        'fields': {
                                'uuid':           {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_last':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':       {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'inventor_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rule_47':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'rawlocation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'deceased':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'name_first':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawlawyer':              {
                        'fields': {
                                'name_last':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'organization': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lawyer_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'country':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        },
                'rawexaminer':            {
                        'fields': {
                                'uuid':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name_first': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'name_last':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'role':       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'group':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rawlocation':            {
                        'fields': {
                                'id':                      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country_transformed':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'location_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'location_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'city':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'state':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'country':                 {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'rel_app_text':           {
                        'fields': {
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'text':      {
                                        'data_type':    'mediumtext',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'subclass':               {
                        'fields': {
                                'id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usapplicationcitation':  {
                        'fields': {
                                'name':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'sequence':                   {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'uuid':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':                       {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'application_id_transformed': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'patent_id':                  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'number':                     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'number_transformed':         {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'application_id':             {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':                    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':                       {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'category':                   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspatentcitation':       {
                        'fields': {
                                'citation_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'category':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'date':        {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'sequence':    {
                                        'data_type':    'bigint',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'name':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':        {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':        {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id':   {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':     {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'uspc':                   {
                        'fields': {
                                'uuid':         {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'patent_id':    {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'mainclass_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'subclass_id':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     True
                                        },
                                'sequence':     {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        }
                                }
                        },
                'usreldoc':               {
                        'fields': {
                                'status':    {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'relkind':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'sequence':  {
                                        'data_type':    'int',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'reldocno':  {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'kind':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'uuid':      {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'country':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        },
                                'patent_id': {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'date':      {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'doctype':   {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     True
                                        }
                                }
                        },
                'us_term_of_grant':       {
                        'fields': {
                                'patent_id':       {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_extension':  {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'lapse_of_patent': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'disclaimer_date': {
                                        'data_type':    'date',
                                        'null_allowed': True,
                                        'date_field':   True,
                                        'category':     False
                                        },
                                'term_disclaimer': {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        },
                                'uuid':            {
                                        'data_type':    'varchar',
                                        'null_allowed': False,
                                        'category':     False
                                        },
                                'term_grant':      {
                                        'data_type':    'varchar',
                                        'null_allowed': True,
                                        'category':     False
                                        }
                                }
                        }
                }
