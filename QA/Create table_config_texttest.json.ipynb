# %%
import os
import pymysql

# %%
conda install pymysql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/bcard/opt/anaconda3
#
#   added / updated specs:
#     - pymysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pymysql-1.0.2              |   py38hecd8cb5_1          78 KB
#     ------------------------------------------------------------
#                                            Total:          78 KB
#
# The following NEW packages will be INSTALLED:
#
#   pymysql            pkgs/main/osx-64::pymysql-1.0.2-py38hecd8cb5_1
#
#
#
# Downloading and Extracting Packages
# pymysql-1.0.2        | 78 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
os.environ['PACKAGE_HOME']="/Users/bcard/OneDrive - American Institutes for Research in the Behavioral Sciences/projects/patentsview/PatentsView-DB"

# %%
pwd
# Out:
# '/Users/bcard/OneDrive - American Institutes for Research in the Behavioral Sciences/projects/patentsview/PatentsView-DB'

# %%
from lib.configuration import get_config, get_connection_string


c=get_config()

# %%
connection_string=get_connection_string(c, database='PGPUBS_DATABASE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9d7529aaa68c> in <module>
# ----> 1 connection_string=get_connection_string(c, database='PGPUBS_DATABASE')
#
# ~/OneDrive - American Institutes for Research in the Behavioral Sciences/projects/patentsview/PatentsView-DB/lib/configuration.py in get_connection_string(config, database, connection)
#      61
#      62 def get_connection_string(config, database='TEMP_UPLOAD_DB', connection='DATABASE_SETUP'):
# ---> 63     database = '{}'.format(config['PATENTSVIEW_DATABASES'][database])
#      64     host = '{}'.format(config[connection]['HOST'])
#      65     user = '{}'.format(config[connection]['USERNAME'])
#
# ~/opt/anaconda3/lib/python3.8/configparser.py in __getitem__(self, key)
#    1252     def __getitem__(self, key):
#    1253         if not self._parser.has_option(self._name, key):
# -> 1254             raise KeyError(key)
#    1255         return self._parser.get(self._name, key)
#    1256
#
# KeyError: 'PGPUBS_DATABASE'

# %%
connection_string
# Out:
# 'mysql+pymysql://bcard:oVKUc4A7ofP5S@pv3-ingestmysql.cckzcdkkfzqo.us-east-1.rds.amazonaws.com:3306/pregrant_publications?charset=utf8mb4'

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine(connection_string)

# %%
import pandas as pd

# %%
# columns=pd.read_sql_query(sql="""
# select *
# from information_schema.COLUMNS
# where TABLE_SCHEMA = 'pregrant_publications'
#   and TABLE_NAME not like '%%temp%%'
#   and TABLE_NAME not like '%%ernest%%'
#   and TABLE_NAME not like 'brf_sum_text%%'
#   and TABLE_NAME not like 'detail_desc%%'
#   and table_name not like 'draw_desc%%'
#   and table_name not like 'claim_%%' group by TABLE_NAME;
# """, con=engine)

# %%
columns=pd.read_sql_query(sql="""
select *
from information_schema.COLUMNS
where TABLE_SCHEMA = 'patent_text'
  and TABLE_NAME not like '%%tmp%%'
  and TABLE_NAME not like '%%temp%%'
  and TABLE_NAME not like '%%backup%%'
  and TABLE_NAME not like '%%archive%%'
  and TABLE_NAME not like '%%old%%'
""", con=engine)

# %%
columns.groupby('TABLE_NAME').get_group('claims_2021')
# Out:
#      TABLE_CATALOG TABLE_SCHEMA   TABLE_NAME        COLUMN_NAME  \
# 1198           def  patent_text  claims_2021               uuid
# 1199           def  patent_text  claims_2021          patent_id
# 1200           def  patent_text  claims_2021                num
# 1201           def  patent_text  claims_2021               text
# 1202           def  patent_text  claims_2021           sequence
# 1203           def  patent_text  claims_2021          dependent
# 1204           def  patent_text  claims_2021          exemplary
# 1205           def  patent_text  claims_2021  version_indicator
# 1206           def  patent_text  claims_2021       created_date
# 1207           def  patent_text  claims_2021       updated_date
#
#       ORDINAL_POSITION       COLUMN_DEFAULT IS_NULLABLE  DATA_TYPE  \
# 1198                 1                 NULL         YES    varchar
# 1199                 2                 NULL         YES    varchar
# 1200                 3                 NULL         YES    varchar
# 1201                 4                 NULL         YES   longtext
# 1202                 5                 NULL         YES        int
# 1203                 6                 NULL         YES    varchar
# 1204                 7                 NULL         YES        int
# 1205                 8                 NULL         YES       date
# 1206                 9  current_timestamp()         YES  timestamp
# 1207                10                 NULL         YES  timestamp
#
#       CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 1198              5.120000e+02            2.048000e+03  ...
# 1199              3.200000e+01            1.280000e+02  ...
# 1200              1.600000e+01            6.400000e+01  ...
# 1201              4.294967e+09            4.294967e+09  ...
# 1202                       NaN                     NaN  ...
# 1203              5.120000e+02            2.048000e+03  ...
# 1204                       NaN                     NaN  ...
# 1205                       NaN                     NaN  ...
# 1206                       NaN                     NaN  ...
# 1207                       NaN                     NaN  ...
#
#       DATETIME_PRECISION  CHARACTER_SET_NAME      COLLATION_NAME  \
# 1198                 NaN             utf8mb4  utf8mb4_unicode_ci
# 1199                 NaN             utf8mb4  utf8mb4_unicode_ci
# 1200                 NaN             utf8mb4  utf8mb4_unicode_ci
# 1201                 NaN             utf8mb4  utf8mb4_unicode_ci
# 1202                 NaN                None                None
# 1203                 NaN             utf8mb4  utf8mb4_unicode_ci
# 1204                 NaN                None                None
# 1205                 NaN                None                None
# 1206                 0.0                None                None
# 1207                 0.0                None                None
#
#        COLUMN_TYPE COLUMN_KEY                          EXTRA  \
# 1198  varchar(512)
# 1199   varchar(32)        MUL
# 1200   varchar(16)
# 1201      longtext
# 1202       int(11)
# 1203  varchar(512)
# 1204       int(32)
# 1205          date
# 1206     timestamp
# 1207     timestamp             on update current_timestamp()
#
#                 PRIVILEGES COLUMN_COMMENT IS_GENERATED GENERATION_EXPRESSION
# 1198  select,insert,update                       NEVER                  None
# 1199  select,insert,update                       NEVER                  None
# 1200  select,insert,update                       NEVER                  None
# 1201  select,insert,update                       NEVER                  None
# 1202  select,insert,update                       NEVER                  None
# 1203  select,insert,update                       NEVER                  None
# 1204  select,insert,update                       NEVER                  None
# 1205  select,insert,update                       NEVER                  None
# 1206  select,insert,update                       NEVER                  None
# 1207  select,insert,update                       NEVER                  None
#
# [10 rows x 22 columns]

# %%
columns['TABLE_NAME'].unique()
# Out:
# array(['brf_sum_text_2017', 'brf_sum_text_1997', 'claims_2014',
#        'detail_desc_text_2013', 'claims_2010', 'brf_sum_text_2019',
#        'detail_desc_text_2004', 'draw_desc_text_2017',
#        'detail_desc_text_1989', 'claims_1977', 'detail_desc_text_1993',
#        'claims_2017', 'detail_desc_text_2018', 'draw_desc_text_1984',
#        'draw_desc_text_2006', 'brf_sum_text_2010',
#        'detail_desc_text_2007', 'draw_desc_text_2001',
#        'draw_desc_text_2008', 'claims_2013', 'brf_sum_text_1993',
#        'detail_desc_text_1980', 'detail_desc_text_2009',
#        'detail_desc_text_2006', 'claims_1987', 'detail_desc_text_1992',
#        'draw_desc_text_1991', 'detail_desc_text_1977', 'h_dates',
#        'brf_sum_text_2013', 'detail_desc_text_1994', 'brf_sum_text_1998',
#        'brf_sum_text_1985', 'claims_1989', 'claims_1983',
#        'detail_desc_text_2008', 'brf_sum_text_2003', 'claims_2011',
#        'brf_sum_text_2008', 'draw_desc_text_2012', 'claims_1996',
#        'draw_desc_text_1995', 'claims_1982', 'detail_desc_text_2016',
#        'claims_2001', 'claims_1986', 'draw_desc_text_2002',
#        'draw_desc_text_1982', 'claims_1998', 'draw_desc_text_1994',
#        'detail_desc_text_1996', 'detail_desc_text_1990',
#        'brf_sum_text_2012', 'brf_sum_text_1983', 'detail_desc_text_1986',
#        'detail_desc_text_2014', 'draw_desc_text_2014', 'claims_2007',
#        'claims_1980', 'detail_desc_text_1978', 'draw_desc_text_2005',
#        'draw_desc_text_1989', 'draw_desc_text_2000', 'brf_sum_text_1995',
#        'draw_desc_text_2015', 'claims_1993', 'detail_desc_text_1982',
#        'brf_sum_text_2004', 'brf_sum_text_1977', 'detail_desc_text_2011',
#        'unmatched_claims', 'draw_desc_text_2009', 'claims_2003',
#        'draw_desc_text_1979', 'claims_1979', 'brf_sum_text_2020',
#        'detail_desc_text_1988', 'brf_sum_text_2021', 'brf_sum_text_1999',
#        'detail_desc_text_2021', 'brf_sum_text_1987',
#        'draw_desc_text_2016', 'draw_desc_text_1987',
#        'draw_desc_text_1981', 'detail_desc_text_2010',
#        'draw_desc_text_1983', 'detail_desc_text_2020',
#        'brf_sum_text_2009', 'detail_desc_text_1995', 'claims_1997',
#        'claims_2008', 'draw_desc_text_1985', 'draw_desc_text_2004',
#        'claims_1995', 'brf_sum_text_2002', 'brf_sum_text_2000',
#        'brf_sum_text_2007', 'claims_2012', 'claims_1985',
#        'draw_desc_text_2011', 'draw_desc_text_1976', 'claims_2005',
#        'detail_desc_text_1976', 'claims_2000', 'claims_2018',
#        'brf_sum_text_1980', 'claims_1978', 'claims_2020',
#        'brf_sum_text_2016', 'detail_desc_text_2017', 'claims_1994',
#        'brf_sum_text_2011', 'claims_1976', 'brf_sum_text_2015',
#        'claims_1988', 'inventor_updated', 'detail_desc_text_1991',
#        'detail_desc_text_1997', 'claims_2004', 'brf_sum_text_1990',
#        'brf_sum_text_1981', 'draw_desc_text_2013', 'draw_desc_text_1978',
#        'brf_sum_text_1979', 'brf_sum_text_2001', 'claims_2009',
#        'detail_desc_text_2000', 'claims_2006', 'brf_sum_text_1986',
#        'brf_sum_text_1994', 'brf_sum_text_2005', 'draw_desc_text_2020',
#        'claim_exemplary_2021', 'draw_desc_text_2018',
#        'draw_desc_text_1998', 'claims_2021', 'draw_desc_text_1999',
#        'detail_desc_text_2003', 'brf_sum_text_2014',
#        'draw_desc_text_1992', 'reparse_1985_v2', 'detail_desc_text_2012',
#        'claims_1990', 'detail_desc_text_1985', 'detail_desc_text_1998',
#        'brf_sum_text_1976', 'draw_desc_text_1990',
#        'detail_desc_text_1981', 'draw_desc_text_1977',
#        'brf_sum_text_1982', 'detail_desc_text_1983',
#        'detail_desc_text_1984', 'draw_desc_text_2010',
#        'draw_desc_text_1986', 'claims_1992', 'detail_desc_text_2005',
#        'draw_desc_text_1997', 'draw_desc_text_2019',
#        'detail_desc_text_2001', 'brf_sum_text_2018',
#        'draw_desc_text_1980', 'detail_desc_text_1979',
#        'brf_sum_text_1984', 'brf_sum_text_2006', 'detail_desc_text_2019',
#        'claims_1981', 'draw_desc_text_1996', 'draw_desc_text_1993',
#        'draw_desc_text_2021', 'claims_2015', 'claims_2019',
#        'draw_desc_text_2003', 'brf_sum_text_1989',
#        'detail_desc_text_1987', 'claims_2002', 'claims_1984',
#        'brf_sum_text_1996', 'draw_desc_text_1988', 'draw_desc_text_2007',
#        'detail_desc_text_2002', 'brf_sum_text_1992', 'claims_1991',
#        'detail_desc_text_1999', 'brf_sum_text_1988', 'brf_sum_text_1978',
#        'claims_2016', 'missing_claim', 'brf_sum_text_1991',
#        'detail_desc_text_2015', 'claim_exemplary_2020', 'claims_1999'],
#       dtype=object)

# %%
def generate_column_setting(column):
    
    data_type = 'varchar'
    if column.DATA_TYPE in ['date', 'timestamp'] and column.COLUMN_NAME != 'version_indicator':
        data_type = 'date'
    if column.DATA_TYPE in ['int', 'bigint', 'smallint', 'float', 'decimal']:
        data_type = 'int'
    
    null_allowed = True
    if column.IS_NULLABLE == 'NO':
        null_allowed = False
    
    category = False
#     if column.COLUMN_NAME in ['version_indicator']:
#         category = True
        
    setting = {
        column.COLUMN_NAME: {
            'data_type': data_type,
            'null_allowed': null_allowed,
            'category': category,
            'location_field': False
        }
    }
    return setting

# %%
from functools import reduce

# %%
def generate_table_setting(table_group):
    y=table_group.apply(generate_column_setting,axis=1)
    t_set={table_group.name:{"fields":reduce(lambda a, b: dict(a, **b), y.tolist())}}
    return t_set

# %%
x=columns.groupby('TABLE_NAME').apply(func=generate_table_setting)

# %%
x.keys()
# Out:
# Index(['brf_sum_text_1976', 'brf_sum_text_1977', 'brf_sum_text_1978',
#        'brf_sum_text_1979', 'brf_sum_text_1980', 'brf_sum_text_1981',
#        'brf_sum_text_1982', 'brf_sum_text_1983', 'brf_sum_text_1984',
#        'brf_sum_text_1985',
#        ...
#        'draw_desc_text_2017', 'draw_desc_text_2018', 'draw_desc_text_2019',
#        'draw_desc_text_2020', 'draw_desc_text_2021', 'h_dates',
#        'inventor_updated', 'missing_claim', 'reparse_1985_v2',
#        'unmatched_claims'],
#       dtype='object', name='TABLE_NAME', length=191)

# %%
c_set=reduce(lambda a, b: dict(a, **b), x.tolist())

# %%
c_set.keys()
# Out:
# dict_keys(['brf_sum_text_1976', 'brf_sum_text_1977', 'brf_sum_text_1978', 'brf_sum_text_1979', 'brf_sum_text_1980', 'brf_sum_text_1981', 'brf_sum_text_1982', 'brf_sum_text_1983', 'brf_sum_text_1984', 'brf_sum_text_1985', 'brf_sum_text_1986', 'brf_sum_text_1987', 'brf_sum_text_1988', 'brf_sum_text_1989', 'brf_sum_text_1990', 'brf_sum_text_1991', 'brf_sum_text_1992', 'brf_sum_text_1993', 'brf_sum_text_1994', 'brf_sum_text_1995', 'brf_sum_text_1996', 'brf_sum_text_1997', 'brf_sum_text_1998', 'brf_sum_text_1999', 'brf_sum_text_2000', 'brf_sum_text_2001', 'brf_sum_text_2002', 'brf_sum_text_2003', 'brf_sum_text_2004', 'brf_sum_text_2005', 'brf_sum_text_2006', 'brf_sum_text_2007', 'brf_sum_text_2008', 'brf_sum_text_2009', 'brf_sum_text_2010', 'brf_sum_text_2011', 'brf_sum_text_2012', 'brf_sum_text_2013', 'brf_sum_text_2014', 'brf_sum_text_2015', 'brf_sum_text_2016', 'brf_sum_text_2017', 'brf_sum_text_2018', 'brf_sum_text_2019', 'brf_sum_text_2020', 'brf_sum_text_2021', 'claim_exemplary_2020', 'claim_exemplary_2021', 'claims_1976', 'claims_1977', 'claims_1978', 'claims_1979', 'claims_1980', 'claims_1981', 'claims_1982', 'claims_1983', 'claims_1984', 'claims_1985', 'claims_1986', 'claims_1987', 'claims_1988', 'claims_1989', 'claims_1990', 'claims_1991', 'claims_1992', 'claims_1993', 'claims_1994', 'claims_1995', 'claims_1996', 'claims_1997', 'claims_1998', 'claims_1999', 'claims_2000', 'claims_2001', 'claims_2002', 'claims_2003', 'claims_2004', 'claims_2005', 'claims_2006', 'claims_2007', 'claims_2008', 'claims_2009', 'claims_2010', 'claims_2011', 'claims_2012', 'claims_2013', 'claims_2014', 'claims_2015', 'claims_2016', 'claims_2017', 'claims_2018', 'claims_2019', 'claims_2020', 'claims_2021', 'detail_desc_text_1976', 'detail_desc_text_1977', 'detail_desc_text_1978', 'detail_desc_text_1979', 'detail_desc_text_1980', 'detail_desc_text_1981', 'detail_desc_text_1982', 'detail_desc_text_1983', 'detail_desc_text_1984', 'detail_desc_text_1985', 'detail_desc_text_1986', 'detail_desc_text_1987', 'detail_desc_text_1988', 'detail_desc_text_1989', 'detail_desc_text_1990', 'detail_desc_text_1991', 'detail_desc_text_1992', 'detail_desc_text_1993', 'detail_desc_text_1994', 'detail_desc_text_1995', 'detail_desc_text_1996', 'detail_desc_text_1997', 'detail_desc_text_1998', 'detail_desc_text_1999', 'detail_desc_text_2000', 'detail_desc_text_2001', 'detail_desc_text_2002', 'detail_desc_text_2003', 'detail_desc_text_2004', 'detail_desc_text_2005', 'detail_desc_text_2006', 'detail_desc_text_2007', 'detail_desc_text_2008', 'detail_desc_text_2009', 'detail_desc_text_2010', 'detail_desc_text_2011', 'detail_desc_text_2012', 'detail_desc_text_2013', 'detail_desc_text_2014', 'detail_desc_text_2015', 'detail_desc_text_2016', 'detail_desc_text_2017', 'detail_desc_text_2018', 'detail_desc_text_2019', 'detail_desc_text_2020', 'detail_desc_text_2021', 'draw_desc_text_1976', 'draw_desc_text_1977', 'draw_desc_text_1978', 'draw_desc_text_1979', 'draw_desc_text_1980', 'draw_desc_text_1981', 'draw_desc_text_1982', 'draw_desc_text_1983', 'draw_desc_text_1984', 'draw_desc_text_1985', 'draw_desc_text_1986', 'draw_desc_text_1987', 'draw_desc_text_1988', 'draw_desc_text_1989', 'draw_desc_text_1990', 'draw_desc_text_1991', 'draw_desc_text_1992', 'draw_desc_text_1993', 'draw_desc_text_1994', 'draw_desc_text_1995', 'draw_desc_text_1996', 'draw_desc_text_1997', 'draw_desc_text_1998', 'draw_desc_text_1999', 'draw_desc_text_2000', 'draw_desc_text_2001', 'draw_desc_text_2002', 'draw_desc_text_2003', 'draw_desc_text_2004', 'draw_desc_text_2005', 'draw_desc_text_2006', 'draw_desc_text_2007', 'draw_desc_text_2008', 'draw_desc_text_2009', 'draw_desc_text_2010', 'draw_desc_text_2011', 'draw_desc_text_2012', 'draw_desc_text_2013', 'draw_desc_text_2014', 'draw_desc_text_2015', 'draw_desc_text_2016', 'draw_desc_text_2017', 'draw_desc_text_2018', 'draw_desc_text_2019', 'draw_desc_text_2020', 'draw_desc_text_2021', 'h_dates', 'inventor_updated', 'missing_claim', 'reparse_1985_v2', 'unmatched ...

# %%
for i in c_set.keys():
    for j in list(c_set[i]['fields'].keys()):
        if j in ['created_date','updated_date','patent_date']:
            del c_set[i]['fields'][j]

# %%
test_script_list = []
for i in c_set.keys():
    if i[:7] in ['brf_sum','claims_','detail_','draw_de']:
        test_script_list.append("TextMergeTest")
        test_script_list.append("TextUploadTest")
        
    c_set[i]['TestScripts'] = test_script_list
    test_script_list = []

# %%
c_set
# Out:
# {'brf_sum_text_1976': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1977': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1978': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1979': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1980': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1981': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1982': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1983': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1984': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1985': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1986': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1987': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1988': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1989': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1990': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1991': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1992': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1993': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1994': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1995': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1996': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1997': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1998': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_1999': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2000': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2001': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2002': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2003': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2004': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2005': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2006': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2007': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2008': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2009': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2010': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2011': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2012': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2013': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2014': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2015': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2016': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2017': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2018': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2019': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2020': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2021': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claim_exemplary_2020': {'fields': {'exemplary': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_exemplary_2021': {'fields': {'exemplary': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claims_1976': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1977': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1978': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1979': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1980': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1981': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1982': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1983': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1984': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1985': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1986': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1987': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1988': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claims_1989': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
# ...
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2007': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2008': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2009': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2010': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2011': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2012': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2013': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2014': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2015': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2016': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2017': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2018': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2019': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2020': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2021': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'h_dates': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'inventor_updated': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'male_flag': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'attribution_status': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'missing_claim': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'reparse_1985_v2': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filename': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'unmatched_claims': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'patent_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'exemplary': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version_indicator': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []}}

# %%
list(c_set['brf_sum_text_1976']['fields'].keys())
# Out:
# ['uuid', 'patent_id', 'text', 'version_indicator', 'filename']

# %%
len(c_set.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e13ccb0856e5> in <module>
# ----> 1 len(c_set.keys())
#
# NameError: name 'c_set' is not defined

# %%
## LOGIC HARD_CODED INTO REPO

TextTest = {"brf_sum_text_": dict(fields={
                        "uuid": {
                                "null_allowed": False,
                                "data_type": "varchar",
                                "category": False
                        },
                        "patent_id": {
                                "null_allowed": False,
                                "data_type": "varchar",
                                "category": False
                        },
                        "text": {
                                "null_allowed": False,
                                "data_type": "mediumtext",
                                "category": False
                        },
                        "version_indicator": {
                                "null_allowed": False,
                                "data_type": "varchar",
                                "category": False
                        }
                }),
                "claims_": {
                        'fields': {
                                "uuid":              {
                                        "null_allowed": False,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "exemplary":         {
                                        "null_allowed": False,
                                        "data_type":    "int",
                                        "category":     False
                                        },
                                "patent_id":         {
                                        "null_allowed": False,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "version_indicator": {
                                        "null_allowed": False,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "text":              {
                                        "null_allowed": False,
                                        "data_type":    "mediumtext",
                                        "category":     False
                                        },
                                "dependent":         {
                                        "null_allowed": True,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "sequence":          {
                                        "null_allowed": True,
                                        "data_type":    "int",
                                        "category":     False
                                        }
                                }
                        },
                "draw_desc_text_": {
                        'fields': {
                                "uuid":              {
                                        "null_allowed": False,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "patent_id":         {
                                        "null_allowed": False,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "text":              {
                                        "null_allowed": False,
                                        "data_type":    "mediumtext",
                                        "category":     False
                                        },
                                "sequence":          {
                                        "null_allowed": False,
                                        "data_type":    "int",
                                        "category":     False
                                        },
                                "version_indicator": {
                                        "null_allowed": True,
                                        "data_type":    "varchar",
                                        "category":     True
                                        }
                                }
                        },
                "detail_desc_text_": {
                        'fields': {
                                "uuid":              {
                                        "null_allowed": False,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "patent_id":         {
                                        "null_allowed": False,
                                        "data_type":    "varchar",
                                        "category":     False
                                        },
                                "text":              {
                                        "null_allowed": False,
                                        "data_type":    "mediumtext",
                                        "category":     False
                                        },
                                "length":            {
                                        "null_allowed": False,
                                        "data_type":    "int",
                                        "category":     False
                                        },
                                "version_indicator": {
                                        "null_allowed": True,
                                        "data_type":    "varchar",
                                        "category":     True
                                        }
                                }
                        }
                }

# %%
#### UPDATES NEEDED IN REPO
# change True and False to lowercase
# change datatype to data_type
