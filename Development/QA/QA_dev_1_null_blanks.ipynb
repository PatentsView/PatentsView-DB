# %%
df_3=pd.read_excel('{}/1_null_and_blank_count.xlsx'.format(previous_qa_loc))

# %%
df_3.head()
# Out:
#          Table     Column  patent_20170808  patent_20171226  \
# 0  application         id              0.0                0
# 1  application  patent_id              0.0                0
# 2  application       type              0.0                0
# 3  application     number              0.0                0
# 4  application    country              0.0                0
#
#   patent_20180528_restored patent_20180828    1    2    3    4     ...       \
# 0                        0            (0,)  NaN  NaN  NaN  NaN     ...
# 1                        0            (0,)  NaN  NaN  NaN  NaN     ...
# 2                        0            (0,)  NaN  NaN  NaN  NaN     ...
# 3                        0            (0,)  NaN  NaN  NaN  NaN     ...
# 4                        0            (0,)  NaN  NaN  NaN  NaN     ...
#
#   68.1 69.1 70.1 71.1 72.1 73.1 74.1 75.1 patent_20181127  Description
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               0  Problem : 0
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               0  Problem : 0
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               0  Problem : 0
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               0  Problem : 0
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               0  Problem : 0
#
# [5 rows x 159 columns]

# %%
#Count Null and Blank QA
import pandas as pd
import os
import configparser
import sys
sys.path.append('/project/Development')
from helpers import general_helpers
import configparser
config = configparser.ConfigParser()
config.read('/project/Development/config.ini')
host = config['DATABASE']['HOST']
username = config['DATABASE']['USERNAME']
password = config['DATABASE']['PASSWORD']
new_database = config['DATABASE']['NEW_DB']
old_database = config['DATABASE']['OLD_DB']
temporary_upload = config['DATABASE']['TEMP_UPLOAD_DB']
previous_qa_loc = config['FOLDERS']['OLD_QA_LOC']
new_qa_loc = config['FOLDERS']['NEW_QA_LOC']
latest_expected_date = config['CONSTANTS']['LATEST_DATE']

engine = general_helpers.connect_to_db(host, username, password, new_database)
data = pd.read_excel("{}/1_null_and_blank_count.xlsx".format(previous_qa_loc))

def count_null_and_blank(new_database, previous_qa_loc):
    tc = pd.read_excel('{}/1_null_and_blank_count.xlsx'.format(previous_qa_loc))
    table_col_dict = zip(tc['Table'], tc['Column'])
    results = []
    for table, col in table_col_dict:
        try:
            conn = engine.connect()
            var = conn.execute("select count(*) from {0}.{1} where `{2}` is null or `{2}` = '';".format(new_database, table, col))
            counts = [row[0] for row in var][0]
            conn.close()
            results.append(counts)
            print ("{0}.{1}: {2}".format(table, col, counts))
        except:
            results.append("Error: Problem with {0}.{1}".format(table, col))
            print ("Error: Problem with {0}.{1}".format(table, col) )
    return results
def increase_10_percent_desc(newdb_count, olddb_count, accept_inc):
    try:
        int(newdb_count)
        int(olddb_count)
        if newdb_count < olddb_count:
            return "Problem: Less nulls in current update than previous update."
        elif newdb_count > (olddb_count * accept_inc):
            return "Problem: Too many new nulls."
        elif olddb_count <= newdb_count <= olddb_count * accept_inc:
            return "No Problem!"
        else:
            return "Check the logic!"
    except:
        return "Problem : {}" .format(newdb_count)
def null_to_file(newdb_results,previous_qa_loc, new_qa_loc, new_database):
    df = pd.read_excel('{}/1_null_and_blank_count.xlsx'.format(previous_qa_loc))
    df_2 = pd.DataFrame(newdb_results)
    df_2.rename(columns={0:new_database}, inplace = True)
    df_3 = pd.concat([df, df_2], axis = 1)
    df_3.drop(['Description'], inplace = True, axis = 1)
    df_3['Description'] = df_3.apply(lambda row: increase_10_percent_desc(row[df_3.columns[-1]], row[df_3.columns[-2]], 1.1), axis=1)
    df_3.to_csv('{}/04_null_blanks.csv'.format(new_qa_loc), index = False)

null_results = count_null_and_blank(new_database, previous_qa_loc)
null_to_file(null_results, previous_qa_loc, new_qa_loc, new_database)
# Out:
# application.id: 0
# application.patent_id: 0
# application.type: 0
# application.number: 0
# application.country: 0
# application.date: 0
# application.id_transformed: 0
# application.number_transformed: 0
# application.series_code_transformed_from_type: 0
# assignee.id: 0
# assignee.type: 1
# assignee.name_first: 459401
# assignee.name_last: 459395
# assignee.organization: 46889
# botanic.uuid: 0
# botanic.patent_id: 0
# botanic.latin_name: 3
# botanic.variety: 4
# brf_sum_text.uuid: 0
# brf_sum_text.patent_id: 0
# brf_sum_text.text: 509
# claim.uuid: 0
# claim.patent_id: 0
# claim.text: 1187
# claim.dependent: 34078
# claim.sequence: 0
# claim.exemplary: 0
# cpc_current.uuid: 0
# cpc_current.patent_id: 0
# cpc_current.section_id: 0
# cpc_current.subsection_id: 0
# cpc_current.group_id: 0
# cpc_current.subgroup_id: 0
# cpc_current.category: 0
# cpc_current.sequence: 6147543
# cpc_group.id: 0
# cpc_group.title: 0
# cpc_subgroup.id: 0
# cpc_subgroup.title: 0
# cpc_subsection.id: 0
# cpc_subsection.title: 0
# detail_desc_text.uuid: 0
# detail_desc_text.patent_id: 0
# detail_desc_text.text: 161407
# detail_desc_text.length: 161393
# draw_desc_text.uuid: 0
# draw_desc_text.patent_id: 0
# draw_desc_text.text: 138
# draw_desc_text.sequence: 3922118
# figures.uuid: 0
# figures.patent_id: 0
# figures.num_figures: 56022
# figures.num_sheets: 54421
# foreign_priority.uuid: 0
# foreign_priority.patent_id: 0
# foreign_priority.sequence: 2543903
# foreign_priority.kind: 1523090
# foreign_priority.number: 1
# foreign_priority.date: 0
# foreign_priority.country: 0
# foreign_priority.country_transformed: 0
# foreigncitation.uuid: 0
# foreigncitation.patent_id: 0
# foreigncitation.date: 0
# foreigncitation.number: 0
# foreigncitation.country: 0
# foreigncitation.category: 0
# foreigncitation.sequence: 3638519
# government_interest.patent_id: 0
# government_interest.gi_statement: 1
# government_organization.organization_id: 0
# government_organization.name: 0
# government_organization.level_one: 0
# government_organization.level_two: 36
# government_organization.level_three: 161
# inventor.id: 0
# inventor.name_first: 155
# inventor.name_last: 6
# ipcr.uuid: 0
# ipcr.patent_id: 0
# ipcr.classification_level: 4424918
# ipcr.section: 0
# ipcr.ipc_class: 0
# ipcr.subclass: 7
# ipcr.main_group: 953
# ipcr.subgroup: 881
# ipcr.symbol_position: 201063
# ipcr.classification_value: 201063
# ipcr.classification_status: 201063
# ipcr.classification_data_source: 201063
# ipcr.action_date: 0
# ipcr.ipc_version_indicator: 0
# ipcr.sequence: 6378835
# lawyer.id: 0
# lawyer.name_first: 73183
# lawyer.name_last: 73183
# lawyer.organization: 93068
# lawyer.country: 148824
# location.id: 0
# location.city: 124
# location.state: 102594
# location.country: 0
# location.latitude: 1
# location.longitude: 15
# location.county: 119109
# location.state_fips: 102646
# location.county_fips: 127016
# location_assignee.location_id: 7768
# location_assignee.assignee_id: 0
# location_inventor.location_id: 0
# location_inventor.inventor_id: 0
# mainclass.id: 0
# mainclass_current.id: 0
# mainclass_current.title: 36
# nber.uuid: 0
# nber.patent_id: 0
# nber.category_id: 0
# nber.subcategory_id: 0
# nber_category.id: 0
# nber_category.title: 0
# nber_subcategory.id: 0
# nber_subcategory.title: 0
# non_inventor_applicant.uuid: 0
# non_inventor_applicant.patent_id: 0
# non_inventor_applicant.rawlocation_id: 1103
# non_inventor_applicant.lname: 1026756
# non_inventor_applicant.fname: 1026678
# non_inventor_applicant.organization: 2519951
# non_inventor_applicant.sequence: 0
# non_inventor_applicant.designation: 0
# non_inventor_applicant.applicant_type: 0
# otherreference.uuid: 0
# otherreference.patent_id: 0
# otherreference.text: 70
# otherreference.sequence: 2997134
# patent.id: 0
# patent.type: 0
# patent.number: 0
# patent.country: 0
# patent.date: 0
# patent.abstract: 334375
# patent.title: 77
# patent.kind: 1
# patent.num_claims: 10
# patent.filename: 1
# patent_assignee.patent_id: 0
# patent_assignee.assignee_id: 0
# patent_contractawardnumber.patent_id: 0
# patent_contractawardnumber.contract_award_number: 0
# patent_govintorg.patent_id: 0
# patent_govintorg.organization_id: 0
# patent_inventor.patent_id: 0
# patent_inventor.inventor_id: 0
# patent_lawyer.patent_id: 0
# patent_lawyer.lawyer_id: 48
# pct_data.uuid: 0
# pct_data.patent_id: 0
# pct_data.rel_id: 1
# pct_data.date: 0
# pct_data.371_date: 100435
# pct_data.country: 0
# pct_data.kind: 0
# pct_data.doc_type: 0
# pct_data.102_date: 131770
# Error: Problem with persistent_inventor_disambig.rawinventor_id
# persistent_inventor_disambig.disamb_inventor_id_20171226: 1236589
# persistent_inventor_disambig.disamb_inventor_id_20171003: 1019009
# persistent_inventor_disambig.disamb_inventor_id_20170808: 1390316
# rawassignee.uuid: 0
# rawassignee.patent_id: 0
# rawassignee.assignee_id: 0
# rawassignee.rawlocation_id: 7707
# rawassignee.type: 0
# rawassignee.name_first: 6003306
# rawassignee.name_last: 6003305
# rawassignee.organization: 66797
# rawassignee.sequence: 5873455
# rawexaminer.uuid: 0
# rawexaminer.patent_id: 0
# rawexaminer.name_first: 29
# rawexaminer.name_last: 0
# rawexaminer.role: 0
# rawexaminer.group: 3648470
# rawinventor.uuid: 0
# rawinventor.patent_id: 0
# rawinventor.inventor_id: 0
# rawinventor.rawlocation_id: 287
# rawinventor.name_first: 334
# rawinventor.name_last: 37
# rawinventor.sequence: 6818468
# rawinventor.rule_47: 10868523
# rawlawyer.uuid: 0
# rawlawyer.lawyer_id: 48
# rawlawyer.patent_id: 0
# rawlawyer.name_first: 4758919
# rawlawyer.name_last: 4758918
# rawlawyer.organization: 2980274
# rawlawyer.country: 7107968
# rawlawyer.sequence: 2949405
# Error: Problem with rawlawyer.country_transformed
# Error: Problem with rawlawyer.name_last_transformed
# Error: Problem with rawlawyer.name_first_transformed
# Error: Problem with rawlawyer.lawyer_id_transformed
# Error: Problem with rawlawyer.organization_transformed
# rawlocation.id: 0
# rawlocation.location_id: 482
# rawlocation.city: 142692
# rawlocation.state: 12947208
# rawlocation.country: 541
# rawlocation.country_transformed: 801
# rawlocation.location_id_transformed: 482
# rel_app_text.uuid: 0
# rel_app_text.patent_id: 0
# rel_app_text.text: 339
# rel_app_text.sequence: 1617202
# subclass.id: 0
# subclass_current.id: 0
# subclass_current.title: 3005
# us_term_of_grant.uuid: 0
# us_term_of_grant.patent_id: 0
# us_term_of_grant.lapse_of_patent: 3215961
# us_term_of_grant.disclaimer_date: 111509
# us_term_of_grant.term_disclaimer: 2973105
# us_term_of_grant.term_grant: 2472771
# us_term_of_grant.term_extension: 871311
# usapplicationcitation.uuid: 0
# usapplicationcitation.patent_id: 0
# usapplicationcitation.application_id: 0
# usapplicationcitation.date: 0
# usapplicationcitation.name: 0
# usapplicationcitation.kind: 511
# usapplicationcitation.number: 0
# usapplicationcitation.country: 0
# usapplicationcitation.category: 0
# usapplicationcitation.sequence: 2752853
# usapplicationcitation.application_id_transformed: 0
# usapplicationcitation.number_transformed: 0
# uspatentcitation.uuid: 0
# uspatentcitation.patent_id: 0
# uspatentcitation.citation_id: 2
# uspatentcitation.date: 0
# uspatentcitation.name: 195
# uspatentcitation.kind: 21753254
# uspatentcitation.country: 0
# uspatentcitation.category: 21863086
# uspatentcitation.sequence: 6472837
# uspc.uuid: 0
# uspc.patent_id: 0
# uspc.mainclass_id: 11
# uspc.subclass_id: 0
# uspc.sequence: 5054587
# uspc_current.uuid: 0
# uspc_current.patent_id: 0
# uspc_current.mainclass_id: 1
# uspc_current.subclass_id: 1
# uspc_current.sequence: 6613578
# usreldoc.uuid: 0
# usreldoc.patent_id: 0
# usreldoc.doctype: 0
# usreldoc.relkind: 4471070
# usreldoc.reldocno: 0
# usreldoc.country: 188704
# usreldoc.date: 136217
# usreldoc.status: 8580824
# usreldoc.sequence: 3440349
# usreldoc.kind: 4445998
# wipo.patent_id: 0
# wipo.field_id: 0
# wipo.sequence: 6144877
# wipo_field.id: 0
# wipo_field.sector_title: 0
# wipo_field.field_title: 0

# %%
#Count Null and Blank QA

#set up sql alchemy engine
import pandas as pd
import os
import configparser
import sys
sys.path.append('/project/Development')
from helpers import general_helpers
import configparser
config = configparser.ConfigParser()
config.read('/project/Development/config.ini')
host = config['DATABASE']['HOST']
username = config['DATABASE']['USERNAME']
password = config['DATABASE']['PASSWORD']
new_database = config['DATABASE']['NEW_DB']
old_database = config['DATABASE']['OLD_DB']
temporary_upload = config['DATABASE']['TEMP_UPLOAD_DB']
previous_qa_loc = config['FOLDERS']['OLD_QA_LOC']
new_qa_loc = config['FOLDERS']['OLD_QA_LOC']
latest_expected_date = config['CONSTANTS']['LATEST_DATE']

# %%
engine = general_helpers.connect_to_db(host, username, password, new_database)
data = pd.read_excel("{}/1_null_and_blank_count.xlsx".format(previous_qa_loc))
print (data.head())
# Out:
#          Table     Column  patent_20170808  patent_20171226  \
# 0  application         id              0.0                0
# 1  application  patent_id              0.0                0
# 2  application       type              0.0                0
# 3  application     number              0.0                0
# 4  application    country              0.0                0
#
#   patent_20180528_restored  Description
# 0                        0  No Problem!
# 1                        0  No Problem!
# 2                        0  No Problem!
# 3                        0  No Problem!
# 4                        0  No Problem!

# %%
tc = pd.read_excel('{}/1_null_and_blank_count.xlsx'.format(previous_qa_loc))
table_col_dict = zip(tc['Table'], tc['Column'])
results = []
for table, col in table_col_dict:
    try:
        counts = engine.execute("select count(*) from {0}.{1} where `{2}` is null or `{2}` = '';".format(new_database, table, col))
        results.append(counts)
        print ("{0}.{1}: {2}".format(table, col, counts))
    except:
        results.append("Error: Problem with {0}.{1}".format(table, col))
        print ("Error: Problem with {0}.{1}".format(table, col) )
return results
# Out:
# application.id: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033033f28>
# application.patent_id: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033021f28>
# application.type: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033021cc0>
# application.number: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033021a90>
# application.country: <sqlalchemy.engine.result.ResultProxy object at 0x7f90330217b8>
# application.date: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033021358>
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py:509: Warning: (1292, "Incorrect date value: '' for column 'date' at row 1")
#   cursor.execute(statement, parameters)
# application.id_transformed: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033021048>
# application.number_transformed: <sqlalchemy.engine.result.ResultProxy object at 0x7f9032fcc320>
# application.series_code_transformed_from_type: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033119470>
# assignee.id: <sqlalchemy.engine.result.ResultProxy object at 0x7f9033033ba8>
# assignee.type: <sqlalchemy.engine.result.ResultProxy object at 0x7f9032fcc518>
# assignee.name_first: <sqlalchemy.engine.result.ResultProxy object at 0x7f9032fcc748>
# assignee.name_last: <sqlalchemy.engine.result.ResultProxy object at 0x7f9032fcca90>
# assignee.organization: <sqlalchemy.engine.result.ResultProxy object at 0x7f9032fcccf8>
# botanic.uuid: <sqlalchemy.engine.result.ResultProxy object at 0x7f9032fc20b8>
# Error: Problem with botanic.patent_id
# Error: Problem with botanic.latin_name
# Error: Problem with botanic.variety
# Error: Problem with brf_sum_text.uuid
# Error: Problem with brf_sum_text.patent_id
# Error: Problem with brf_sum_text.text
# Error: Problem with claim.uuid
# Error: Problem with claim.patent_id
# Error: Problem with claim.text
# Error: Problem with claim.dependent
# Error: Problem with claim.sequence

# %%
def count_null_and_blank(new_database, previous_qa_loc):
    tc = pd.read_excel('{}/1_null_and_blank_count.xlsx'.format(previous_qa_loc))
    table_col_dict = zip(tc['Table'], tc['Column'])
    results = []
    for table, col in table_col_dict:
        try:
            counts = engine.execute("select count(*) from {0}.{1} where `{2}` is null or `{2}` = '';".format(new_database, table, col))
            results.append(counts)
            print ("{0}.{1}: {2}".format(table, col, counts))
        except:
            results.append("Error: Problem with {0}.{1}".format(table, col))
            print ("Error: Problem with {0}.{1}".format(table, col) )
    return results
def increase_10_percent_desc(newdb_count, olddb_count, accept_inc):
    try:
        int(newdb_count)
        int(olddb_count)
        if newdb_count < olddb_count:
            return "Problem: Less nulls in current update than previous update."
        elif newdb_count > (olddb_count * accept_inc):
            return "Problem: Too many new nulls."
        elif olddb_count <= newdb_count <= olddb_count * accept_inc:
            return "No Problem!"
        else:
            return "Check the logic!"
    except:
        return "Problem : {}" .format(newdb_count)
def null_to_excel(newdb_results,previous_qa_loc, new_qa_loc, new_database):
    df = pd.read_excel('{}/1_null_and_blank_count.xlsx'.format(previous_qa_loc))
    df_2 = pd.DataFrame(newdb_results)
    df_2.rename(columns={0:new_database}, inplace = True)
    df_3 = pd.concat([df, df_2], axis = 1)
    df_3.drop(['Description'], inplace = True, axis = 1)
    df_3['Description'] = df_3.apply(lambda row: increase_10_percent_desc(row[df_3.columns[-1]], row[df_3.columns[-2]], 1.1), axis=1)
    df_3.to_excel('{}/1_null_and_blank_count.xlsx'.format(new_qa_loc), index = False)

# %%
null_results = count_null_and_blank(new_database, previous_qa_loc)
null_to_excel(null_results, previous_qa_loc, new_qa_loc, new_database)
# Out:
# application.id: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ced20b8>
# application.patent_id: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ced2240>
# application.type: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ced24a8>
# application.number: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ced2710>
# application.country: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ced29e8>
# application.date: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9cf03a20>
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py:509: Warning: (1292, "Incorrect date value: '' for column 'date' at row 1")
#   cursor.execute(statement, parameters)
# application.id_transformed: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9cee0908>
# application.number_transformed: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9cee0cc0>
# application.series_code_transformed_from_type: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ced2fd0>
# assignee.id: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ce7e358>
# assignee.type: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ce7e630>
# assignee.name_first: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ce7e8d0>
# assignee.name_last: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ce7eba8>
# assignee.organization: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ce7ee48>
# botanic.uuid: <sqlalchemy.engine.result.ResultProxy object at 0x7f9d9ce84208>
# Error: Problem with botanic.patent_id
# Error: Problem with botanic.latin_name
# Error: Problem with botanic.variety
# Error: Problem with brf_sum_text.uuid
# Error: Problem with brf_sum_text.patent_id
# Error: Problem with brf_sum_text.text
# Error: Problem with claim.uuid
# Error: Problem with claim.patent_id
# Error: Problem with claim.text
# Error: Problem with claim.dependent
# Error: Problem with claim.sequence
# Error: Problem with claim.exemplary
# Error: Problem with cpc_current.uuid
# Error: Problem with cpc_current.patent_id
# Error: Problem with cpc_current.section_id
# Error: Problem with cpc_current.subsection_id
# Error: Problem with cpc_current.group_id
# Error: Problem with cpc_current.subgroup_id
# Error: Problem with cpc_current.category
# Error: Problem with cpc_current.sequence
# Error: Problem with cpc_group.id
# Error: Problem with cpc_group.title
# Error: Problem with cpc_subgroup.id
# Error: Problem with cpc_subgroup.title
# Error: Problem with cpc_subsection.id
# Error: Problem with cpc_subsection.title
# Error: Problem with detail_desc_text.uuid
# Error: Problem with detail_desc_text.patent_id
# Error: Problem with detail_desc_text.text
# Error: Problem with detail_desc_text.length
# Error: Problem with draw_desc_text.uuid
# Error: Problem with draw_desc_text.patent_id
# Error: Problem with draw_desc_text.text
# Error: Problem with draw_desc_text.sequence
# Error: Problem with figures.uuid
# Error: Problem with figures.patent_id
# Error: Problem with figures.num_figures
# Error: Problem with figures.num_sheets
# Error: Problem with foreign_priority.uuid
# Error: Problem with foreign_priority.patent_id
# Error: Problem with foreign_priority.sequence
# Error: Problem with foreign_priority.kind
# Error: Problem with foreign_priority.number
# Error: Problem with foreign_priority.date
# Error: Problem with foreign_priority.country
# Error: Problem with foreign_priority.country_transformed
# Error: Problem with foreigncitation.uuid
# Error: Problem with foreigncitation.patent_id
# Error: Problem with foreigncitation.date
# Error: Problem with foreigncitation.number
# Error: Problem with foreigncitation.country
# Error: Problem with foreigncitation.category
# Error: Problem with foreigncitation.sequence
# Error: Problem with government_interest.patent_id
# Error: Problem with government_interest.gi_statement
# Error: Problem with government_organization.organization_id
# Error: Problem with government_organization.name
# Error: Problem with government_organization.level_one
# Error: Problem with government_organization.level_two
# Error: Problem with government_organization.level_three
# Error: Problem with inventor.id
# Error: Problem with inventor.name_first
# Error: Problem with inventor.name_last
# Error: Problem with ipcr.uuid
# Error: Problem with ipcr.patent_id
# Error: Problem with ipcr.classification_level
# Error: Problem with ipcr.section
# Error: Problem with ipcr.ipc_class
# Error: Problem with ipcr.subclass
# Error: Problem with ipcr.main_group
# Error: Problem with ipcr.subgroup
# Error: Problem with ipcr.symbol_position
# Error: Problem with ipcr.classification_value
# Error: Problem with ipcr.classification_status
# Error: Problem with ipcr.classification_data_source
# Error: Problem with ipcr.action_date
# Error: Problem with ipcr.ipc_version_indicator
# Error: Problem with ipcr.sequence
# Error: Problem with lawyer.id
# Error: Problem with lawyer.name_first
# Error: Problem with lawyer.name_last
# Error: Problem with lawyer.organization
# Error: Problem with lawyer.country
# Error: Problem with location.id
# Error: Problem with location.city
# Error: Problem with location.state
# Error: Problem with location.country
# Error: Problem with location.latitude
# Error: Problem with location.longitude
# Error: Problem with location.county
# Error: Problem with location.state_fips
# Error: Problem with location.county_fips
# Error: Problem with location_assignee.location_id
# Error: Problem with location_assignee.assignee_id
# Error: Problem with location_inventor.location_id
# Error: Problem with location_inventor.inventor_id
# Error: Problem with mainclass.id
# Error: Problem with mainclass_current.id
# Error: Problem with mainclass_current.title
# Error: Problem with nber.uuid
# Error: Problem with nber.patent_id
# Error: Problem with nber.category_id
# Error: Problem with nber.subcategory_id
# Error: Problem with nber_category.id
# Error: Problem with nber_category.title
# Error: Problem with nber_subcategory.id
# Error: Problem with nber_subcategory.title
# Error: Problem with non_inventor_applicant.uuid
# Error: Problem with non_inventor_applicant.patent_id
# Error: Problem with non_inventor_applicant.rawlocation_id
# Error: Problem with non_inventor_applicant.lname
# Error: Problem with non_inventor_applicant.fname
# Error: Problem with non_inventor_applicant.organization
# Error: Problem with non_inventor_applicant.sequence
# Error: Problem with non_inventor_applicant.designation
# Error: Problem with non_inventor_applicant.applicant_type
# Error: Problem with otherreference.uuid
# Error: Problem with otherreference.patent_id
# Error: Problem with otherreference.text
# Error: Problem with otherreference.sequence
# Error: Problem with patent.id
# Error: Problem with patent.type
# Error: Problem with patent.number
# Error: Problem with patent.country
# Error: Problem with patent.date
# Error: Problem with patent.abstract
# Error: Problem with patent.title
# Error: Problem with patent.kind
# Error: Problem with patent.num_claims
# Error: Problem with patent.filename
# Error: Problem with patent_assignee.patent_id
# Error: Problem with patent_assignee.assignee_id
# Error: Problem with patent_contractawardnumber.patent_id
# Error: Problem with patent_contractawardnumber.contract_award_number
# Error: Problem with patent_govintorg.patent_id
# Error: Problem with patent_govintorg.organization_id
# Error: Problem with patent_inventor.patent_id
# Error: Problem with patent_inventor.inventor_id
# Error: Problem with patent_lawyer.patent_id
# Error: Problem with patent_lawyer.lawyer_id
# Error: Problem with pct_data.uuid
# Error: Problem with pct_data.patent_id
# Error: Problem with pct_data.rel_id
# Error: Problem with pct_data.date
# Error: Problem with pct_data.371_date
# Error: Problem with pct_data.country
# Error: Problem with pct_data.kind
# Error: Problem with pct_data.doc_type
# Error: Problem with pct_data.102_date
# Error: Problem with persistent_inventor_disambig.rawinventor_id
# Error: Problem with persistent_inventor_disambig.disamb_inventor_id_20171226
# Error: Problem with persistent_inventor_disambig.disamb_inventor_id_20171003
# Error: Problem with persistent_inventor_disambig.disamb_inventor_id_20170808
# Error: Problem with rawassignee.uuid
# Error: Problem with rawassignee.patent_id
# Error: Problem with rawassignee.assignee_id
# Error: Problem with rawassignee.rawlocation_id
# Error: Problem with rawassignee.type
# Error: Problem with rawassignee.name_first
# Error: Problem with rawassignee.name_last
# Error: Problem with rawassignee.organization
# Error: Problem with rawassignee.sequence
# Error: Problem with rawexaminer.uuid
# Error: Problem with rawexaminer.patent_id
# Error: Problem with rawexaminer.name_first
# Error: Problem with rawexaminer.name_last
# Error: Problem with rawexaminer.role
# Error: Problem with rawexaminer.group
# Error: Problem with rawinventor.uuid
# Error: Problem with rawinventor.patent_id
# Error: Problem with rawinventor.inventor_id
# Error: Problem with rawinventor.rawlocation_id
# Error: Problem with rawinventor.name_first
# Error: Problem with rawinventor.name_last
# Error: Problem with rawinventor.sequence
# Error: Problem with rawinventor.rule_47
# Error: Problem with rawlawyer.uuid
# Error: Problem with rawlawyer.lawyer_id
# Error: Problem with rawlawyer.patent_id
# Error: Problem with rawlawyer.name_first
# Error: Problem with rawlawyer.name_last
# Error: Problem with rawlawyer.organization
# Error: Problem with rawlawyer.country
# Error: Problem with rawlawyer.sequence
# Error: Problem with rawlawyer.country_transformed
# Error: Problem with rawlawyer.name_last_transformed
# Error: Problem with rawlawyer.name_first_transformed
# Error: Problem with rawlawyer.lawyer_id_transformed
# Error: Problem with rawlawyer.organization_transformed
# Error: Problem with rawlocation.id
# Error: Problem with rawlocation.location_id
# Error: Problem with rawlocation.city
# Error: Problem with rawlocation.state
# Error: Problem with rawlocation.country
# Error: Problem with rawlocation.country_transformed
# Error: Problem with rawlocation.location_id_transformed
# Error: Problem with rel_app_text.uuid
# Error: Problem with rel_app_text.patent_id
# Error: Problem with rel_app_text.text
# Error: Problem with rel_app_text.sequence
# Error: Problem with subclass.id
# Error: Problem with subclass_current.id
# Error: Problem with subclass_current.title
# Error: Problem with us_term_of_grant.uuid
# Error: Problem with us_term_of_grant.patent_id
# Error: Problem with us_term_of_grant.lapse_of_patent
# Error: Problem with us_term_of_grant.disclaimer_date
# Error: Problem with us_term_of_grant.term_disclaimer
# Error: Problem with us_term_of_grant.term_grant
# Error: Problem with us_term_of_grant.term_extension
# Error: Problem with usapplicationcitation.uuid
# Error: Problem with usapplicationcitation.patent_id
# Error: Problem with usapplicationcitation.application_id
# Error: Problem with usapplicationcitation.date
# Error: Problem with usapplicationcitation.name
# Error: Problem with usapplicationcitation.kind
# Error: Problem with usapplicationcitation.number
# Error: Problem with usapplicationcitation.country
# Error: Problem with usapplicationcitation.category
# Error: Problem with usapplicationcitation.sequence
# Error: Problem with usapplicationcitation.application_id_transformed
# Error: Problem with usapplicationcitation.number_transformed
# Error: Problem with uspatentcitation.uuid
# Error: Problem with uspatentcitation.patent_id
# Error: Problem with uspatentcitation.citation_id
# Error: Problem with uspatentcitation.date
# Error: Problem with uspatentcitation.name
# Error: Problem with uspatentcitation.kind
# Error: Problem with uspatentcitation.country
# Error: Problem with uspatentcitation.category
# Error: Problem with uspatentcitation.sequence
# Error: Problem with uspc.uuid
# Error: Problem with uspc.patent_id
# Error: Problem with uspc.mainclass_id
# Error: Problem with uspc.subclass_id
# Error: Problem with uspc.sequence
# Error: Problem with uspc_current.uuid
# Error: Problem with uspc_current.patent_id
# Error: Problem with uspc_current.mainclass_id
# Error: Problem with uspc_current.subclass_id
# Error: Problem with uspc_current.sequence
# Error: Problem with usreldoc.uuid
# Error: Problem with usreldoc.patent_id
# Error: Problem with usreldoc.doctype
# Error: Problem with usreldoc.relkind
# Error: Problem with usreldoc.reldocno
# Error: Problem with usreldoc.country
# Error: Problem with usreldoc.date
# Error: Problem with usreldoc.status
# Error: Problem with usreldoc.sequence
# Error: Problem with usreldoc.kind
# Error: Problem with wipo.patent_id
# Error: Problem with wipo.field_id
# Error: Problem with wipo.sequence
# Error: Problem with wipo_field.id
# Error: Problem with wipo_field.sector_title
# Error: Problem with wipo_field.field_title
