# %%
import os
import pymysql
import datetime

# %%
os.environ['PACKAGE_HOME']="/Users/bcard/projects/patentsview/PatentsView-DB"

# %%
pwd
# Out:
# '/Users/bcard/projects/patentsview/PatentsView-DB'

# %%
from lib.configuration import get_config, get_connection_string, get_current_config
# c=get_config()

# %%
config = get_current_config('pgpubs', **{
        "execution_date": datetime.date(2021, 12, 2)
    })

# %%
connection_string=get_connection_string(config, database='PROD_DB')

# %%
connection_string
# Out:
# 'mysql+pymysql://bcard:oVKUc4A7ofP5S@pv3-ingestmysql.cckzcdkkfzqo.us-east-1.rds.amazonaws.com:3306/pregrant_publications?charset=utf8mb4'

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine(connection_string)

# %%
engine
# Out:
# Engine(mysql+pymysql://bcard:***@pv3-ingestmysql.cckzcdkkfzqo.us-east-1.rds.amazonaws.com:3306/pregrant_publications?charset=utf8mb4)

# %%
import pandas as pd

# %%
columns=pd.read_sql_query(sql="""
select *
from information_schema.COLUMNS
where TABLE_SCHEMA = 'pregrant_publications'
   and TABLE_NAME not like '%%tmp%%'
   and TABLE_NAME not like '%%temp%%'
   and TABLE_NAME not like '%%backup%%'
   and TABLE_NAME not like '%%archive%%'
   and TABLE_NAME not like '%%old%%';
""", con=engine)

# %%
columns
# Out:
#      TABLE_CATALOG           TABLE_SCHEMA         TABLE_NAME  \
# 0              def  pregrant_publications  brf_sum_text_2017
# 1              def  pregrant_publications  brf_sum_text_2017
# 2              def  pregrant_publications  brf_sum_text_2017
# 3              def  pregrant_publications  brf_sum_text_2017
# 4              def  pregrant_publications  brf_sum_text_2017
# ...            ...                    ...                ...
# 1118           def  pregrant_publications   foreign_priority
# 1119           def  pregrant_publications   foreign_priority
# 1120           def  pregrant_publications   foreign_priority
# 1121           def  pregrant_publications   foreign_priority
# 1122           def  pregrant_publications   foreign_priority
#
#             COLUMN_NAME  ORDINAL_POSITION       COLUMN_DEFAULT IS_NULLABLE  \
# 0                    id                 1                 NULL         YES
# 1       document_number                 2                 NULL         YES
# 2                  text                 3                 NULL         YES
# 3              filename                 4                 NULL         YES
# 4          created_date                 5  current_timestamp()         YES
# ...                 ...               ...                  ...         ...
# 1118               kind                 6                 NULL         YES
# 1119           filename                 7                 NULL         YES
# 1120       created_date                 8  current_timestamp()         YES
# 1121       updated_date                 9                 NULL         YES
# 1122  version_indicator                10                 NULL         YES
#
#        DATA_TYPE  CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 0        varchar                     512.0                  2048.0  ...
# 1         bigint                       NaN                     NaN  ...
# 2     mediumtext                16777215.0              16777215.0  ...
# 3        varchar                      16.0                    64.0  ...
# 4      timestamp                       NaN                     NaN  ...
# ...          ...                       ...                     ...  ...
# 1118     varchar                      20.0                    80.0  ...
# 1119     varchar                      16.0                    64.0  ...
# 1120   timestamp                       NaN                     NaN  ...
# 1121   timestamp                       NaN                     NaN  ...
# 1122        date                       NaN                     NaN  ...
#
#       DATETIME_PRECISION  CHARACTER_SET_NAME      COLLATION_NAME  \
# 0                    NaN             utf8mb4  utf8mb4_unicode_ci
# 1                    NaN                None                None
# 2                    NaN             utf8mb4  utf8mb4_unicode_ci
# 3                    NaN             utf8mb4  utf8mb4_unicode_ci
# 4                    0.0                None                None
# ...                  ...                 ...                 ...
# 1118                 NaN             utf8mb4  utf8mb4_unicode_ci
# 1119                 NaN             utf8mb4  utf8mb4_unicode_ci
# 1120                 0.0                None                None
# 1121                 0.0                None                None
# 1122                 NaN                None                None
#
#        COLUMN_TYPE COLUMN_KEY                          EXTRA  \
# 0     varchar(512)
# 1       bigint(16)        UNI
# 2       mediumtext
# 3      varchar(16)        MUL
# 4        timestamp
# ...            ...        ...                            ...
# 1118   varchar(20)
# 1119   varchar(16)        MUL
# 1120     timestamp
# 1121     timestamp             on update current_timestamp()
# 1122          date        MUL
#
#                 PRIVILEGES COLUMN_COMMENT IS_GENERATED GENERATION_EXPRESSION
# 0     select,insert,update                       NEVER                  None
# 1     select,insert,update                       NEVER                  None
# 2     select,insert,update                       NEVER                  None
# 3     select,insert,update                       NEVER                  None
# 4     select,insert,update                       NEVER                  None
# ...                    ...            ...          ...                   ...
# 1118  select,insert,update                       NEVER                  None
# 1119  select,insert,update                       NEVER                  None
# 1120  select,insert,update                       NEVER                  None
# 1121  select,insert,update                       NEVER                  None
# 1122  select,insert,update                       NEVER                  None
#
# [1123 rows x 22 columns]

# %%
# columns=pd.read_sql_query(sql="""
# select *
# from information_schema.COLUMNS
# where TABLE_SCHEMA = 'patent_text'
#   and TABLE_NAME not like '%%tmp%%'
#   and TABLE_NAME not like '%%temp%%'
#   and TABLE_NAME not like '%%backup%%'
#   and TABLE_NAME not like '%%archive%%'
#   and TABLE_NAME not like '%%old%%'
# """, con=engine)

# %%
columns.groupby('TABLE_NAME').get_group('claim_2021')
# Out:
#     TABLE_CATALOG           TABLE_SCHEMA  TABLE_NAME        COLUMN_NAME  \
# 124           def  pregrant_publications  claim_2021                 id
# 125           def  pregrant_publications  claim_2021    document_number
# 126           def  pregrant_publications  claim_2021               text
# 127           def  pregrant_publications  claim_2021           sequence
# 128           def  pregrant_publications  claim_2021          dependent
# 129           def  pregrant_publications  claim_2021           filename
# 130           def  pregrant_publications  claim_2021       created_date
# 131           def  pregrant_publications  claim_2021       updated_date
# 132           def  pregrant_publications  claim_2021                num
# 133           def  pregrant_publications  claim_2021  version_indicator
#
#      ORDINAL_POSITION       COLUMN_DEFAULT IS_NULLABLE   DATA_TYPE  \
# 124                 1                 NULL         YES     varchar
# 125                 2                 NULL         YES      bigint
# 126                 3                 NULL         YES  mediumtext
# 127                 4                 NULL         YES         int
# 128                 5                 NULL         YES     varchar
# 129                 6                 NULL         YES     varchar
# 130                 7  current_timestamp()         YES   timestamp
# 131                 8                 NULL         YES   timestamp
# 132                 9                 NULL         YES     varchar
# 133                10                 NULL         YES        date
#
#      CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 124                     512.0                  2048.0  ...
# 125                       NaN                     NaN  ...
# 126                16777215.0              16777215.0  ...
# 127                       NaN                     NaN  ...
# 128                     512.0                  2048.0  ...
# 129                      16.0                    64.0  ...
# 130                       NaN                     NaN  ...
# 131                       NaN                     NaN  ...
# 132                     128.0                   512.0  ...
# 133                       NaN                     NaN  ...
#
#      DATETIME_PRECISION  CHARACTER_SET_NAME      COLLATION_NAME   COLUMN_TYPE  \
# 124                 NaN             utf8mb4  utf8mb4_unicode_ci  varchar(512)
# 125                 NaN                None                None    bigint(16)
# 126                 NaN             utf8mb4  utf8mb4_unicode_ci    mediumtext
# 127                 NaN                None                None       int(11)
# 128                 NaN             utf8mb4  utf8mb4_unicode_ci  varchar(512)
# 129                 NaN             utf8mb4  utf8mb4_unicode_ci   varchar(16)
# 130                 0.0                None                None     timestamp
# 131                 0.0                None                None     timestamp
# 132                 NaN             utf8mb4  utf8mb4_unicode_ci  varchar(128)
# 133                 NaN                None                None          date
#
#     COLUMN_KEY                          EXTRA            PRIVILEGES  \
# 124                                            select,insert,update
# 125        MUL                                 select,insert,update
# 126                                            select,insert,update
# 127                                            select,insert,update
# 128                                            select,insert,update
# 129        MUL                                 select,insert,update
# 130                                            select,insert,update
# 131             on update current_timestamp()  select,insert,update
# 132                                            select,insert,update
# 133                                            select,insert,update
#
#     COLUMN_COMMENT IS_GENERATED GENERATION_EXPRESSION
# 124                       NEVER                  None
# 125                       NEVER                  None
# 126                       NEVER                  None
# 127                       NEVER                  None
# 128                       NEVER                  None
# 129                       NEVER                  None
# 130                       NEVER                  None
# 131                       NEVER                  None
# 132                       NEVER                  None
# 133                       NEVER                  None
#
# [10 rows x 22 columns]

# %%
columns['TABLE_NAME'].unique()
# Out:
# array(['brf_sum_text_2017', 'detail_desc_text_2013',
#        'inventor_disambiguation_mapping_20210629', 'claim_2003',
#        'assignee_disambiguation_mapping_20210330', 'brf_sum_text_2019',
#        'detail_desc_text_2004', 'draw_desc_text_2017', 'claim_2011',
#        'rawuspc', 'claim_2018', 'detail_desc_text_2018', 'inventor',
#        'draw_desc_text_2006', 'brf_sum_text_2010',
#        'detail_desc_text_2007', 'draw_desc_text_2001', 'claim_2021',
#        'draw_desc_text_2008', 'rawlocation_geos_missed',
#        'assignee_disambiguation_mapping_20210930', 'claim_2017',
#        'detail_desc_text_2009', 'claim_2007', 'claim_2019',
#        'detail_desc_text_2006', 'rawinventor_ernest_20210330',
#        'brf_sum_text_2013', 'claim_2014', 'ipcr', 'detail_desc_text_2008',
#        'brf_sum_text_2003', 'usreldoc', 'brf_sum_text_2008',
#        'draw_desc_text_2012', 'location_disambiguation_mapping_20210629',
#        'location_inventor_20210330', 'persistent_assignee_disambig_long',
#        'detail_desc_text_2016', 'draw_desc_text_2002',
#        'brf_sum_text_2012', 'detail_desc_text_2014',
#        'draw_desc_text_2014', 'claim_2012', 'rawlocation_lat_lon',
#        'clean_rawlocation', 'draw_desc_text_2005',
#        'assignee_disambiguation_mapping_20201229', 'claim_2005',
#        'draw_desc_text_2015', 'claim_2010', 'brf_sum_text_2004',
#        'persistent_assignee_disambig', 'detail_desc_text_2011',
#        'draw_desc_text_2009', 'brf_sum_text_2020',
#        'granted_patent_crosswalk', 'brf_sum_text_2021', 'uspc',
#        'detail_desc_text_2021', 'draw_desc_text_2016', 'claim_2016',
#        'detail_desc_text_2010', 'detail_desc_text_2020',
#        'brf_sum_text_2009', 'publication_inventor', 'cpc_current',
#        'main_cpc', 'granted_patent_crosswalk_20201231',
#        'draw_desc_text_2004', 'brf_sum_text_2002', 'rel_app_text',
#        'inventor_disambiguation_mapping_20210629_full',
#        'brf_sum_text_2007', 'inventor_disambiguation_mapping_20210930',
#        'draw_desc_text_2011', 'further_cpc',
#        'assignee_disambiguation_mapping_20210629',
#        'rawlocation_ernest_20210330', 'application', 'brf_sum_text_2016',
#        'detail_desc_text_2017', 'pct_data', 'government_interest',
#        'brf_sum_text_2011', 'brf_sum_text_2015', 'us_parties',
#        'rawinventor', 'claim_2006', 'draw_desc_text_2013',
#        'brf_sum_text_2001', 'location_disambiguation_mapping',
#        'claim_2020', 'rawlocation', 'claim_2002',
#        'rawlocation_lat_lon_20210930', 'brf_sum_text_2005',
#        'draw_desc_text_2020', 'draw_desc_text_2018',
#        'disambiguated_rawassginee', 'detail_desc_text_2003',
#        'brf_sum_text_2014', 'detail_desc_text_2012',
#        'disambiguated_inventor_ids_20210629',
#        'inventor_disambiguation_mapping_20210330', 'publication',
#        'claim_2009', 'publication_assignee', 'draw_desc_text_2010',
#        'claim_2001', 'rawassignee', 'cpc', 'claim_2004', 'claim_2013',
#        'detail_desc_text_2005', 'granted_patent_crosswalk_20201229',
#        'disambiguated_assignee_ids_20210629',
#        'inventor_disambiguation_mapping', 'draw_desc_text_2019',
#        'detail_desc_text_2001', 'brf_sum_text_2018', 'brf_sum_text_2006',
#        'location_disambiguation_mapping_20210330',
#        'detail_desc_text_2019', 'location_assignee_20210330',
#        'draw_desc_text_2021', 'assignee_disambiguation_mapping',
#        'publication_assignee_20210330', 'location_assignee',
#        'rawassignee_20201229', 'draw_desc_text_2003', 'claim_2015',
#        'assignee', 'draw_desc_text_2007', 'detail_desc_text_2002',
#        'location_inventor', 'claim_2008', 'detail_desc_text_2015',
#        'foreign_priority'], dtype=object)

# %%
def generate_column_setting(column):
    
    data_type = 'varchar'
    if column.DATA_TYPE in ['date', 'timestamp'] and column.COLUMN_NAME != 'version_indicator':
        data_type = 'date'
    if column.DATA_TYPE in ['int', 'bigint', 'smallint', 'float', 'decimal']:
        data_type = 'int'
    
    null_allowed = True
    if column.IS_NULLABLE == 'NO':
        null_allowed = False
    
    category = False
#     if column.COLUMN_NAME in ['version_indicator']:
#         category = True
        
    setting = {
        column.COLUMN_NAME: {
            'data_type': data_type,
            'null_allowed': null_allowed,
            'category': category,
            'location_field': False
        }
    }
    return setting

# %%
from functools import reduce

# %%
def generate_table_setting(table_group):
    y=table_group.apply(generate_column_setting,axis=1)
    t_set={table_group.name:{"fields":reduce(lambda a, b: dict(a, **b), y.tolist())}}
    return t_set

# %%
x=columns.groupby('TABLE_NAME').apply(func=generate_table_setting)

# %%
x.keys()
# Out:
# Index(['application', 'assignee', 'assignee_disambiguation_mapping',
#        'assignee_disambiguation_mapping_20201229',
#        'assignee_disambiguation_mapping_20210330',
#        'assignee_disambiguation_mapping_20210629',
#        'assignee_disambiguation_mapping_20210930', 'brf_sum_text_2001',
#        'brf_sum_text_2002', 'brf_sum_text_2003',
#        ...
#        'rawlocation', 'rawlocation_ernest_20210330', 'rawlocation_geos_missed',
#        'rawlocation_lat_lon', 'rawlocation_lat_lon_20210930', 'rawuspc',
#        'rel_app_text', 'us_parties', 'uspc', 'usreldoc'],
#       dtype='object', name='TABLE_NAME', length=139)

# %%
c_set=reduce(lambda a, b: dict(a, **b), x.tolist())

# %%
c_set.keys()
# Out:
# dict_keys(['application', 'assignee', 'assignee_disambiguation_mapping', 'assignee_disambiguation_mapping_20201229', 'assignee_disambiguation_mapping_20210330', 'assignee_disambiguation_mapping_20210629', 'assignee_disambiguation_mapping_20210930', 'brf_sum_text_2001', 'brf_sum_text_2002', 'brf_sum_text_2003', 'brf_sum_text_2004', 'brf_sum_text_2005', 'brf_sum_text_2006', 'brf_sum_text_2007', 'brf_sum_text_2008', 'brf_sum_text_2009', 'brf_sum_text_2010', 'brf_sum_text_2011', 'brf_sum_text_2012', 'brf_sum_text_2013', 'brf_sum_text_2014', 'brf_sum_text_2015', 'brf_sum_text_2016', 'brf_sum_text_2017', 'brf_sum_text_2018', 'brf_sum_text_2019', 'brf_sum_text_2020', 'brf_sum_text_2021', 'claim_2001', 'claim_2002', 'claim_2003', 'claim_2004', 'claim_2005', 'claim_2006', 'claim_2007', 'claim_2008', 'claim_2009', 'claim_2010', 'claim_2011', 'claim_2012', 'claim_2013', 'claim_2014', 'claim_2015', 'claim_2016', 'claim_2017', 'claim_2018', 'claim_2019', 'claim_2020', 'claim_2021', 'clean_rawlocation', 'cpc', 'cpc_current', 'detail_desc_text_2001', 'detail_desc_text_2002', 'detail_desc_text_2003', 'detail_desc_text_2004', 'detail_desc_text_2005', 'detail_desc_text_2006', 'detail_desc_text_2007', 'detail_desc_text_2008', 'detail_desc_text_2009', 'detail_desc_text_2010', 'detail_desc_text_2011', 'detail_desc_text_2012', 'detail_desc_text_2013', 'detail_desc_text_2014', 'detail_desc_text_2015', 'detail_desc_text_2016', 'detail_desc_text_2017', 'detail_desc_text_2018', 'detail_desc_text_2019', 'detail_desc_text_2020', 'detail_desc_text_2021', 'disambiguated_assignee_ids_20210629', 'disambiguated_inventor_ids_20210629', 'disambiguated_rawassginee', 'draw_desc_text_2001', 'draw_desc_text_2002', 'draw_desc_text_2003', 'draw_desc_text_2004', 'draw_desc_text_2005', 'draw_desc_text_2006', 'draw_desc_text_2007', 'draw_desc_text_2008', 'draw_desc_text_2009', 'draw_desc_text_2010', 'draw_desc_text_2011', 'draw_desc_text_2012', 'draw_desc_text_2013', 'draw_desc_text_2014', 'draw_desc_text_2015', 'draw_desc_text_2016', 'draw_desc_text_2017', 'draw_desc_text_2018', 'draw_desc_text_2019', 'draw_desc_text_2020', 'draw_desc_text_2021', 'foreign_priority', 'further_cpc', 'government_interest', 'granted_patent_crosswalk', 'granted_patent_crosswalk_20201229', 'granted_patent_crosswalk_20201231', 'inventor', 'inventor_disambiguation_mapping', 'inventor_disambiguation_mapping_20210330', 'inventor_disambiguation_mapping_20210629', 'inventor_disambiguation_mapping_20210629_full', 'inventor_disambiguation_mapping_20210930', 'ipcr', 'location_assignee', 'location_assignee_20210330', 'location_disambiguation_mapping', 'location_disambiguation_mapping_20210330', 'location_disambiguation_mapping_20210629', 'location_inventor', 'location_inventor_20210330', 'main_cpc', 'pct_data', 'persistent_assignee_disambig', 'persistent_assignee_disambig_long', 'publication', 'publication_assignee', 'publication_assignee_20210330', 'publication_inventor', 'rawassignee', 'rawassignee_20201229', 'rawinventor', 'rawinventor_ernest_20210330', 'rawlocation', 'rawlocation_ernest_20210330', 'rawlocation_geos_missed', 'rawlocation_lat_lon', 'rawlocation_lat_lon_20210930', 'rawuspc', 'rel_app_text', 'us_parties', 'uspc', 'usreldoc'])

# %%
for i in c_set.keys():
    for j in list(c_set[i]['fields'].keys()):
        if j in ['created_date','updated_date','patent_date','version_indicator','filename']:
            del c_set[i]['fields'][j]

# %%
test_script_list = []
for i in c_set.keys():
    if i[:7] in ['brf_sum','claims_','detail_','draw_de']:
        test_script_list.append("TextMergeTest")
        test_script_list.append("TextUploadTest")
        
    c_set[i]['TestScripts'] = test_script_list
    test_script_list = []

# %%
c_set
# Out:
# {'application': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'series_code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invention_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invention_abstract': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rule_47_flag': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20201229': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20210330': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20210629': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20210930': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'brf_sum_text_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2006': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2007': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2008': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2009': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2010': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2011': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2012': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2013': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2014': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2015': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2016': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2017': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2018': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2019': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2020': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2021': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claim_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2006': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2007': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2008': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2009': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2010': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2011': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2012': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2013': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2014': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2015': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2016': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2017': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2018': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2019': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2020': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2021': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'clean_rawlocation': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc_current': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'detail_desc_text_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2006': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2007': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2008': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2009': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2010': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2011': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2012': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2013': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2014': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2015': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2016': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2017': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2018': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2019': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2020': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2021': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'disambiguated_assignee_ids_20210629': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'disambiguated_inventor_ids_20210629': {'fields': {'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'disambiguated_rawassginee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'draw_desc_text_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
# ...
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filing_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication_assignee': {'fields': {'document_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication_assignee_20210330': {'fields': {'document_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication_inventor': {'fields': {'document_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawassignee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawassignee_20201229': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawinventor': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'deceased': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawinventor_ernest_20210330': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'deceased': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'export': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_ernest_20210330': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_geos_missed': {'fields': {'lat': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_lat_lon': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lat': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_lat_lon_20210930': {'fields': {'lat': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawuspc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'classification': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rel_app_text': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'us_parties': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'uspc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'usreldoc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'related_doc_number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'doc_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'relkind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []}}

# %%
list(c_set['brf_sum_text_2016']['fields'].keys())
# Out:
# ['id', 'document_number', 'text']

# %%
len(c_set.keys())
# Out:
# 139

# %%
c_set
# Out:
# {'application': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'application_number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'series_code': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invention_title': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'invention_abstract': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rule_47_flag': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20201229': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20210330': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20210629': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'assignee_disambiguation_mapping_20210930': {'fields': {'uuid': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'brf_sum_text_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2006': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2007': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2008': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2009': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2010': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2011': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2012': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2013': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2014': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2015': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2016': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2017': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2018': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2019': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2020': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'brf_sum_text_2021': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'claim_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2006': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2007': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2008': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2009': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2010': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2011': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2012': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2013': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2014': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2015': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2016': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2017': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2018': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2019': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2020': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'claim_2021': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'dependent': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'num': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'clean_rawlocation': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'action_date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'cpc_current': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'version': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'section_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subsection_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'group_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subgroup_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'symbol_position': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'value': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'category': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'detail_desc_text_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2006': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2007': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2008': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2009': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2010': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2011': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2012': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2013': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2014': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2015': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2016': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2017': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2018': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2019': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2020': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'detail_desc_text_2021': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'length': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'disambiguated_assignee_ids_20210629': {'fields': {'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'disambiguated_inventor_ids_20210629': {'fields': {'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'disambiguated_rawassginee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'draw_desc_text_2001': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2002': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2003': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2004': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': ['TextMergeTest', 'TextUploadTest']},
#  'draw_desc_text_2005': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
# ...
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'kind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'filing_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication_assignee': {'fields': {'document_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication_assignee_20210330': {'fields': {'document_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'publication_inventor': {'fields': {'document_number': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawassignee': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawassignee_20201229': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'assignee_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawinventor': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'deceased': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawinventor_ernest_20210330': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'inventor_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'deceased': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'export': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_ernest_20210330': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'location_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'latitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'longitude': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'location_id_transformed': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_geos_missed': {'fields': {'lat': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_lat_lon': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'lat': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawlocation_lat_lon_20210930': {'fields': {'lat': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'lon': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rawuspc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'classification': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'rel_app_text': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'text': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'us_parties': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'name_first': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'name_last': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'organization': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'designation': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'rawlocation_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'city': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'state': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'uspc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'mainclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'subclass_id': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'sequence': {'data_type': 'int',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []},
#  'usreldoc': {'fields': {'id': {'data_type': 'varchar',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'document_number': {'data_type': 'int',
#     'null_allowed': False,
#     'category': False,
#     'location_field': False},
#    'related_doc_number': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'country': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'doc_type': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'relkind': {'data_type': 'varchar',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False},
#    'date': {'data_type': 'date',
#     'null_allowed': True,
#     'category': False,
#     'location_field': False}},
#   'TestScripts': []}}

# %%
#### UPDATES NEEDED IN REPO
# change True and False to lowercase
# change datatype to data_type
